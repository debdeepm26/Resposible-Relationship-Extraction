# %%
import pandas as pd
from pandas.errors import EmptyDataError
import numpy as np
import difflib as df
import spacy
from transformers import pipeline
import spacy_component
import glob
import operator
from collections import Counter

# %%
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# # Create Dict

# %%
def create_tagged_dict(tagged_token):
    tagged_dict = {} # creating a data dict using the tagged dataframe
    prev_sen = 0
    word_count = 0
    error_flag = 0
    for index, row in tagged_token.iterrows():
        current_sen = row["sent_index"]
        if prev_sen != current_sen:
            word_count = 0
        key = str(row["sent_index"]) + "_" + str(row["word_index"])
        tagged_dict[key] = [row["pos"], row["tag"], row["dep"], row["entity type"], row["entity mention ID"], str(row["text"])]
        word_count += 1
        prev_sen = current_sen
            
    return tagged_dict

# %% [markdown]
# # Sentence Entity

# %%
def sentence_entity(tagged_dict, sentence_index, sentence_nlp, enhanced_bool = False):
    
    entities = []
    entity = ""
    entity_index = ""
    prev_token = ""
    prev_token_index = ""
    indices = []
    entities_types = []
    key_str = []
    
    
    if enhanced_bool == True:
        for index, token in enumerate(sentence_nlp):

            if token.text == "''":
                token_text = "'"
            else:
                token_text = token.text

            key = str(sentence_index) + "_" + str(index)

            pos = tagged_dict[key][0]
            dep = str(tagged_dict[key][2])
            entity_type = tagged_dict[key][3]

            if not pd.isnull(entity_type):
                entity = entity + " " + token_text
                if entity_index != "":
                    entity_index = entity_index + "_" + str(index)
                else:
                    entity_index = str(index)

            elif pd.isnull(entity_type) and (dep == "compound" or dep.endswith("mod")):
                prev_token = prev_token + " " + token_text
                if prev_token_index != "":
                    prev_token_index = prev_token_index + "_" + str(index)
                else:
                    prev_token_index = str(index)

            elif pd.isnull(entity_type) and dep != "compound" and dep.endswith("mod") == False and entity == "":
                prev_token = ""
                prev_token_index = ""

            entity = entity.strip()

            if pd.isnull(entity_type) and entity != "":

                if prev_token != "":
                    entity = prev_token + " " + entity
                    entity_index = prev_token_index + "_" + entity_index

                entities.append(entity.strip())
                indices.append(entity_index)
                entities_types.append(entity_type.strip())
                entity = ""
                entity_index = ""
                prev_token = ""
                prev_token_index = ""
    else:
        for key in tagged_dict.keys():
            
            key_split = key.split("_")
            sentence_id = key_split[0]
            key_id = key_split[1]
            
            if str(sentence_id) == str(sentence_index):
                entity_type = tagged_dict[key][3]
                entity_id = tagged_dict[key][4]
                
                if not pd.isnull(entity_type):
                    
                    if len(indices) != 0 and indices[-1] == entity_id:
                        entities[-1] = entities[-1] + " " + tagged_dict[key][5]
                        key_str[-1] = key_str[-1] + "-" + str(key_id)
                        
                    else:
                        key_str.append(str(key_id))
                        entities.append(tagged_dict[key][5])
                        indices.append(entity_id)
                        entities_types.append(entity_type.strip())              
    return entities, indices, key_str, entities_types

# %% [markdown]
# # Raw Relationships

# %%
def find_relation(tagged_dict, sentence_index, entity_list):
    
    entities_relations = []
    
    sentence_entities = entity_list[1]
    
    entities_text = sentence_entities[0]
    entities_indices = sentence_entities[1]
    entities_key = sentence_entities[2]
    entities_type = sentence_entities[3]
    entities_len = len(entities_text)
    
    for index, entity_text in enumerate(entities_text):
        
        entity1 = ""
        entity1_index = ""
        entity2 = ""
        entity2_index = ""
        
        entity_pair_relation = ""
        entity_pair_relation_pos_pattern = ""
        
        if index == entities_len - 1:
            continue
        else:
            
            entity1 = entity_text
            entity1_index = entities_key[index].split('-')[-1]
            entity1_id = entities_indices[index]
            entity1_type = entities_type[index]
            
            entity2 = entities_text[index + 1]
            entity2_index = entities_key[index + 1].split('-')[0]
            entity2_id = entities_indices[index + 1]
            entity2_type = entities_type[index + 1]
            
            for i in range(int(entity1_index) + 1, int(entity2_index)):
                
                token_text = tagged_dict[str(sentence_index) + "_" + str(i)][5]
                
                entity_pair_relation = entity_pair_relation + " " + token_text
                
                if entity_pair_relation_pos_pattern != "" and entity_pair_relation_pos_pattern != 'PUNCT':
                    tmp = tagged_dict[str(sentence_index) + "_" + str(i)][0]
                    if tmp != 'PUNCT':
                        entity_pair_relation_pos_pattern = entity_pair_relation_pos_pattern + "-" + tagged_dict[str(sentence_index) + "_" + str(i)][0]
                else:
                    tmp = tagged_dict[str(sentence_index) + "_" + str(i)][0]
                    if tmp != 'PUNCT':
                        entity_pair_relation_pos_pattern = tagged_dict[str(sentence_index) + "_" + str(i)][0]
                    
        entity_pair_relation = entity1 + " " + entity_pair_relation.strip() + " " + entity2
        entity_pair_type = entity1_type + "-" + entity2_type
        entities_relations.append([[entity1, entity2], [entity1_id, entity2_id, entity_pair_type], [entity_pair_relation, entity_pair_relation_pos_pattern]])
    
    return entities_relations

# %% [markdown]
# # Global Snowball

# %%
def cal_pos_pattern_count(snowball_index, pos_pattern_list):
    for index, pos_pattern in enumerate(pos_pattern_list):
        if pos_pattern in snowball_index:
            snowball_index[pos_pattern] += 1
        elif pos_pattern != pos_pattern:
            pass
        else:
            snowball_index[pos_pattern] = 1

    return snowball_index

# %%
def generate_snowball(files):
    
    snowball_index = {}

    for file in files:
        try:
            file_tagged_truth = pd.read_csv(file, sep = "\t")
            if len(file_tagged_truth) != 0:
                pos_pattern_list = file_tagged_truth.pos_pattern.tolist()
                snowball_index = cal_pos_pattern_count(snowball_index, pos_pattern_list)
        except EmptyDataError:
            print(f"No columns to parse from file {file}")
            
    return snowball_index

# %%
def cal_rank(snowball_index):
    
    snowball_pos_pattern = {}
    total_index = 0
    
    for value in snowball_index.values():
        total_index += value
    
    for key, value in snowball_index.items():
        snowball_pos_pattern[key] = value/total_index
    
    return snowball_pos_pattern, total_index

# %%
def sort_dict(snowball_pos_pattern):
    return dict(sorted(snowball_pos_pattern.items(), key=operator.itemgetter(1), reverse=True))

# %%
def remove_out(snowball_pos_pattern):
    snowball_pos_pattern_values = np.array(list(snowball_pos_pattern.values()))
    snowball_pos_pattern_keys = list(snowball_pos_pattern.keys())
    
    mean = np.mean(snowball_pos_pattern_values, axis=0)
    sd = np.std(snowball_pos_pattern_values, axis=0)
    
    final_list = [x for x in snowball_pos_pattern_values if (x >= mean - 2 * sd)]
    final_list = [x for x in final_list if (x <= mean + 2 * sd)]
    
    snowball_pos_pattern_keys = snowball_pos_pattern_keys[:len(final_list)]
    
    snowball_pos_pattern_filter = dict(zip(snowball_pos_pattern_keys, final_list))
    
    return snowball_pos_pattern_filter

# %%
def re_rank_snowball(snowball_pos_pattern, snowball_key, total_index):
    
    for key in snowball_pos_pattern.keys():
        
        if snowball_key == key:
            snowball_pos_pattern[key] = ((snowball_pos_pattern[key]*(total_index)) + 1)/(total_index + 1)
        else:
            snowball_pos_pattern[key] = (snowball_pos_pattern[key]*(total_index))/(total_index + 1)
            
    return snowball_pos_pattern

# %%
def check_pos_pattern_and_update(snowball_pos_pattern, pos_pattern, total_index, re_compute = False):
    
    if pos_pattern in snowball_pos_pattern.keys():
        score = snowball_pos_pattern[pos_pattern]
        if re_compute == True:
            print("\n=====Matched with SnowBall -- Re-Computing Snowball=====\n")
            snowball_pos_pattern = re_rank_snowball(snowball_pos_pattern, pos_pattern, total_index)
        return score, snowball_pos_pattern
    else:
        return False, snowball_pos_pattern

# %% [markdown]
# # Main Script

# %%
train_annotated_0_truth = pd.read_csv("../Data/relex_processed_data/relex/docred/ground_truth/train_annotated_0.csv", sep = "\t")
train_annotated_0_tagged = pd.read_csv("../Data/relex_processed_data/relex/docred/tagged_tokens/train_annotated_0.csv", sep = "\t")

# %%
train_annotated_0_text = open("../Data/relex_processed_data/relex/docred/raw_text/train_annotated_0.txt", "r", encoding="utf8")

# %%
train_annotated_0_text_list = train_annotated_0_text.readlines()

# %%
train_annotated_0_text_list = [sentence for sentence in train_annotated_0_text_list if sentence != '\n']
train_annotated_0_text_list = [sentence.replace('\n', '') for sentence in train_annotated_0_text_list]

# %%
train_annotated_0_dict = create_tagged_dict(train_annotated_0_tagged)

# %%
sentences_entity_list = []

for index, sentence in enumerate(train_annotated_0_text_list):
    sentence_nlp = nlp(sentence)
    entities, indices, key_str, entities_types = sentence_entity(train_annotated_0_dict, index, sentence_nlp, False)
    sentences_entity_list.append([index, [entities, indices, key_str, entities_types]])

# %%
for index, entity_list in enumerate(sentences_entity_list):
    print(entity_list[0])
    print(train_annotated_0_text_list[entity_list[0]])
    print(entity_list[1])
    print("\n")
# Out:
# 0
# Zest Airways , Inc. operated as AirAsia Zest ( formerly Asian Spirit and Zest Air ) , was a low - cost airline based at the Ninoy Aquino International Airport in Pasay City , Metro Manila in the Philippines .
# [['Zest Airways , Inc.', 'AirAsia Zest', 'Asian Spirit and Zest Air', 'Ninoy Aquino International Airport', 'Pasay City', 'Metro Manila', 'Philippines'], ['train_annotated_0_0_0', 'train_annotated_0_0_2', 'train_annotated_0_0_1', 'train_annotated_0_1_1', 'train_annotated_0_2_0', 'train_annotated_0_3_0', 'train_annotated_0_4_0'], ['0-1-2-3', '6-7', '10-11-12-13-14', '26-27-28-29', '31-32', '34-35', '38'], ['ORG', 'ORG', 'ORG', 'LOC', 'LOC', 'LOC', 'LOC']]
#
#
# 1
# It operated scheduled domestic and international tourist services , mainly feeder services linking Manila and Cebu with 24 domestic destinations in support of the trunk route operations of other airlines .
# [['Manila', 'Cebu', '24'], ['train_annotated_0_5_0', 'train_annotated_0_6_0', 'train_annotated_0_7_0'], ['53', '55', '57'], ['LOC', 'LOC', 'NUM']]
#
#
# 2
# In 2013 , the airline became an affiliate of Philippines AirAsia operating their brand separately .
# [['2013', 'Philippines AirAsia'], ['train_annotated_0_8_0', 'train_annotated_0_9_0'], ['72', '80-81'], ['TIME', 'ORG']]
#
#
# 3
# Its main base was Ninoy Aquino International Airport , Manila .
# [['Ninoy Aquino International Airport', 'Manila'], ['train_annotated_0_1_0', 'train_annotated_0_5_1'], ['91-92-93-94', '96'], ['LOC', 'LOC']]
#
#
# 4
# The airline was founded as Asian Spirit , the first airline in the Philippines to be run as a cooperative .
# [['Asian Spirit', 'Philippines'], ['train_annotated_0_10_0', 'train_annotated_0_4_1'], ['103-104', '111'], ['ORG', 'LOC']]
#
#
# 5
# On August 16 , 2013 , the Civil Aviation Authority of the Philippines ( CAAP ) , the regulating body of the Government of the Republic of the Philippines for civil aviation , suspended Zest Air flights until further notice because of safety issues .
# [['August 16 , 2013', 'Civil Aviation Authority of the Philippines', 'CAAP', 'Republic of the Philippines', 'Zest Air'], ['train_annotated_0_8_1', 'train_annotated_0_11_0', 'train_annotated_0_11_1', 'train_annotated_0_4_2', 'train_annotated_0_12_0'], ['120-121-122-123', '126-127-128-129-130-131', '133', '144-145-146-147', '153-154'], ['TIME', 'ORG', 'ORG', 'LOC', 'ORG']]
#
#
# 6
# Less than a year after AirAsia and Zest Air 's strategic alliance , the airline has been rebranded as AirAsia Zest .
# [['a year', 'AirAsia', 'Zest Air', 'AirAsia Zest'], ['train_annotated_0_13_0', 'train_annotated_0_14_0', 'train_annotated_0_12_1', 'train_annotated_0_0_3'], ['166-167', '169', '171-172', '183-184'], ['NUM', 'ORG', 'ORG', 'ORG']]
#
#
# 7
# The airline was merged into AirAsia Philippines in January 2016 .
# [['AirAsia Philippines', 'January 2016'], ['train_annotated_0_15_0', 'train_annotated_0_16_0'], ['191-192', '194-195'], ['ORG', 'TIME']]

# %% [markdown]
# ## Generate Snowball

# %%
docred_truth_dir = "../Data/relex_processed_data/relex/docred/ground_truth/*.csv"
docred_truth_dir_files = glob.glob(docred_truth_dir)

# %%
snowball_index = generate_snowball(docred_truth_dir_files)
snowball_pos_pattern, total_index = cal_rank(snowball_index)
snowball_pos_pattern = sort_dict(snowball_pos_pattern)
snowball_pos_pattern_filter = remove_out(snowball_pos_pattern)

# %%
snowball_pos_pattern_filter
# Out:
# {'ADP': 0.003048780487804878,
#  'PROPN': 0.0029563932002956393,
#  'VERB': 0.0029563932002956393,
#  'NOUN-ADP': 0.002771618625277162,
#  'NOUN': 0.0025868440502586844,
#  'ADP-DET': 0.0024944567627494456,
#  'VERB-DET': 0.0024944567627494456,
#  'PART': 0.002402069475240207,
#  'NUM-SYM': 0.002402069475240207,
#  'VERB-VERB-ADP': 0.002402069475240207,
#  'CCONJ': 0.0022172949002217295,
#  'ADP-PROPN': 0.0021249076127124907,
#  'VERB-ADP': 0.0021249076127124907,
#  'PROPN-PROPN': 0.0020325203252032522,
#  'NUM-PROPN': 0.0019401330376940134,
#  'NOUN-NOUN': 0.0019401330376940134,
#  'VERB-DET-NOUN-ADP': 0.0018477457501847746,
#  'PROPN-ADP': 0.001755358462675536,
#  'DET-NOUN-ADP': 0.0016629711751662971,
#  'PART-NOUN': 0.0016629711751662971,
#  'ADP-DET-NOUN-ADP': 0.0016629711751662971,
#  'ADP-PROPN-PROPN': 0.0015705838876570585,
#  'NOUN-ADP-DET': 0.0014781966001478197,
#  'NOUN-ADP-PROPN': 0.0014781966001478197,
#  'VERB-NUM-ADP': 0.0014781966001478197,
#  'DET': 0.001385809312638581,
#  'VERB-DET-NOUN-ADP-DET': 0.0012934220251293422,
#  'ADP-ADJ': 0.0012934220251293422,
#  'NUM': 0.0012934220251293422,
#  'VERB-ADP-DET': 0.0012010347376201036,
#  'VERB-DET-ADJ-NOUN-ADP': 0.0012010347376201036,
#  'VERB-ADP-PROPN-ADP': 0.0012010347376201036,
#  'PROPN-PROPN-VERB-DET': 0.0012010347376201036,
#  'CCONJ-DET-NOUN': 0.0012010347376201036,
#  'VERB-PROPN-ADP': 0.0012010347376201036,
#  'VERB-NUM-VERB-DET': 0.0011086474501108647,
#  'VERB-VERB': 0.0011086474501108647,
#  'NUM-SYM-NUM-VERB-DET': 0.0011086474501108647,
#  'VERB-PROPN-VERB-DET': 0.0011086474501108647,
#  'NUM-ADP': 0.0011086474501108647,
#  'CCONJ-PROPN-ADP': 0.0011086474501108647,
#  'ADP-PROPN-ADP': 0.0011086474501108647,
#  'ADJ': 0.0010162601626016261,
#  'ADJ-NOUN': 0.0010162601626016261,
#  'CCONJ-PROPN-NOUN-ADP': 0.0010162601626016261,
#  'ADP-DET-PROPN-ADP': 0.0010162601626016261,
#  'NUM-PROPN-NUM-VERB-DET': 0.0010162601626016261,
#  'VERB-VERB-ADP-DET': 0.0010162601626016261,
#  'PROPN-NOUN': 0.0010162601626016261,
#  'ADP-DET-PROPN-NOUN-ADP': 0.0010162601626016261,
#  'CCONJ-PROPN': 0.0010162601626016261,
#  'NUM-ADP-PROPN-PROPN': 0.0010162601626016261,
#  'NOUN-NOUN-NOUN': 0.0010162601626016261,
#  'NOUN-VERB': 0.0010162601626016261,
#  'VERB-DET-ADJ-NOUN-NOUN-ADP': 0.0010162601626016261,
#  'VERB-DET-ADJ-NOUN-ADP-DET': 0.0009238728750923873,
#  'VERB-ADP-PROPN': 0.0009238728750923873,
#  'VERB-PROPN': 0.0009238728750923873,
#  'ADP-DET-ADJ-NOUN-ADP': 0.0009238728750923873,
#  'PROPN-CCONJ': 0.0009238728750923873,
#  'PART-ADJ-NOUN': 0.0009238728750923873,
#  'DET-NOUN-ADP-DET': 0.0009238728750923873,
#  'PROPN-CCONJ-PROPN-NOUN-ADP': 0.0009238728750923873,
#  'VERB-DET-ADJ-NOUN-ADP-PROPN': 0.0009238728750923873,
#  'PROPN-VERB-DET': 0.0009238728750923873,
#  'NOUN-VERB-ADP': 0.0009238728750923873,
#  'CCONJ-DET': 0.0008314855875831486,
#  'VERB-DET-ADJ-NOUN-NOUN-VERB-ADP': 0.0008314855875831486,
#  'CCONJ-DET-NOUN-ADP': 0.0008314855875831486,
#  'ADV-ADP': 0.0008314855875831486,
#  'PROPN-ADP-DET': 0.0008314855875831486,
#  'VERB-DET-NOUN-ADP-PROPN': 0.0008314855875831486,
#  'ADP-DET-NOUN': 0.0007390983000739098,
#  'PART-NUM-NOUN': 0.0007390983000739098,
#  'PROPN-PROPN-PROPN': 0.0007390983000739098,
#  'VERB-DET-ADJ-NOUN-ADP-PROPN-PROPN': 0.0006467110125646711,
#  'ADP-DET-ADJ': 0.0006467110125646711,
#  'VERB-DET-NUM': 0.0006467110125646711,
#  'NOUN-ADP-ADJ': 0.0006467110125646711,
#  'ADP-DET-NOUN-ADP-PROPN': 0.0006467110125646711,
#  'PART-NOUN-ADP': 0.0006467110125646711,
#  'PROPN-PROPN-PROPN-VERB-DET': 0.0006467110125646711,
#  'ADP-PROPN-ADP-DET': 0.0006467110125646711,
#  'NOUN-NOUN-VERB-ADP': 0.0006467110125646711,
#  'NUM-ADP-PROPN-PROPN-NUM-ADP': 0.0006467110125646711,
#  'VERB-ADP-DET-NOUN-ADP': 0.0006467110125646711,
#  'PROPN-PROPN-CCONJ': 0.0006467110125646711,
#  'VERB-VERB-ADP-PROPN-ADP': 0.0006467110125646711,
#  'ADJ-NOUN-ADP': 0.0006467110125646711,
#  'VERB-DET-NOUN-NOUN-ADP-DET': 0.0006467110125646711,
#  'NUM-CCONJ': 0.0006467110125646711,
#  'NOUN-PROPN': 0.0006467110125646711,
#  'VERB-NOUN': 0.0006467110125646711,
#  'DET-ADJ-NOUN-ADP': 0.0006467110125646711,
#  'VERB-DET-ADJ-NOUN-NOUN-ADP-ADJ-NOUN-NOUN-PROPN-VERB-ADP': 0.0006467110125646711,
#  'NOUN-NOUN-ADP-PROPN': 0.0005543237250554324,
#  'NOUN-NOUN-VERB-ADP-PROPN': 0.0005543237250554324,
#  'NOUN-ADP-PROPN-PROPN': 0.0005543237250554324,
#  'VERB-DET-NUM-ADJ-NOUN-NOUN-VERB-ADP': 0.0005543237250554324,
#  'VERB-DET-ADJ': 0.0005543237250554324,
#  'NOUN-NOUN-ADP': 0.0005543237250554324,
#  'VERB-DET-NOUN-ADP-PROPN-PROPN': 0.0005543237250554324,
#  'VERB-VERB-CCONJ-VERB-ADP': 0.0005543237250554324,
#  'PART-ADJ-NOUN-NOUN': 0.0005543237250554324,
#  'NOUN-PROPN-CCONJ': 0.0005543237250554324,
#  'ADJ-ADJ': 0.0005543237250554324,
#  'NUM-ADP-PROPN': 0.0005543237250554324,
#  'VERB-NUM-ADP-PROPN': 0.0005543237250554324,
#  'VERB-PROPN-PROPN': 0.0005543237250554324,
#  'PROPN-PROPN-PROPN-PROPN': 0.0005543237250554324,
#  'NOUN-ADP-DET-ADJ-NOUN-ADP': 0.0005543237250554324,
#  'PART-NOUN-NOUN': 0.0005543237250554324,
#  'ADV': 0.0005543237250554324,
#  'NOUN-DET': 0.0005543237250554324,
#  'ADJ-NOUN-NOUN': 0.0005543237250554324,
#  'ADP-DET-NOUN-ADP-DET': 0.00046193643754619364,
#  'VERB-DET-ADJ-NOUN-NOUN-ADP-ADJ-NOUN-NOUN': 0.00046193643754619364,
#  'ADP-ADP': 0.00046193643754619364,
#  'ADP-NUM': 0.00046193643754619364,
#  'PRON-VERB-ADP-DET': 0.00046193643754619364,
#  'ADP-NOUN': 0.00046193643754619364,
#  'NOUN-ADP-PROPN-ADP': 0.00046193643754619364,
#  'DET-NOUN-NOUN-ADP': 0.00046193643754619364,
#  'PROPN-VERB': 0.00046193643754619364,
#  'VERB-DET-NOUN-ADP-ADJ-NOUN-CCONJ-ADJ-NOUN-PROPN-ADP': 0.00046193643754619364,
#  'VERB-DET-NOUN-ADP-ADJ-NOUN-ADP': 0.00046193643754619364,
#  'PRON-VERB': 0.00046193643754619364,
#  'VERB-DET-NOUN-ADP-DET-NOUN-ADP': 0.00046193643754619364,
#  'NOUN-ADP-DET-NOUN-ADP': 0.00046193643754619364,
#  'ADJ-NOUN-NOUN-VERB-ADP': 0.00046193643754619364,
#  'ADP-NOUN-ADP-DET': 0.00046193643754619364,
#  'VERB-NOUN-ADP': 0.00046193643754619364,
#  'ADV-VERB-ADP': 0.00046193643754619364,
#  'VERB-DET-PROPN-ADP-DET': 0.00046193643754619364,
#  'ADP-DET-PROPN-ADP-PROPN': 0.00046193643754619364,
#  'VERB-NUM-PROPN': 0.00046193643754619364,
#  'PROPN-ADP-PROPN': 0.00046193643754619364,
#  'VERB-NOUN-NOUN': 0.00046193643754619364,
#  'NOUN-VERB-ADP-DET': 0.00046193643754619364,
#  'ADJ-NOUN-VERB-ADP': 0.00046193643754619364,
#  'DET-NOUN': 0.00046193643754619364,
#  'PROPN-CCONJ-PROPN-ADP': 0.00046193643754619364,
#  'ADP-NOUN-ADP': 0.00046193643754619364,
#  'VERB-DET-NOUN-ADP-ADJ-NOUN': 0.00046193643754619364,
#  'VERB-NUM-ADP-PROPN-VERB-DET': 0.00046193643754619364,
#  'ADP-PROPN-PART': 0.00046193643754619364,
#  'DET-VERB-NOUN-ADP-DET': 0.00046193643754619364,
#  'CCONJ-VERB-ADP': 0.00046193643754619364,
#  'VERB-NUM-ADP-PROPN-PROPN-VERB-DET': 0.00046193643754619364,
#  'VERB-DET-NOUN-ADP-DET-PROPN-ADP': 0.00046193643754619364,
#  'DET-VERB-ADP': 0.00046193643754619364,
#  'ADV-PRON-VERB-ADP': 0.00046193643754619364,
#  'ADP-DET-NUM': 0.00046193643754619364,
#  'VERB-DET-NOUN-NOUN-ADP': 0.00046193643754619364,
#  'NOUN-VERB-PROPN-PROPN': 0.0003695491500369549,
#  'DET-VERB-VERB-ADP': 0.0003695491500369549,
#  'NUM-PROPN-PROPN': 0.0003695491500369549,
#  'NUM-PROPN-NUM': 0.0003695491500369549,
#  'NOUN-CCONJ-NOUN': 0.0003695491500369549,
#  'PART-VERB-ADP': 0.0003695491500369549,
#  'VERB-VERB-DET': 0.0003695491500369549,
#  'VERB-NUM': 0.0003695491500369549,
#  'VERB-DET-NOUN-VERB-ADP': 0.0003695491500369549,
#  'NUM-NUM-VERB-DET': 0.0003695491500369549,
#  'CCONJ-VERB-ADP-DET': 0.0003695491500369549,
#  'PROPN-NOUN-NOUN': 0.0003695491500369549,
#  'PROPN-NOUN-ADP': 0.0003695491500369549,
#  'VERB-DET-NOUN-NOUN-VERB-ADP': 0.0003695491500369549,
#  'VERB-DET-ADJ-ADJ-NOUN-VERB-ADP': 0.0003695491500369549,
#  'VERB-ADP-PROPN-ADP-DET': 0.0003695491500369549,
#  'CCONJ-NUM-ADP-DET-ADJ-ADP': 0.0003695491500369549,
#  'VERB-DET-NOUN-ADP-ADJ': 0.0003695491500369549,
#  'CCONJ-NOUN-ADP': 0.0003695491500369549,
#  'CCONJ-VERB': 0.0003695491500369549,
#  'ADP-DET-NOUN-ADP-ADJ-NUM-CCONJ-ADP-DET-ADJ-NOUN-ADP-PROPN-ADV-DET-NOUN-VERB-PRON-VERB-DET-NOUN-ADP-ADJ-NOUN-NOUN-ADP': 0.0003695491500369549,
#  'ADP-PROPN-ADP-PROPN': 0.0003695491500369549,
#  'VERB-DET-PROPN-ADP-DET-NOUN': 0.0003695491500369549,
#  'ADV-PROPN': 0.0003695491500369549,
#  'ADJ-NOUN-PROPN-PROPN-CCONJ': 0.0003695491500369549,
#  'ADP-DET-NOUN-NOUN': 0.0003695491500369549,
#  'PROPN-VERB-DET-NOUN-ADP-DET-NOUN-ADP-DET-PROPN-ADP-PROPN': 0.0003695491500369549,
#  'ADP-NOUN-ADP-DET-NOUN': 0.0003695491500369549,
#  'DET-ADJ-NOUN-ADP-DET': 0.0003695491500369549,
#  'NOUN-ADJ-ADP': 0.0003695491500369549,
#  'VERB-NOUN-ADP-DET': 0.0003695491500369549,
#  'CCONJ-PROPN-PROPN': 0.0003695491500369549,
#  'PRON-VERB-ADP': 0.0003695491500369549,
#  'VERB-DET-ADJ-NOUN-NOUN-ADP-ADJ-NOUN-PROPN-VERB-ADP': 0.0003695491500369549,
#  'CCONJ-ADJ-NOUN-ADP': 0.0003695491500369549,
#  'PART-ADJ': 0.0003695491500369549,
#  'VERB-DET-NOUN-ADP-DET-PROPN-ADP-PROPN': 0.0003695491500369549,
#  'ADP-PROPN-CCONJ': 0.0003695491500369549,
#  'PROPN-NUM-SYM': 0.0003695491500369549,
#  'VERB-VERB-PROPN-ADP': 0.0003695491500369549,
#  'ADP-ADJ-NOUN': 0.0003695491500369549,
#  'PROPN-VERB-VERB-ADP': 0.0003695491500369549,
#  'SYM': 0.0003695491500369549,
#  'NOUN-VERB-PROPN': 0.0003695491500369549,
#  'VERB-DET-ADJ-NOUN-NOUN-ADP-ADJ-NOUN': 0.0003695491500369549,
#  'ADP-DET-PROPN-NOUN-ADP-ADJ': 0.0003695491500369549,
#  'PART-VERB': 0.0003695491500369549,
#  'ADP-DET-NOUN-ADP-PROPN-ADP': 0.0003695491500369549,
#  'VERB-NOUN-VERB': 0.0003695491500369549,
#  'VERB-DET-ADJ-ADJ-NOUN-NOUN-VERB-ADP': 0.0003695491500369549,
#  'ADP-NUM-ADP': 0.0003695491500369549,
#  'NOUN-ADP-DET-PROPN-VERB-ADP-PROPN-ADP': 0.0003695491500369549,
#  'VERB-PROPN-CCONJ': 0.0003695491500369549,
#  'CCONJ-ADJ': 0.0003695491500369549,
#  'CCONJ-PROPN-NOUN': 0.0003695491500369549,
#  'CCONJ-ADV-ADP-DET': 0.0003695491500369549,
#  'NUM-PROPN-PROPN-VERB-DET': 0.0003695491500369549,
#  'VERB-NOUN-NOUN-VERB-ADP-PROPN-PROPN': 0.0002771618625277162,
#  'ADV-DET': 0.0002771618625277162,
#  'VERB-ADP-PROPN-CCONJ': 0.0002771618625277162,
#  'VERB-ADP-DET-NOUN-NOUN-ADP': 0.0002771618625277162,
#  'DET-NOUN-VERB-ADP': 0.0002771618625277162,
#  'PART-NOUN-NOUN-NOUN': 0.0002771618625277162,
#  'VERB-DET-NOUN-ADP-ADJ-NOUN-NOUN': 0.0002771618625277162,
#  'NOUN-ADP-DET-PROPN-NOUN-ADP': 0.0002771618625277162,
#  'ADP-DET-ADJ-NOUN': 0.0002771618625277162,
#  'ADP-DET-NOUN-NOUN-NOUN': 0.0002771618625277162,
#  'VERB-DET-NOUN-ADP-DET-PROPN-ADP-DET': 0.0002771618625277162,
#  'CCONJ-VERB-ADV-DET-ADV-ADJ-ADP-ADJ-NOUN-ADP-DET-NOUN-NOUN-ADP-DET': 0.0002771618625277162,
#  'VERB-DET-NUM-ADJ-NOUN-NOUN-NOUN-NOUN-VERB-ADP': 0.0002771618625277162,
#  'VERB-DET-NOUN': 0.0002771618625277162,
#  'ADV-DET-ADJ-NOUN-ADP-CCONJ-ADP': 0.0002771618625277162,
#  'ADV-VERB-VERB-DET-NOUN-ADP-DET-PROPN-ADP-DET-PROPN-VERB-ADP-DET-PROPN-NOUN-ADP': 0.0002771618625277162,
#  'ADP-DET-PROPN-CCONJ': 0.0002771618625277162,
#  'NOUN-NUM-SYM': 0.0002771618625277162,
#  'ADP-DET-PROPN-PROPN': 0.0002771618625277162,
#  'PROPN-NUM': 0.0002771618625277162,
#  'NUM-SYM-NUM-CCONJ': 0.0002771618625277162,
#  'CCONJ-PROPN-NOUN-ADP-ADJ': 0.0002771618625277162,
#  'PROPN-PROPN-CCONJ-PROPN-ADP': 0.0002771618625277162,
#  'VERB-NUM-ADP-DET-ADV-ADJ-NOUN-ADP-PROPN-ADP-NUM-ADP-DET-ADJ-NOUN-VERB-ADP-DET-ADJ-ADJ-NOUN-ADV-ADP': 0.0002771618625277162,
#  'VERB-ADP-NOUN-ADP-DET-NOUN-NOUN-ADP': 0.0002771618625277162,
#  'VERB-DET-ADJ-NOUN-VERB-ADP': 0.0002771618625277162,
#  'VERB-DET-NOUN-ADP-PROPN-PROPN-CCONJ': 0.0002771618625277162,
#  'DET-VERB-ADP-DET-NOUN-ADP': 0.0002771618625277162,
#  'CCONJ-VERB-DET-NOUN-ADP-PROPN-NOUN-ADP': 0.0002771618625277162,
#  'CCONJ-DET-ADJ-NOUN': 0.0002771618625277162,
#  'ADP-ADJ-NOUN-ADP': 0.0002771618625277162,
#  'VERB-DET-NOUN-NOUN-NOUN-VERB-ADP': 0.0002771618625277162,
#  'VERB-DET-NOUN-VERB-ADP-DET': 0.0002771618625277162,
#  'VERB-DET-NOUN-ADJ-NOUN-NOUN-DET-VERB-NOUN-ADP-ADJ-ADJ-VERB-ADP-ADJ-NOUN-ADP-PROPN-ADP-PROPN': 0.0002771618625277162,
#  'VERB-DET-NOUN-ADJ-NOUN-NOUN-DET-VERB-NOUN-ADP-ADJ-ADJ-VERB-ADP-ADJ-NOUN-ADP-PROPN-ADP-PROPN-PROPN': 0.0002771618625277162,
#  'CCONJ-DET-PROPN-ADP-PROPN-PRON-VERB-DET-ADV-ADJ-NOUN-VERB-DET-PROPN-ADP-DET-ADJ': 0.0002771618625277162,
#  'PRON-VERB-DET-ADV-ADJ-NOUN-VERB-DET-PROPN-ADP-DET-ADJ': 0.0002771618625277162,
#  'VERB-DET-NUM-ADJ-NOUN-NOUN-NOUN-VERB-CCONJ-VERB-ADP': 0.0002771618625277162,
#  'VERB-VERB-ADP-PROPN-CCONJ-VERB-ADP': 0.0002771618625277162,
#  'NOUN-VERB-DET-PROPN': 0.0002771618625277162,
#  'NOUN-VERB-DET-PROPN-PROPN-DET-PROPN': 0.0002771618625277162,
#  'NOUN-VERB-DET-PROPN-PROPN-DET-PROPN-PROPN-CCONJ': 0.0002771618625277162,
#  'PART-NOUN-ADP-DET': 0.0002771618625277162,
#  'VERB-PROPN-PROPN-PROPN': 0.0002771618625277162,
#  'VERB-DET-ADJ-NOUN': 0.0002771618625277162,
#  'PRON-VERB-VERB-ADP': 0.0002771618625277162,
#  'NUM-ADV-ADP': 0.0002771618625277162,
#  'VERB-DET-NOUN-ADP-PROPN-CCONJ': 0.0002771618625277162,
#  'PART-ADJ-NOUN-ADP': 0.0002771618625277162,
#  'DET-ADJ-ADP': 0.0002771618625277162,
#  'ADP-PROPN-PROPN-CCONJ': 0.0002771618625277162,
#  'NOUN-NOUN-ADP-PROPN-PROPN-CCONJ': 0.0002771618625277162,
#  'PROPN-VERB-ADP': 0.0002771618625277162,
#  'VERB-ADP-DET-ADJ-NOUN-NOUN-ADP': 0.0002771618625277162,
#  'VERB-DET-NOUN-VERB-NOUN-VERB-ADP': 0.0002771618625277162,
#  'VERB-VERB-DET-NOUN-ADP': 0.0002771618625277162,
#  'VERB-DET-ADJ-NOUN-ADP-DET-NOUN-ADP-PROPN-ADP-PROPN': 0.0002771618625277162,
#  'NOUN-VERB-PROPN-PROPN-PROPN': 0.0002771618625277162,
#  'VERB-DET-NOUN-PROPN-NOUN-ADP': 0.0002771618625277162,
#  'VERB-DET-ADJ-ADJ-NOUN-ADP': 0.0002771618625277162,
#  'NOUN-VERB-ADJ-DET-ADV-ADJ-ADP': 0.0002771618625277162,
#  'ADJ-NOUN-NOUN-ADP-DET-NOUN-ADP': 0.0002771618625277162,
#  'DET-NOUN-ADJ-ADP': 0.0002771618625277162,
#  'PART-VERB-DET-ADJ-ADJ-CCONJ-ADJ-ADJ-NOUN-NOUN-ADP': 0.0002771618625277162,
#  'VERB-VERB-VERB-ADP': 0.0002771618625277162,
#  'VERB-DET-ADJ-ADJ-NOUN-NOUN-VERB-ADP-PROPN': 0.0002771618625277162,
#  'CCONJ-PROPN-ADV-VERB-ADP-DET': 0.0002771618625277162,
#  'NOUN-ADP-ADJ-ADJ': 0.0002771618625277162,
#  'PROPN-NUM-PROPN': 0.0002771618625277162,
#  'VERB-NUM-NUM-NOUN-ADP-DET': 0.0002771618625277162,
#  'DET-NOUN-ADP-PROPN-PROPN': 0.0002771618625277162,
#  'DET-NOUN-ADP-PROPN': 0.0002771618625277162,
#  'VERB-DET-NOUN-ADP-DET-ADJ-NOUN-ADP': 0.0002771618625277162,
#  'CCONJ-DET-ADJ-NOUN-VERB': 0.0002771618625277162,
#  'CCONJ-NUM-ADP-DET-ADJ-NOUN-ADP-DET-PROPN-PART': 0.0002771618625277162,
#  'NUM-VERB-DET': 0.0002771618625277162,
#  'NUM-ADP-PROPN-PROPN-NUM-ADP-PROPN-VERB-DET': 0.0002771618625277162,
#  'VERB-PROPN-ADP-PROPN-CCONJ-PROPN-ADP': 0.0002771618625277162,
#  'NOUN-ADJ-CCONJ-PROPN-PROPN-VERB-ADP-DET-ADJ-NOUN-ADP-PROPN': 0.0002771618625277162,
#  'DET-NOUN-ADP-DET-NOUN-PART-NOUN': 0.0002771618625277162,
#  'DET-NOUN-ADP-PROPN-DET-NOUN-ADP': 0.0002771618625277162,
#  'VERB-ADP-NUM-ADP': 0.0002771618625277162,
#  'NUM-VERB': 0.0002771618625277162,
#  'VERB-DET-NOUN-VERB-ADP-PROPN-PROPN': 0.0002771618625277162,
#  'ADP-NUM-ADP-DET': 0.0002771618625277162,
#  'ADP-DET-ADJ-NOUN-ADP-DET': 0.0002771618625277162,
#  'VERB-DET-NOUN-NOUN-ADP-DET-PROPN-NOUN-ADP': 0.0002771618625277162,
#  'VERB-DET-ADJ-ADJ-NOUN-ADP-DET': 0.0002771618625277162,
#  'VERB-ADV-ADP-DET': 0.0002771618625277162,
#  'VERB-DET-NUM-NOUN-NOUN-NOUN-CCONJ-DET-NOUN-ADP': 0.0002771618625277162,
#  'ADP-DET-NUM-NOUN': 0.0002771618625277162,
#  'VERB-VERB-ADP-NUM-ADP': 0.0002771618625277162,
#  'DET-ADJ': 0.0002771618625277162,
#  'CCONJ-DET-PROPN-ADP': 0.0002771618625277162,
#  'CCONJ-PROPN-ADP-ADJ': 0.0002771618625277162,
#  'PROPN-PROPN-NUM': 0.0002771618625277162,
#  'PART-ADJ-NOUN-NOUN-DET-PROPN-VERB-PRON-ADP-DET-ADJ-NOUN-NOUN-NOUN-ADP': 0.0002771618625277162,
#  'DET-NOUN-NOUN-ADP-DET': 0.0002771618625277162,
#  'CCONJ-DET-ADJ-NOUN-ADP-DET-NOUN-PROPN-ADP': 0.0002771618625277162,
#  'ADP-ADJ-ADJ': 0.0002771618625277162,
#  'PROPN-SYM': 0.0002771618625277162,
#  'ADP-ADJ-PROPN': 0.0002771618625277162,
#  'CCONJ-VERB-DET-ADV-VERB-NOUN-NOUN-NOUN-ADP': 0.0002771618625277162,
#  'VERB-VERB-ADP-DET-NOUN-ADP-ADJ-NOUN-CCONJ-ADP-DET-NOUN-NOUN-VERB-VERB-DET-ADJ-NOUN-ADP-NOUN-ADP': 0.0002771618625277162,
#  'NOUN-ADP-DET-NOUN': 0.0002771618625277162,
#  'PART-PROPN-CCONJ': 0.0002771618625277162,
#  'VERB-ADV-ADP': 0.0002771618625277162,
#  'VERB-DET-ADJ-NOUN-ADP-PROPN-CCONJ': 0.0002771618625277162,
#  'ADP-DET-NOUN-ADP-PROPN-CCONJ': 0.0002771618625277162,
#  'ADP-PROPN-ADP-ADJ': 0.0002771618625277162,
#  'ADP-PROPN-ADP-ADJ-PROPN': 0.0002771618625277162,
#  'VERB-ADJ-NOUN-ADP': 0.0002771618625277162,
#  'CCONJ-VERB-NOUN-ADP-DET': 0.0002771618625277162,
#  'VERB-CCONJ-VERB-DET-PROPN-ADJ-NOUN': 0.0002771618625277162,
#  'PROPN-VERB-ADV-ADP-PROPN-VERB-ADP': 0.0002771618625277162,
#  'VERB-ADV-VERB-ADP': 0.0002771618625277162,
#  'CCONJ-PROPN-NOUN-ADP-DET': 0.0002771618625277162,
#  'VERB-NUM-ADP-DET-ADV-ADJ-NOUN-ADP': 0.0002771618625277162,
#  'VERB-NOUN-ADP-DET-ADJ-NOUN-ADP-PROPN-ADP-PROPN-ADP': 0.0002771618625277162,
#  'ADP-NUM-NOUN-ADP-DET': 0.0002771618625277162,
#  'VERB-PROPN-ADP-PROPN-VERB-DET': 0.0002771618625277162,
#  'NOUN-ADP-DET-PROPN-ADP': 0.0002771618625277162,
#  'PART-NOUN-VERB-VERB': 0.0002771618625277162,
#  'VERB-DET-NOUN-NOUN': 0.0002771618625277162,
#  'NOUN-ADP-PROPN-ADP-DET-PROPN-CCONJ-PROPN-NOUN-ADP': 0.0002771618625277162,
#  'NOUN-ADP-PROPN-ADP-DET-PROPN-CCONJ-PROPN-NOUN-ADP-PROPN-ADP': 0.0002771618625277162,
#  'ADP-PROPN-PROPN-PROPN-CCONJ': 0.0002771618625277162,
#  'ADP-DET-VERB-ADP-DET-PROPN-CCONJ-PROPN-ADP-DET-ADJ': 0.0002771618625277162,
#  'VERB-VERB-PART-VERB': 0.0002771618625277162,
#  'NOUN-PRON-VERB-ADV-VERB-ADP-VERB-NUM-NOUN-ADP-DET-NUM-SYM-NUM-NOUN-ADP': 0.0002771618625277162,
#  'PRON-VERB-DET-NOUN-NOUN-ADP-DET-NOUN-ADP': 0.0002771618625277162,
#  'VERB-DET-PROPN-ADP-PROPN': 0.0002771618625277162,
#  'VERB-NOUN-NOUN-ADP-DET-VERB-DET-PROPN-ADP-PROPN': 0.0002771618625277162,
#  'ADJ-NOUN-NOUN-VERB-ADP-PROPN-PROPN': 0.0002771618625277162,
#  'VERB-DET-NUM-ADJ-NOUN-NOUN-NOUN-VERB-NOUN-VERB-VERB-CCONJ-VERB-ADP': 0.0002771618625277162,
#  'PROPN-ADP-DET-ADJ-ADJ-NOUN-ADP': 0.0002771618625277162,
#  'DET-NOUN-DET-ADJ-NOUN-VERB-VERB-ADP-DET-NOUN-ADP-PROPN-VERB-ADP-NOUN-ADP': 0.0002771618625277162,
#  'DET-NOUN-DET-ADJ-NOUN-VERB-VERB-ADP-DET-NOUN-ADP-PROPN-VERB-ADP-NOUN-ADP-PROPN-ADP': 0.0002771618625277162,
#  'VERB-VERB-PART-ADP': 0.0002771618625277162,
#  'ADV-ADP-DET-NOUN-NOUN-ADP': 0.0002771618625277162,
#  'ADV-VERB-ADP-PROPN-CCONJ-VERB': 0.0002771618625277162,
#  'NUM-SYM-NUM-CCONJ-PROPN-PROPN-NUM-SYM-NUM-VERB-ADP-NOUN-ADP-DET-PROPN-CCONJ-DET-NOUN-ADP': 0.0002771618625277162,
#  'NUM-SYM-NUM-VERB-ADP-NOUN-ADP-DET-PROPN-CCONJ-DET-NOUN-ADP': 0.0002771618625277162,
#  'VERB-VERB-ADP-DET-NOUN-PART-ADJ-NOUN-ADP': 0.0002771618625277162,
#  'PRON-VERB-VERB-ADP-DET': 0.0002771618625277162,
#  'VERB-NUM-SYM': 0.0002771618625277162,
#  'VERB-DET-ADJ-ADJ-NOUN-NOUN-ADP': 0.0002771618625277162,
#  'NOUN-PRON-VERB-PROPN-PROPN-ADP-PROPN-ADP-NUM-ADP-NUM-CCONJ-VERB-DET-ADJ-PROPN-ADP-PROPN-DET-ADJ-NOUN-ADP': 0.0002771618625277162,
#  'ADP-NUM-ADP-NUM-CCONJ-VERB-DET-ADJ-PROPN-ADP-PROPN-DET-ADJ-NOUN-ADP': 0.0002771618625277162,
#  'VERB-VERB-NUM-VERB-DET': 0.0002771618625277162,
#  'PROPN-NUM-NOUN-NOUN': 0.0002771618625277162,
#  'VERB-ADP-DET-ADJ-ADJ-NOUN-ADP': 0.0002771618625277162,
#  'ADP-DET-PROPN': 0.0002771618625277162,
#  'ADP-DET-PROPN-NOUN-NOUN': 0.0002771618625277162,
#  'PROPN-ADP-PROPN-PROPN': 0.0002771618625277162,
#  'NOUN-ADJ': 0.0002771618625277162,
#  'DET-VERB': 0.0002771618625277162,
#  'ADP-DET-PROPN-ADP-DET-NOUN-ADP': 0.0002771618625277162,
#  'DET-NOUN-CCONJ-ADJ-NOUN-ADP-DET': 0.0002771618625277162,
#  'VERB-ADP-DET-ADJ-NOUN-ADP-DET-ADJ-NOUN-NOUN': 0.0002771618625277162,
#  'NOUN-NOUN-NOUN-ADP-PROPN': 0.0002771618625277162,
#  'VERB-NUM-ADP-DET-ADV-ADJ-NOUN-ADP-PROPN-ADP-NUM-ADP-DET-ADJ-NOUN-VERB-ADP-DET-ADJ-ADJ-NOUN-ADV-ADP-PROPN': 0.0002771618625277162,
#  'ADV-ADP-DET-NOUN-ADP': 0.0002771618625277162,
#  'VERB-DET-NOUN-VERB-ADP-PROPN': 0.0002771618625277162,
#  'CCONJ-ADJ-PROPN': 0.0002771618625277162,
#  'VERB-DET-NOUN-NOUN-ADP-ADJ-NOUN': 0.0002771618625277162,
#  'NOUN-VERB-PROPN-PROPN-CCONJ': 0.0002771618625277162,
#  'PROPN-CCONJ-NOUN-ADP': 0.0002771618625277162,
#  'CCONJ-PROPN-VERB-VERB-DET-ADJ-NOUN': 0.0002771618625277162,
#  'ADP-DET-NOUN-NOUN-NOUN-ADP-DET-PROPN': 0.0002771618625277162,
#  'ADP-PROPN-NOUN-ADP-ADJ': 0.0002771618625277162,
#  'ADP-PROPN-NOUN-ADP-ADJ-PROPN-CCONJ-NOUN-ADP': 0.0002771618625277162,
#  'ADP-PROPN-NOUN-ADP-ADJ-PROPN-CCONJ-NOUN-ADP-PROPN-CCONJ-ADJ': 0.0002771618625277162,
#  'PROPN-ADP-DET-PROPN-PROPN-ADP': 0.0002771618625277162,
#  'DET-ADJ-NOUN-ADP-NOUN-NOUN-VERB': 0.0002771618625277162,
#  'DET-ADJ-NOUN-ADP-NOUN-NOUN-VERB-PROPN': 0.0002771618625277162,
#  'DET-ADJ-NOUN-ADP-NOUN-NOUN-VERB-PROPN-PROPN-CCONJ': 0.0002771618625277162,
#  'DET-ADJ-NOUN-ADP-NOUN-NOUN-VERB-PROPN-PROPN-CCONJ-PROPN-ADP-NOUN-VERB-VERB-ADV-ADP-ADJ-NOUN-ADP': 0.0002771618625277162,
#  'ADJ-NOUN-VERB-DET-NUM-NOUN-ADP-DET-ADJ-NOUN-CCONJ-NOUN': 0.0002771618625277162,
#  'ADV-VERB-NUM-ADP': 0.0002771618625277162,
#  'ADV-VERB-NUM-ADP-PROPN-CCONJ': 0.0002771618625277162,
#  'VERB-DET-ADJ-NOUN-DET-VERB-ADJ-ADP-DET-NOUN-ADP': 0.0002771618625277162,
#  'PROPN-VERB-DET-NOUN-ADP-DET-NOUN-ADP-DET-PROPN-ADP-PROPN-PROPN': 0.0002771618625277162,
#  'ADV-PRON-VERB-ADP-PROPN-CCONJ-DET-ADJ-NOUN-ADP': 0.0002771618625277162,
#  'VERB-VERB-ADP-DET-PROPN-CCONJ-DET-PROPN-NOUN-ADP-ADV-ADV-ADP-PROPN': 0.0002771618625277162,
#  'PART-NOUN-VERB': 0.0002771618625277162,
#  'NOUN-VERB-DET-ADJ-NOUN-NOUN-ADP-DET-ADJ-NOUN-ADP-PROPN-ADP-ADJ-PROPN': 0.0002771618625277162,
#  'ADP-ADJ-NOUN-ADP-DET': 0.0002771618625277162,
#  'CCONJ-ADV-ADP': 0.0002771618625277162,
#  'NOUN-PRON-ADP-DET-NOUN-PROPN-VERB-ADJ-NOUN-CCONJ-NOUN-NOUN-ADP': 0.0002771618625277162,
#  'VERB-DET-ADJ-NOUN-ADP-DET-ADJ-NOUN-ADP-DET-ADJ-NOUN-NOUN-NOUN-NOUN': 0.0002771618625277162,
#  'PROPN-CCONJ-PROPN-CCONJ-VERB-ADV-DET-NOUN-CCONJ-NOUN-PART-VERB-PROPN-ADP-DET-NOUN-NOUN-ADP-DET-PROPN-ADP': 0.0002771618625277162,
#  'VERB-DET-PROPN-ADP-NOUN': 0.0002771618625277162,
#  'DET-ADJ-NOUN-ADP-PROPN-CCONJ-DET-ADJ-NOUN-ADP-DET-ADJ-NOUN-ADP-PROPN-DET-ADP': 0.0002771618625277162,
#  'NOUN-ADV-VERB-ADP': 0.0002771618625277162,
#  'ADP-NOUN-PROPN': 0.0002771618625277162,
#  'NOUN-NOUN-NOUN-VERB-ADP': 0.0002771618625277162,
#  'NUM-SYM-NUM-NUM-SYM-NUM-PROPN-PROPN-ADP-DET-PROPN-NUM-NOUN-NUM-ADP': 0.0002771618625277162,
#  'VERB-DET-PROPN-VERB': 0.0002771618625277162,
#  'ADP-DET-ADJ-NOUN-ADP-PROPN-ADP-DET': 0.0002771618625277162,
#  'PART-NOUN-ADP-DET-NOUN-ADP-PROPN': 0.0002771618625277162,
#  'NOUN-ADP-DET-PROPN-PRON-VERB-ADJ-ADP-ADJ-NOUN-ADP-PROPN': 0.0002771618625277162,
#  'VERB-ADP-DET-ADJ-NOUN-ADP-DET-NOUN-ADP-PROPN-DET-PROPN-PROPN-PROPN-CCONJ': 0.0002771618625277162,
#  'VERB-ADP-DET-ADJ-NOUN-ADP-DET-NOUN-ADP-PROPN-DET-PROPN': 0.0002771618625277162,
#  'VERB-ADP-DET-ADJ-NOUN-ADP-DET-NOUN-ADP-PROPN-DET-PROPN-PROPN': 0.00018477457501847746,
#  'ADP-NOUN-ADP-PROPN': 0.00018477457501847746,
#  'ADP-NUM-VERB-VERB-ADP-DET': 0.00018477457501847746,
#  'VERB-VERB-ADV-ADP-DET-NOUN-ADP-PROPN-CCONJ': 0.00018477457501847746,
#  'VERB-VERB-DET-NOUN-ADP-DET': 0.00018477457501847746,
#  'DET-VERB-VERB-DET-PROPN-VERB-VERB-VERB-ADP': 0.00018477457501847746,
#  'VERB-DET-NOUN-ADP-NUM-NOUN-NOUN-ADJ-ADP-DET-NOUN-ADP': 0.00018477457501847746,
#  'ADJ-NOUN-SYM-NOUN-NOUN-NOUN-ADP-PROPN': 0.00018477457501847746,
#  'VERB-DET-NOUN-NOUN-NOUN-NOUN-NOUN-ADP-DET-PROPN-PROPN-PROPN-PROPN-CCONJ-PROPN-VERB-CCONJ-VERB-ADP': 0.00018477457501847746,
#  'NOUN-PROPN-CCONJ-VERB-ADP-PROPN-PART-NOUN': 0.00018477457501847746,
#  'PART-NOUN-ADP-ADJ': 0.00018477457501847746,
#  'VERB-ADV-VERB-ADP-DET': 0.00018477457501847746,
#  'PART-ADV-ADJ-NOUN-CCONJ-VERB-PROPN-PART-PROPN-PROPN-PROPN': 0.00018477457501847746,
#  'PART-ADV-ADJ-NOUN-CCONJ-VERB-PROPN-PART-PROPN-PROPN-PROPN-PROPN-PROPN-PROPN-PROPN-PROPN-PROPN-PROPN-PROPN-PROPN-CCONJ-PROPN-PROPN-PROPN': 0.00018477457501847746,
#  'NOUN-DET-ADV-VERB-NOUN-NOUN-ADP-ADJ-ADJ-NOUN-NOUN-ADP-PROPN-ADP': 0.00018477457501847746,
#  'PROPN-PROPN-PROPN-VERB-DET-ADJ-NOUN-CCONJ-NOUN-ADP-ADJ-NOUN-NOUN-ADV-VERB-ADP-DET-NOUN-ADP-VERB-DET': 0.00018477457501847746,
#  'CCONJ-ADJ-PROPN-ADP': 0.00018477457501847746,
#  'NOUN-VERB-ADP-PROPN': 0.00018477457501847746,
#  'CCONJ-PROPN-VERB-ADP-DET-NOUN-NOUN-ADP-DET-NOUN': 0.00018477457501847746,
#  'VERB-ADP-DET-NOUN-NOUN-ADP-DET-NOUN': 0.00018477457501847746,
#  'ADP-ADP-PROPN-ADP-DET': 0.00018477457501847746,
#  'ADP-ADP-PROPN-ADP-DET-PROPN-NOUN-ADP-DET-ADJ-NOUN-ADP-PROPN-CCONJ-ADP-DET-NOUN-ADP-PROPN-ADP': 0.00018477457501847746,
#  'ADP-DET-PROPN-NOUN-ADP-DET-NOUN-ADP': 0.00018477457501847746,
#  'ADJ-NOUN-NOUN-ADP-PROPN': 0.00018477457501847746,
#  'CCONJ-ADJ-ADP': 0.00018477457501847746,
#  'VERB-NOUN-VERB-NOUN-ADP-DET-NOUN-ADP': 0.00018477457501847746,
#  'CCONJ-PROPN-VERB-DET-ADJ-PROPN-NOUN-CCONJ-ADP-NUM-DET-NOUN-VERB-VERB-ADV-ADP': 0.00018477457501847746,
#  'VERB-DET-ADJ-PROPN-NOUN-CCONJ-ADP-NUM-DET-NOUN-VERB-VERB-ADV-ADP': 0.00018477457501847746,
#  'CCONJ-PROPN-ADP-DET-NOUN-ADP': 0.00018477457501847746,
#  'CCONJ-PROPN-ADP-DET-NOUN-ADP-PROPN-ADP-DET': 0.00018477457501847746,
#  'ADP-DET-NOUN-ADP-PROPN-ADP-DET': 0.00018477457501847746,
#  'ADV-DET-PROPN-VERB-ADV-CCONJ-ADV-DET-PROPN-ADP-PROPN-ADP-DET-NOUN-ADP-PROPN-ADP': 0.00018477457501847746,
#  'PROPN-CCONJ-PROPN': 0.00018477457501847746,
#  'NOUN-NOUN-CCONJ-NOUN-ADP-PROPN': 0.00018477457501847746,
#  'VERB-DET-NUM-NOUN-NOUN-VERB-ADP': 0.00018477457501847746,
#  'PART-PROPN-NUM-CCONJ': 0.00018477457501847746,
#  'PRON-VERB-VERB-VERB-ADP-DET-NOUN-ADP-NOUN-PROPN-PART-PROPN-NUM-CCONJ-DET-NUM-VERB-ADJ-PART-VERB': 0.00018477457501847746,
#  'ADV-NUM-ADV-ADP-PROPN-DET-NOUN-ADP': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-ADP-ADJ-NOUN-NOUN': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-ADP-ADJ-NOUN-NOUN-PROPN-VERB-ADP': 0.00018477457501847746,
#  'VERB-DET-NOUN-ADP-NOUN-ADP-DET': 0.00018477457501847746,
#  'VERB-DET-NOUN-ADP-DET-PROPN': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-VERB-ADP-DET': 0.00018477457501847746,
#  'VERB-DET-NOUN-ADP-ADJ-NOUN-CCONJ-ADJ-NOUN-PROPN-ADP-PROPN-ADJ-ADJ': 0.00018477457501847746,
#  'VERB-VERB-ADP-NUM-ADP-DET-NOUN-ADV-DET-NOUN-VERB-VERB-ADP-ADP-DET-NOUN': 0.00018477457501847746,
#  'VERB-VERB-ADP-NUM-ADP-DET-NOUN-ADV-DET-NOUN-VERB-VERB-ADP-ADP-DET-NOUN-PROPN-CCONJ-DET-NOUN': 0.00018477457501847746,
#  'ADP-PROPN-PROPN-PROPN': 0.00018477457501847746,
#  'CCONJ-DET-NOUN-ADP-DET': 0.00018477457501847746,
#  'PROPN-DET-VERB-NOUN-ADP-DET': 0.00018477457501847746,
#  'PROPN-PROPN-PROPN-VERB-DET-NOUN-ADP-PROPN-NOUN': 0.00018477457501847746,
#  'VERB-ADP-PROPN-PROPN-CCONJ': 0.00018477457501847746,
#  'CCONJ-ADV-DET-NOUN-PROPN-VERB-ADP': 0.00018477457501847746,
#  'PROPN-VERB-DET-NOUN-ADP': 0.00018477457501847746,
#  'NOUN-DET-CCONJ-PROPN-ADP-PROPN-VERB-DET-NOUN-NOUN-VERB-CCONJ-VERB-ADP': 0.00018477457501847746,
#  'PROPN-DET-NOUN-PART-VERB-NOUN-DET-NOUN-ADP-NOUN-VERB-NOUN-PROPN-VERB-DET-NOUN-ADP-DET': 0.00018477457501847746,
#  'VERB-DET-NUM-NOUN-ADP-DET-PROPN-ADP': 0.00018477457501847746,
#  'VERB-ADJ-ADP': 0.00018477457501847746,
#  'ADJ-ADP': 0.00018477457501847746,
#  'VERB-VERB-ADP-PROPN-DET-NOUN-ADP-DET-ADJ-NOUN': 0.00018477457501847746,
#  'ADJ-NOUN-ADP-ADP-DET-PROPN-ADP-NUM-DET-VERB-PROPN-NOUN': 0.00018477457501847746,
#  'NUM-PROPN-NUM-VERB-DET-ADJ-NOUN-CCONJ-NOUN-DET-ADJ-NOUN-ADP-DET-ADV-VERB': 0.00018477457501847746,
#  'NUM-PROPN-NUM-PROPN-VERB-DET': 0.00018477457501847746,
#  'DET-NOUN-CCONJ-NOUN-ADP': 0.00018477457501847746,
#  'CCONJ-NUM-NOUN': 0.00018477457501847746,
#  'PART-ADJ-NOUN-ADP-DET-PROPN-PROPN-PROPN-CCONJ-NUM-NOUN': 0.00018477457501847746,
#  'PROPN-CCONJ-NUM-NOUN': 0.00018477457501847746,
#  'ADP-PROPN-CCONJ-PROPN-NOUN-ADP': 0.00018477457501847746,
#  'VERB-ADP-DET-PROPN-ADP': 0.00018477457501847746,
#  'VERB-VERB-ADP-DET-ADJ-NOUN-DET-NOUN-ADP-DET-ADJ-PROPN-NOUN': 0.00018477457501847746,
#  'VERB-VERB-ADP-DET-ADJ-NOUN-DET-NOUN-ADP-DET-ADJ-PROPN-NOUN-PROPN-CCONJ': 0.00018477457501847746,
#  'VERB-DET-NOUN-ADP-DET-ADJ-PROPN-PROPN': 0.00018477457501847746,
#  'VERB-VERB-ADP-PROPN-CCONJ-VERB-ADJ-ADP-PROPN-NOUN': 0.00018477457501847746,
#  'VERB-VERB-PROPN-VERB-DET': 0.00018477457501847746,
#  'VERB-DET-NOUN-ADP-NOUN-NOUN-NOUN-NOUN-NOUN-DET-VERB-ADP-DET-ADJ-PROPN-PROPN-NOUN-VERB-ADP-DET-ADP-DET-PROPN-NOUN-NOUN-ADP': 0.00018477457501847746,
#  'CCONJ-DET-NUM-NOUN-PROPN-PROPN-PROPN-CCONJ': 0.00018477457501847746,
#  'CCONJ-DET-NOUN-VERB-ADP': 0.00018477457501847746,
#  'CCONJ-PROPN-PRON-VERB-ADV-VERB-DET-ADJ-NOUN': 0.00018477457501847746,
#  'PROPN-CCONJ-ADJ-NOUN-NOUN-ADP': 0.00018477457501847746,
#  'PROPN-PROPN-CCONJ-ADJ-NOUN-NOUN-ADP': 0.00018477457501847746,
#  'ADP-DET-NOUN-ADP-DET-PROPN-ADP': 0.00018477457501847746,
#  'VERB-NOUN-ADP-PROPN-NOUN-NOUN-ADP-NOUN-CCONJ-NOUN-CCONJ-ADJ-ADJ-NOUN-ADP': 0.00018477457501847746,
#  'NOUN-ADP-PROPN-ADP-DET-NOUN-ADP': 0.00018477457501847746,
#  'VERB-DET-PROPN-ADP': 0.00018477457501847746,
#  'PROPN-PROPN-PROPN-VERB-DET-ADJ-NOUN-NOUN-ADV-VERB-ADP': 0.00018477457501847746,
#  'VERB-DET-NOUN-PROPN-NOUN-ADP-PROPN-ADP-DET-PROPN-NOUN-ADP-ADJ': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-ADP-DET-NOUN-CCONJ-NOUN': 0.00018477457501847746,
#  'VERB-ADP-DET-NOUN': 0.00018477457501847746,
#  'ADP-DET-ADJ-NOUN-ADP-PROPN-ADP-DET-NOUN-ADP-PROPN-ADP': 0.00018477457501847746,
#  'ADP-DET-PROPN-CCONJ-ADP': 0.00018477457501847746,
#  'CCONJ-PROPN-CCONJ-ADJ-NOUN-ADP': 0.00018477457501847746,
#  'ADV-VERB-ADP-PROPN-VERB-DET': 0.00018477457501847746,
#  'VERB-ADJ-NOUN-ADV-DET-NOUN-PROPN-CCONJ-PROPN-ADP-DET-PROPN-ADP-DET-NOUN-CCONJ-NOUN-NOUN-PROPN-DET': 0.00018477457501847746,
#  'VERB-ADJ-NOUN-ADV-DET-NOUN-PROPN-CCONJ-PROPN-ADP-DET-PROPN-ADP-DET-NOUN-CCONJ-NOUN-NOUN': 0.00018477457501847746,
#  'NOUN-ADP-PROPN-ADP-PROPN': 0.00018477457501847746,
#  'VERB-VERB-ADP-PROPN-CCONJ-VERB-NOUN-ADP-DET': 0.00018477457501847746,
#  'PROPN-ADP-NUM': 0.00018477457501847746,
#  'PROPN-PROPN-DET-VERB-VERB-ADP': 0.00018477457501847746,
#  'VERB-NUM-VERB-DET-ADJ': 0.00018477457501847746,
#  'ADJ-NOUN-NOUN-VERB-ADP-PROPN': 0.00018477457501847746,
#  'ADP-PROPN-NOUN': 0.00018477457501847746,
#  'ADP-ADP-DET': 0.00018477457501847746,
#  'VERB-DET-NOUN-ADP-DET-PROPN-NOUN-ADP-DET': 0.00018477457501847746,
#  'VERB-DET-NUM-ADJ-NOUN-NOUN-VERB-ADP-PROPN-CCONJ-VERB-ADP': 0.00018477457501847746,
#  'ADP-PROPN-NOUN-ADP': 0.00018477457501847746,
#  'NUM-SYM-NUM-VERB-DET-PROPN-ADP-PROPN-NUM-ADP-DET-PROPN-ADP-PROPN-NOUN-ADP': 0.00018477457501847746,
#  'PROPN-VERB-DET-ADJ-NOUN-ADP-PROPN': 0.00018477457501847746,
#  'VERB-DET-PROPN-NOUN-ADP-ADJ-PROPN-VERB-DET-NOUN-ADP-PROPN': 0.00018477457501847746,
#  'VERB-DET-PROPN-NOUN-ADP-ADJ-PROPN-VERB-DET-NOUN-ADP-PROPN-PROPN-PROPN-PROPN': 0.00018477457501847746,
#  'ADP-ADJ-PROPN-PROPN': 0.00018477457501847746,
#  'NOUN-ADP-ADJ-NOUN-NOUN': 0.00018477457501847746,
#  'PROPN-PROPN-DET-ADP-DET-NOUN-ADP': 0.00018477457501847746,
#  'PROPN-DET-ADP-DET-NOUN-ADP': 0.00018477457501847746,
#  'PROPN-PROPN-PROPN-PROPN-DET-ADP-DET-NOUN-ADP': 0.00018477457501847746,
#  'PROPN-PROPN-PROPN-DET-ADP-DET-NOUN-ADP': 0.00018477457501847746,
#  'DET-ADP-DET-NOUN-ADP': 0.00018477457501847746,
#  'CCONJ-PROPN-DET-NUM-ADJ-NOUN-ADP-DET': 0.00018477457501847746,
#  'DET-NUM-ADJ-NOUN-ADP-DET': 0.00018477457501847746,
#  'ADP-DET-NOUN-ADP-DET-NOUN-ADP': 0.00018477457501847746,
#  'VERB-ADJ-ADP-CCONJ-VERB-ADP': 0.00018477457501847746,
#  'DET-NOUN-ADP-ADJ': 0.00018477457501847746,
#  'PROPN-PROPN-PROPN-PROPN-VERB-DET': 0.00018477457501847746,
#  'VERB-DET-NUM-ADJ-ADJ-NOUN-NOUN-VERB-ADP': 0.00018477457501847746,
#  'VERB-DET-NUM-PROPN-PROPN-NOUN-ADJ-NOUN-NOUN-VERB-CCONJ-VERB-ADP': 0.00018477457501847746,
#  'PART-NOUN-PART-VERB-VERB-NOUN-ADP-DET-ADV-NOUN-ADJ-NOUN-VERB-NOUN': 0.00018477457501847746,
#  'NOUN-NUM-VERB-DET-ADJ-NOUN-ADP-DET-ADJ-NOUN': 0.00018477457501847746,
#  'NOUN-NUM-VERB-DET-ADJ-NOUN-ADP-DET-ADJ-NOUN-PROPN-CCONJ-DET-NOUN': 0.00018477457501847746,
#  'ADV-VERB-ADP-DET-PROPN-ADP-DET-PROPN-ADP-PROPN-CCONJ-ADP-DET-ADP-PROPN-ADP-NUM-ADP-DET-NOUN-ADP': 0.00018477457501847746,
#  'PRON-VERB-VERB-DET': 0.00018477457501847746,
#  'VERB-DET-NOUN-NOUN-ADP-DET-NOUN-ADP-DET-NOUN-ADP-DET-NOUN-VERB-DET-ADP-DET-NOUN-NOUN-ADP-DET-ADJ-NOUN-NOUN': 0.00018477457501847746,
#  'VERB-ADP-DET-NOUN-ADP-DET-PROPN-CCONJ-ADP-DET-NOUN': 0.00018477457501847746,
#  'CCONJ-DET-ADJ-NOUN-ADP-DET-NOUN': 0.00018477457501847746,
#  'VERB-DET-NOUN-ADP-PROPN-VERB-ADP': 0.00018477457501847746,
#  'VERB-DET-NOUN-ADP-PROPN-VERB-ADP-PROPN-ADP': 0.00018477457501847746,
#  'NOUN-NOUN-CCONJ-NOUN-NOUN-VERB-DET-NUM-NOUN-ADP-PROPN-CCONJ-VERB-VERB-ADP-DET-NOUN-ADP-DET-NOUN-CCONJ-ADJ-NOUN-NOUN-PROPN-CCONJ': 0.00018477457501847746,
#  'PROPN-ADP-PROPN-CCONJ-ADV-ADV-PROPN-ADP': 0.00018477457501847746,
#  'NOUN-ADP-PROPN-NOUN': 0.00018477457501847746,
#  'VERB-DET-NOUN-VERB-ADP-ADJ-NOUN-NOUN': 0.00018477457501847746,
#  'ADP-NUM-CCONJ-VERB-VERB-ADP': 0.00018477457501847746,
#  'VERB-PROPN-ADP-PROPN-CCONJ': 0.00018477457501847746,
#  'VERB-DET-NOUN-ADP-NOUN-PROPN': 0.00018477457501847746,
#  'DET-DET-ADJ-NOUN-ADP-PROPN-ADV-DET-NOUN-VERB-VERB-ADP-NUM-ADP-DET-NOUN-PROPN': 0.00018477457501847746,
#  'DET-VERB-VERB-CCONJ-VERB-ADV-ADP': 0.00018477457501847746,
#  'ADV-VERB-PROPN': 0.00018477457501847746,
#  'VERB-DET-NOUN-ADP-DET-PROPN-ADP-PROPN-PROPN': 0.00018477457501847746,
#  'NOUN-ADP-PROPN-ADP-PROPN-ADP': 0.00018477457501847746,
#  'ADP-DET-NOUN-ADP-DET-PROPN-ADP-PROPN-PROPN': 0.00018477457501847746,
#  'DET-NOUN-NOUN-ADP-DET-NOUN-PART-NOUN': 0.00018477457501847746,
#  'ADP-PROPN-VERB-VERB-ADP-DET-ADJ-NOUN-ADP-DET-ADJ-NOUN-ADP-DET-PROPN-ADP-PROPN-ADP': 0.00018477457501847746,
#  'VERB-VERB-ADP-PROPN-ADP-DET-ADJ-NOUN-ADP-DET-VERB': 0.00018477457501847746,
#  'DET-PROPN-VERB-DET-NOUN-NOUN-PART-VERB-NOUN-VERB-PROPN-VERB-DET-ADJ-NOUN-ADP': 0.00018477457501847746,
#  'DET-PROPN-VERB-DET-NOUN-NOUN-PART-VERB-NOUN-VERB-PROPN-VERB-DET-ADJ-NOUN-ADP-ADJ-ADJ-NOUN-CCONJ-ADV-VERB': 0.00018477457501847746,
#  'VERB-DET-NOUN-DET-VERB-DET-ADJ-NOUN-ADP-DET-ADJ-NOUN-ADP-DET-NOUN-ADP': 0.00018477457501847746,
#  'PROPN-ADP-DET-ADJ-NOUN-ADP-DET': 0.00018477457501847746,
#  'NOUN-NOUN-VERB-VERB-ADP-DET-PROPN-NOUN-ADP': 0.00018477457501847746,
#  'NOUN-NOUN-VERB-VERB-ADP-DET-PROPN-NOUN-ADP-PROPN': 0.00018477457501847746,
#  'NUM-ADP-PROPN-NUM-VERB-DET-NOUN-ADP': 0.00018477457501847746,
#  'ADP-DET-PROPN-ADP-DET': 0.00018477457501847746,
#  'PART-ADJ-NOUN-ADJ-ADP-DET-ADJ-ADJ-NOUN': 0.00018477457501847746,
#  'NUM-CCONJ-ADV-ADP-DET-NUM-ADJ-NOUN-NOUN': 0.00018477457501847746,
#  'ADP-DET-NOUN-ADP-PROPN-PROPN': 0.00018477457501847746,
#  'DET-NOUN-NOUN-NOUN-ADP': 0.00018477457501847746,
#  'PRON-VERB-VERB-ADP-PROPN-PROPN-PROPN-PROPN-PROPN-PROPN-CCONJ-ADP': 0.00018477457501847746,
#  'PRON-VERB-ADP-DET-PROPN': 0.00018477457501847746,
#  'VERB-DET-NOUN-ADP-PROPN-PROPN-PROPN': 0.00018477457501847746,
#  'VERB-DET-NOUN-NOUN-ADP-PROPN-PROPN': 0.00018477457501847746,
#  'NOUN-VERB-DET-PROPN-PART-PROPN-PART-NOUN-ADP-NOUN-ADP': 0.00018477457501847746,
#  'VERB-DET-NOUN-ADP-NOUN-ADP': 0.00018477457501847746,
#  'ADP-PRON-VERB-ADV-ADJ-ADV-ADP-DET-NOUN-ADP': 0.00018477457501847746,
#  'PROPN-ADJ-NOUN': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-NOUN-ADP-PROPN': 0.00018477457501847746,
#  'PROPN-PROPN-VERB-NOUN': 0.00018477457501847746,
#  'NOUN-VERB-PROPN-PROPN-PROPN-PROPN-CCONJ': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-ADP-DET-PROPN-NOUN-ADP': 0.00018477457501847746,
#  'ADP-DET-PROPN-PART-VERB-DET-NOUN-VERB-ADP-DET-NOUN-ADP': 0.00018477457501847746,
#  'ADP-PROPN-ADP-DET-NOUN': 0.00018477457501847746,
#  'VERB-NOUN-ADP-DET-PROPN-ADP-DET-PROPN-CCONJ-DET-NOUN': 0.00018477457501847746,
#  'VERB-NUM-ADP-PROPN-PROPN-VERB': 0.00018477457501847746,
#  'ADP-PROPN-PROPN-ADP': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-ADP-DET-PROPN-NOUN': 0.00018477457501847746,
#  'ADP-NUM-DET-NOUN-ADP-PROPN-ADP-DET-PROPN-VERB-ADP-DET-NOUN': 0.00018477457501847746,
#  'VERB-DET-NOUN-ADP-PROPN-ADP-NOUN-ADP-DET-NOUN-PART-NOUN': 0.00018477457501847746,
#  'VERB-NOUN-ADP-NUM-NOUN-ADP-NOUN': 0.00018477457501847746,
#  'NOUN-NOUN-NOUN-NOUN-DET-NOUN-ADP-VERB-NOUN-NOUN-ADP': 0.00018477457501847746,
#  'NOUN-DET-ADV-VERB-ADP': 0.00018477457501847746,
#  'NOUN-DET-ADV-VERB-ADP-PROPN-VERB-VERB-ADP-DET': 0.00018477457501847746,
#  'PRON-ADV-VERB-DET-ADJ-PROPN-ADP-DET': 0.00018477457501847746,
#  'NOUN-PRON-VERB-NUM-ADP-DET-ADJ-NOUN-ADP-PROPN-NOUN-PROPN-NOUN-ADP': 0.00018477457501847746,
#  'NOUN-NOUN-NOUN-NOUN': 0.00018477457501847746,
#  'VERB-VERB-ADP-PROPN-PROPN-ADP': 0.00018477457501847746,
#  'ADP-PRON-VERB-ADV-VERB-VERB-DET': 0.00018477457501847746,
#  'VERB-ADP-ADJ-NOUN-ADP': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-ADP-DET-NOUN': 0.00018477457501847746,
#  'PROPN-PROPN-VERB': 0.00018477457501847746,
#  'ADP-NUM-CCONJ': 0.00018477457501847746,
#  'DET-ADJ-NOUN-NOUN-ADP': 0.00018477457501847746,
#  'NUM-SYM-NUM-CCONJ-PROPN-PROPN-NUM-SYM-NUM-CCONJ-DET-NOUN-PROPN': 0.00018477457501847746,
#  'NUM-SYM-NUM-CCONJ-PROPN': 0.00018477457501847746,
#  'PART-NUM-NOUN-NOUN': 0.00018477457501847746,
#  'ADP-ADJ-ADJ-PROPN-ADP': 0.00018477457501847746,
#  'VERB-PROPN-ADJ-ADP': 0.00018477457501847746,
#  'VERB-DET-NOUN-ADP-DET-ADJ-NOUN-DET-VERB-DET-PROPN-NOUN-ADP-DET-PROPN-NUM-DET-VERB-ADP-NOUN-ADP-DET': 0.00018477457501847746,
#  'VERB-DET-NOUN-VERB-ADP-DET-PROPN-NOUN-ADP': 0.00018477457501847746,
#  'PART-NOUN-VERB-NOUN': 0.00018477457501847746,
#  'DET-VERB-VERB-ADP-DET': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-ADJ-NOUN-ADJ-NOUN-NOUN-VERB-CCONJ-VERB-ADP': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-ADJ-NOUN-NOUN-DET-VERB-NOUN-ADP-ADJ-ADJ-VERB-ADP-ADJ-NOUN-ADP-PROPN-ADP-PROPN': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-ADJ-NOUN-NOUN-DET-VERB-NOUN-ADP-ADJ-ADJ-VERB-ADP-ADJ-NOUN-ADP-PROPN-ADP-PROPN-PROPN': 0.00018477457501847746,
#  'PRON-VERB-ADV-NUM-ADP-DET-ADJ-ADJ': 0.00018477457501847746,
#  'NOUN-ADP-PROPN-VERB-ADP-PROPN-CCONJ': 0.00018477457501847746,
#  'PART-ADJ-NOUN-ADP-DET-NOUN-ADP-PROPN-ADP-PRON-VERB': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-NOUN-NOUN-VERB-ADP': 0.00018477457501847746,
#  'VERB-ADP-PROPN-ADJ-ADJ-NOUN-PROPN-CCONJ-ADJ-ADJ-NOUN-ADP': 0.00018477457501847746,
#  'NOUN-ADV': 0.00018477457501847746,
#  'NOUN-ADV-PROPN': 0.00018477457501847746,
#  'DET-PROPN-VERB-VERB-ADP-DET-NOUN-ADP-DET-NOUN-VERB-PART-ADP-PROPN-ADP-NOUN-ADP-NOUN-ADP-DET': 0.00018477457501847746,
#  'VERB-VERB-ADP-NUM-ADP-PROPN-ADP-PROPN-ADV-ADP-DET-NOUN-NOUN-CCONJ': 0.00018477457501847746,
#  'VERB-VERB-ADP-PROPN-ADP-PROPN': 0.00018477457501847746,
#  'DET-PROPN-VERB': 0.00018477457501847746,
#  'NOUN-NOUN-ADJ-ADP': 0.00018477457501847746,
#  'NOUN-NOUN-ADJ-ADP-PROPN-CCONJ': 0.00018477457501847746,
#  'ADV-VERB-ADP-PROPN': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-ADP-PROPN-VERB-ADP': 0.00018477457501847746,
#  'VERB-NUM-VERB-DET-NOUN-ADP-ADJ-ADJ-NOUN-NOUN': 0.00018477457501847746,
#  'CCONJ-PROPN-VERB-ADP-DET-NOUN-ADP-NOUN-DET-ADJ-NOUN-VERB-NOUN': 0.00018477457501847746,
#  'CCONJ-PROPN-VERB-ADP-DET-NOUN-ADP-NOUN-DET-ADJ-NOUN-VERB-NOUN-PROPN-DET-NOUN-ADP-DET-NOUN-CCONJ-NOUN-ADP-PROPN-CCONJ-DET-NOUN': 0.00018477457501847746,
#  'DET-NOUN-ADP-DET-NOUN-CCONJ-NOUN-ADP-PROPN-CCONJ-DET-NOUN': 0.00018477457501847746,
#  'VERB-ADP-DET-NOUN-ADP-NOUN-DET-ADJ-NOUN-VERB-NOUN': 0.00018477457501847746,
#  'VERB-ADP-DET-NOUN-ADP-NOUN-DET-ADJ-NOUN-VERB-NOUN-PROPN-DET-NOUN-ADP-DET-NOUN-CCONJ-NOUN-ADP-PROPN-CCONJ-DET-NOUN': 0.00018477457501847746,
#  'CCONJ-ADP-PROPN-ADP': 0.00018477457501847746,
#  'VERB-DET-NOUN-ADP-DET-VERB-NOUN': 0.00018477457501847746,
#  'VERB-VERB-ADV-CCONJ-PRON-VERB-DET-NOUN-ADP-DET-PROPN-PROPN': 0.00018477457501847746,
#  'CCONJ-PROPN-VERB-VERB-ADV-CCONJ-PRON-VERB-DET-NOUN-ADP-DET-PROPN-PROPN': 0.00018477457501847746,
#  'CCONJ-VERB-ADP-DET-NOUN': 0.00018477457501847746,
#  'CCONJ-PROPN-VERB-DET': 0.00018477457501847746,
#  'NOUN-VERB-DET-NOUN-PROPN-NOUN-ADP': 0.00018477457501847746,
#  'CCONJ-PROPN-ADP-PROPN': 0.00018477457501847746,
#  'NOUN-NOUN-DET': 0.00018477457501847746,
#  'ADV-ADP-DET-PROPN-CCONJ-VERB-NOUN-ADP-DET': 0.00018477457501847746,
#  'PRON-VERB-VERB-VERB-DET': 0.00018477457501847746,
#  'VERB-DET-NOUN-ADP-NOUN-PROPN-CCONJ-PROPN-CCONJ-ADJ-NOUN-ADP-NOUN': 0.00018477457501847746,
#  'NOUN-NOUN-CCONJ-NOUN-ADP-DET': 0.00018477457501847746,
#  'VERB-DET-NOUN-VERB-ADP-ADJ-ADJ-NOUN-NOUN-DET-ADP-DET-NOUN-NOUN': 0.00018477457501847746,
#  'CCONJ-PROPN-VERB': 0.00018477457501847746,
#  'PROPN-PROPN-PROPN-VERB-DET-ADJ': 0.00018477457501847746,
#  'VERB-ADV-ADJ-ADP-DET-NOUN-ADP-PRON-PROPN-VERB-ADP-DET-ADJ-NOUN-ADP-NOUN-NOUN-ADJ-ADP': 0.00018477457501847746,
#  'VERB-ADV-ADJ-ADP-DET-NOUN-ADP-PRON': 0.00018477457501847746,
#  'ADP-PROPN-CCONJ-PROPN-NOUN-ADP-DET': 0.00018477457501847746,
#  'VERB-ADP-DET-NOUN-ADP-PROPN': 0.00018477457501847746,
#  'VERB-ADJ-ADP-NUM-CCONJ-VERB-VERB-PART-VERB-PROPN-ADP': 0.00018477457501847746,
#  'NUM-VERB-ADP-PROPN-ADP': 0.00018477457501847746,
#  'ADP-ADJ-DET-ADJ-NOUN': 0.00018477457501847746,
#  'DET-PROPN': 0.00018477457501847746,
#  'PRON-VERB-ADP-PROPN-PART-NOUN-VERB-DET-ADJ-NOUN-VERB-ADP-NOUN-NOUN': 0.00018477457501847746,
#  'PROPN-PROPN-NOUN-NOUN-NOUN-CCONJ-NOUN': 0.00018477457501847746,
#  'PART-ADJ-NOUN-NOUN-ADP': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-ADP-DET-PROPN-ADP-ADJ': 0.00018477457501847746,
#  'ADP-DET-NOUN-ADP-DET-PROPN': 0.00018477457501847746,
#  'VERB-NUM-NOUN-CCONJ-NUM-NOUN-NUM-ADP-DET-NOUN-VERB-DET-NOUN': 0.00018477457501847746,
#  'ADV-NUM-ADV-ADP': 0.00018477457501847746,
#  'PART-NOUN-PROPN-VERB-PROPN-ADP-NOUN-ADP-VERB-PART-VERB-DET-NOUN': 0.00018477457501847746,
#  'VERB-PROPN-ADP-NOUN-ADP-VERB-PART-VERB-DET-NOUN': 0.00018477457501847746,
#  'ADJ-NOUN-NOUN-NOUN': 0.00018477457501847746,
#  'PRON-VERB-ADV-DET-PROPN-PROPN-ADP': 0.00018477457501847746,
#  'PRON-ADJ-NOUN-ADP-PROPN-VERB-ADP-DET-NOUN-ADP-PROPN-CCONJ': 0.00018477457501847746,
#  'PRON-ADJ-NOUN-ADP-PROPN-VERB-ADP-DET-NOUN-ADP': 0.00018477457501847746,
#  'VERB-NUM-ADP-PROPN-VERB-DET-ADJ-NOUN-ADP': 0.00018477457501847746,
#  'DET-VERB-ADP-DET': 0.00018477457501847746,
#  'NOUN-NOUN-ADP-DET-NOUN-NOUN-NOUN': 0.00018477457501847746,
#  'PART-NOUN-DET-ADV': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-ADP-DET-ADJ-NOUN-NOUN': 0.00018477457501847746,
#  'DET-ADJ-ADJ': 0.00018477457501847746,
#  'DET-NOUN-NOUN-ADP-DET-PROPN-CCONJ-DET-NOUN-ADP': 0.00018477457501847746,
#  'PROPN-PROPN-PROPN-CCONJ': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-ADP-ADJ-PROPN-PROPN': 0.00018477457501847746,
#  'ADV-VERB-CCONJ-VERB-DET-ADJ-NOUN-NOUN': 0.00018477457501847746,
#  'PROPN-CCONJ-PROPN-NOUN-ADP-PROPN-ADV-VERB-DET': 0.00018477457501847746,
#  'PRON-VERB-DET-ADJ-NOUN-ADP-DET-NOUN': 0.00018477457501847746,
#  'VERB-DET-NOUN-NOUN-VERB-ADP-DET': 0.00018477457501847746,
#  'DET-NOUN-VERB-ADP-DET-NOUN-ADP-PROPN-CCONJ': 0.00018477457501847746,
#  'VERB-DET-NOUN-VERB-ADP-NUM-ADP': 0.00018477457501847746,
#  'PROPN-PROPN-ADP-DET': 0.00018477457501847746,
#  'CCONJ-PROPN-CCONJ-DET-NOUN-ADP': 0.00018477457501847746,
#  'CCONJ-DET-NOUN-ADP-DET-NOUN-ADP-DET-VERB-DET-NUM-ADP': 0.00018477457501847746,
#  'NUM-PROPN-NUM-CCONJ-VERB-VERB-ADP-ADJ-NOUN-ADP-DET-NOUN-DET-ADP-DET-NOUN': 0.00018477457501847746,
#  'NUM-SYM-NUM-CCONJ-PROPN-NUM-PROPN-NUM-CCONJ-VERB-VERB-ADP-ADJ-NOUN-ADP-DET-NOUN-DET-ADP-DET-NOUN': 0.00018477457501847746,
#  'PROPN-PROPN-CCONJ-NOUN-ADP-PROPN-ADP': 0.00018477457501847746,
#  'PROPN-CCONJ-NOUN-ADP-PROPN-ADP': 0.00018477457501847746,
#  'ADP-ADJ-ADJ-ADP-NUM-ADP-ADJ-NOUN-ADP-PROPN-ADP-PROPN': 0.00018477457501847746,
#  'ADP-ADJ-ADJ-ADP-NUM-ADP-ADJ-NOUN-ADP-PROPN-ADP-PROPN-PROPN-PROPN-ADP-PROPN-PROPN-CCONJ-PROPN': 0.00018477457501847746,
#  'VERB-DET-NUM-ADJ-NOUN-NOUN-VERB-ADP-PROPN-CCONJ-VERB': 0.00018477457501847746,
#  'VERB-DET-NUM-ADJ-NOUN-NOUN-VERB-ADP-PROPN-CCONJ-VERB-PROPN': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-ADP-DET-ADJ-NOUN-ADP-DET-ADJ-NOUN-NOUN-NOUN': 0.00018477457501847746,
#  'ADP-NUM-ADP-PROPN': 0.00018477457501847746,
#  'DET-NOUN-VERB-PROPN-VERB': 0.00018477457501847746,
#  'NOUN-NUM-SYM-NUM-VERB-DET-PROPN-NOUN-CCONJ-DET-VERB-NOUN-ADP-PROPN': 0.00018477457501847746,
#  'CCONJ-PROPN-PROPN-PROPN': 0.00018477457501847746,
#  'ADP-DET-NOUN-ADP-NUM-CCONJ-VERB-VERB-NOUN-ADP-DET-NOUN-PART-NOUN-VERB-PROPN': 0.00018477457501847746,
#  'ADP-DET-NOUN-ADP-NUM-CCONJ-VERB-VERB-NOUN-ADP-DET-NOUN-PART-NOUN-VERB-PROPN-PROPN-CCONJ': 0.00018477457501847746,
#  'NOUN-NOUN-NOUN-ADJ-NOUN-NOUN-CCONJ-ADJ-NOUN-ADP-DET-PROPN-PRON-VERB-ADJ-NOUN-ADP-DET-NOUN-ADP-PROPN-PROPN': 0.00018477457501847746,
#  'ADP-DET-VERB-ADP-DET-PROPN-CCONJ-PROPN-ADP-DET-ADJ-PROPN-CCONJ': 0.00018477457501847746,
#  'NUM-PROPN-NUM-VERB-PROPN-VERB-ADP-DET-PROPN-ADP-DET': 0.00018477457501847746,
#  'PROPN-ADP-PROPN-PROPN-PROPN-ADP-PROPN-PROPN-VERB-DET': 0.00018477457501847746,
#  'PROPN-PROPN-ADP-PROPN-PROPN-VERB-DET': 0.00018477457501847746,
#  'PROPN-NUM-VERB-DET': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-NOUN-ADP-ADJ-NOUN-NOUN-PROPN-VERB-ADP-PROPN-ADP': 0.00018477457501847746,
#  'PRON-VERB-DET-NOUN-NOUN-ADP-DET-NOUN-ADP-PROPN-CCONJ-DET-ADJ-NOUN-ADP': 0.00018477457501847746,
#  'PROPN-VERB-DET-ADJ-NOUN-VERB': 0.00018477457501847746,
#  'NOUN-NOUN-VERB-ADP-PROPN-PROPN-ADP-PROPN': 0.00018477457501847746,
#  'PROPN-ADP-DET-ADJ-NOUN-ADP-DET-PROPN-NOUN-ADP': 0.00018477457501847746,
#  'NOUN-VERB-VERB-ADP-PROPN-ADP-DET-NOUN-ADP-DET-NOUN': 0.00018477457501847746,
#  'NOUN-ADP-DET-NOUN-VERB': 0.00018477457501847746,
#  'PROPN-CCONJ-DET': 0.00018477457501847746,
#  'VERB-DET-NOUN-NOUN-ADP-ADJ-NOUN-NOUN-NOUN': 0.00018477457501847746,
#  'ADV-VERB-ADP-VERB-DET-ADJ-NOUN-NOUN-VERB-CCONJ-VERB-ADP': 0.00018477457501847746,
#  'CCONJ-ADV-ADP-DET-NOUN-PRON-ADP-NOUN-ADP-DET': 0.00018477457501847746,
#  'ADP-ADP-NOUN-CCONJ-NOUN-PROPN-PRON-VERB-DET-PROPN-VERB-NOUN-VERB': 0.00018477457501847746,
#  'PROPN-DET-PROPN-ADV-VERB-ADP-DET-PROPN-ADP': 0.00018477457501847746,
#  'VERB-VERB-DET-NOUN-NOUN-NOUN-VERB-ADV-VERB-ADP-NUM-ADJ-NOUN-INTJ-CCONJ-DET': 0.00018477457501847746,
#  'PART-PROPN-VERB-NOUN-NOUN-ADP-ADP-CCONJ-VERB': 0.00018477457501847746,
#  'DET-NOUN-NOUN-ADP-DET-NOUN-ADP': 0.00018477457501847746,
#  'VERB-VERB-DET-NOUN-NOUN-NOUN-VERB-ADV-VERB-ADP-NUM-ADJ-NOUN': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-VERB-ADP-PROPN': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-VERB-ADP-PROPN-PROPN': 0.00018477457501847746,
#  'PRON-VERB-ADP-NOUN-ADP-PROPN-ADP-PROPN-ADP-DET-NOUN': 0.00018477457501847746,
#  'CCONJ-ADP-DET-PROPN-ADP': 0.00018477457501847746,
#  'PART-NOUN-CCONJ-NOUN': 0.00018477457501847746,
#  'NOUN-PROPN-PROPN': 0.00018477457501847746,
#  'ADV-PROPN-NOUN-VERB-PART-DET-ADJ-NOUN-ADP-DET-NOUN-DET-NOUN-VERB-ADV-VERB-ADP-PROPN-NOUN-VERB-VERB': 0.00018477457501847746,
#  'DET-ADV-ADJ-NOUN-ADP': 0.00018477457501847746,
#  'NUM-SYM-NUM-VERB-ADP-NOUN-ADP-DET': 0.00018477457501847746,
#  'ADP-DET-ADJ-NOUN-PROPN-VERB-ADP-NOUN-ADP-PROPN-CCONJ-ADV-NOUN-ADP': 0.00018477457501847746,
#  'VERB-ADV-PART-VERB-VERB-ADP-PROPN-PRON-VERB-ADV-ADJ-PART-VERB-DET-NOUN-ADP-DET-PROPN-CCONJ-VERB-DET-NOUN-ADP-DET-NOUN-ADP-DET': 0.00018477457501847746,
#  'ADP-DET-NOUN-VERB-DET-NOUN-VERB': 0.00018477457501847746,
#  'DET-ADJ-NOUN-NOUN-VERB-DET-ADJ-ADJ-ADP-DET-NOUN': 0.00018477457501847746,
#  'CCONJ-VERB-ADP-ADJ-NOUN-ADP-DET-NOUN': 0.00018477457501847746,
#  'PART-ADJ-NOUN-PROPN-PROPN-ADP': 0.00018477457501847746,
#  'PRON-VERB-DET-NUM': 0.00018477457501847746,
#  'NUM-ADP-DET-NOUN-NOUN-ADP-DET': 0.00018477457501847746,
#  'ADP-DET-ADJ-ADJ-ADJ-NOUN-NOUN': 0.00018477457501847746,
#  'VERB-DET-VERB': 0.00018477457501847746,
#  'PART-VERB-DET': 0.00018477457501847746,
#  'CCONJ-NOUN-NOUN-ADP-NOUN-NOUN': 0.00018477457501847746,
#  'VERB-ADP-DET-ADJ-NOUN': 0.00018477457501847746,
#  'VERB-ADP-DET-ADJ-NOUN-PROPN-CCONJ': 0.00018477457501847746,
#  'CCONJ-NOUN-VERB-VERB-ADP-NOUN': 0.00018477457501847746,
#  'VERB-PROPN-ADP-PROPN-PROPN': 0.00018477457501847746,
#  'ADV-VERB-DET-NOUN-ADP-DET-NOUN': 0.00018477457501847746,
#  'CCONJ-DET-NOUN-PROPN-CCONJ': 0.00018477457501847746,
#  'PROPN-NUM-NUM-VERB-DET-ADJ-ADJ-NOUN-DET-NOUN-ADP-DET-PROPN-PROPN-PROPN-ADP-DET-PROPN-ADP': 0.00018477457501847746,
#  'PROPN-NUM-NUM-VERB-DET-ADJ-ADJ-NOUN-DET-NOUN-ADP-DET-PROPN-PROPN': 0.00018477457501847746,
#  'DET-ADJ-NOUN-ADP-PROPN-PROPN-CCONJ': 0.00018477457501847746,
#  'DET-ADJ-NOUN-ADP-PROPN': 0.00018477457501847746,
#  'VERB-ADV-DET-NOUN-ADP-DET': 0.00018477457501847746,
#  'NOUN-ADJ-ADP-PROPN': 0.00018477457501847746,
#  'ADP-DET-NOUN-DET-NOUN-ADP-DET-PROPN-ADP-DET-PROPN-VERB': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-ADP-DET-ADJ-NOUN-ADP-DET-ADJ-NOUN-NOUN-NOUN-NOUN-DET': 0.00018477457501847746,
#  'NOUN-CCONJ-NOUN-ADP-DET': 0.00018477457501847746,
#  'VERB-VERB-ADJ-NOUN-PROPN-PART-NOUN-ADJ-NOUN-PART-VERB-DET-PROPN-CCONJ-NOUN-PART-NOUN-DET-PROPN-ADP-DET-ADJ-NOUN-ADP-DET-NOUN': 0.00018477457501847746,
#  'CCONJ-VERB-DET-NOUN-ADP': 0.00018477457501847746,
#  'PART-ADJ-NOUN-ADP-DET': 0.00018477457501847746,
#  'PART-ADJ-PROPN-PROPN-PROPN-CCONJ': 0.00018477457501847746,
#  'VERB-DET-NOUN-NOUN-VERB-ADP-PROPN-ADP-DET-PROPN-NOUN-ADP': 0.00018477457501847746,
#  'ADP-DET-ADV-PRON-VERB-VERB-ADP': 0.00018477457501847746,
#  'ADP-DET-ADV-PRON-VERB-VERB-ADP-PROPN-PROPN-PROPN-CCONJ': 0.00018477457501847746,
#  'ADP-DET-ADV-PRON-VERB-VERB-ADP-PROPN': 0.00018477457501847746,
#  'ADP-DET-ADV-PRON-VERB-VERB-ADP-PROPN-PROPN': 0.00018477457501847746,
#  'VERB-DET-NOUN-PART-NOUN-ADP': 0.00018477457501847746,
#  'VERB-DET-NOUN-PART-NOUN-ADP-PROPN-ADV-VERB-ADP-DET-NOUN-ADP': 0.00018477457501847746,
#  'ADP-PRON-VERB-DET-NUM-VERB': 0.00018477457501847746,
#  'DET-NOUN-VERB-VERB-ADP': 0.00018477457501847746,
#  'CCONJ-PROPN-DET-NOUN-PRON-ADV-VERB-DET-NOUN-ADP-DET-NOUN': 0.00018477457501847746,
#  'VERB-DET-NUM-NOUN-NOUN-NOUN-VERB-ADP': 0.00018477457501847746,
#  'VERB-NUM-ADP-PROPN-VERB-DET-ADJ': 0.00018477457501847746,
#  'PRON-VERB-DET-NOUN-ADP-DET': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-ADP-DET-NUM-NOUN': 0.00018477457501847746,
#  'ADV-DET-ADJ-ADJ-NOUN': 0.00018477457501847746,
#  'VERB-ADV-NUM-ADV-ADP-PROPN-ADP-DET-PROPN-ADP-DET-NOUN-ADP': 0.00018477457501847746,
#  'VERB-ADV-NUM-ADV-ADP-PROPN-ADP-DET': 0.00018477457501847746,
#  'ADP-PROPN-ADP-DET-PROPN-ADP': 0.00018477457501847746,
#  'VERB-NUM-ADP-DET-ADJ-ADJ-NOUN-VERB-DET-NOUN-CCONJ-NOUN-NOUN': 0.00018477457501847746,
#  'VERB-ADP-ADJ-NOUN': 0.00018477457501847746,
#  'VERB-DET-ADJ-CCONJ-ADJ-NOUN-NOUN-NUM-ADP-DET-NUM-ADP': 0.00018477457501847746,
#  'ADP-NUM-ADP-DET-NOUN-ADP-DET-NOUN-VERB-VERB-DET-PROPN-PROPN-DET-PROPN-PROPN': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-ADP-PROPN-PROPN-ADP-DET-PROPN-CCONJ': 0.00018477457501847746,
#  'PROPN-ADP-DET-PROPN-CCONJ': 0.00018477457501847746,
#  'ADP-DET-ADJ-ADJ-NOUN-ADP': 0.00018477457501847746,
#  'CCONJ-DET-ADJ-ADJ-NOUN-PROPN-VERB-ADJ-CCONJ-VERB-VERB-VERB-VERB-ADP-PROPN-CCONJ-VERB-ADP-ADJ': 0.00018477457501847746,
#  'VERB-DET-NOUN-PROPN-ADJ-NOUN-ADP': 0.00018477457501847746,
#  'ADP-PROPN-CCONJ-DET-ADJ-NOUN': 0.00018477457501847746,
#  'PART-VERB-ADP-NOUN-ADP-DET-PROPN-ADV-VERB-ADP-DET-NOUN': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-CCONJ-NOUN-VERB-ADP-DET-PROPN-ADP-PROPN-PROPN': 0.00018477457501847746,
#  'VERB-DET-NOUN-VERB-NOUN-ADP-DET': 0.00018477457501847746,
#  'VERB-DET-NOUN-ADP-CCONJ-DET-NOUN-NOUN-ADP': 0.00018477457501847746,
#  'VERB-PROPN-ADP-NUM-ADP-NUM-ADV-ADP-ADJ-PROPN-ADP-DET-ADV': 0.00018477457501847746,
#  'ADP-NUM-ADP-NUM-ADV-ADP-ADJ-PROPN-ADP-DET-ADV': 0.00018477457501847746,
#  'DET-NOUN-ADV-VERB-DET-ADJ-PROPN-DET-VERB-DET-ADJ-NOUN-ADP-PROPN': 0.00018477457501847746,
#  'DET-NOUN-ADP-PROPN-ADP-DET': 0.00018477457501847746,
#  'NUM-ADP-PROPN-NUM-ADP': 0.00018477457501847746,
#  'ADP-DET-NOUN-PART-NOUN-ADP-DET-PROPN-ADP': 0.00018477457501847746,
#  'NOUN-NOUN-NOUN-ADP': 0.00018477457501847746,
#  'ADV-VERB-ADP-ADJ-ADJ-NOUN-VERB-DET-NOUN-ADP-DET': 0.00018477457501847746,
#  'NOUN-NOUN-ADP-DET-NOUN': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-ADP-ADJ': 0.00018477457501847746,
#  'VERB-VERB-ADP-NOUN-ADP': 0.00018477457501847746,
#  'PROPN-ADV-PROPN': 0.00018477457501847746,
#  'ADV-NOUN-ADP': 0.00018477457501847746,
#  'ADV-NOUN-ADP-PROPN-ADV': 0.00018477457501847746,
#  'ADV-ADJ-NOUN-ADP-NOUN-CCONJ-NOUN-VERB-VERB-ADP': 0.00018477457501847746,
#  'VERB-VERB-ADV-ADP-NOUN-ADP-ADP-PART-VERB-DET-NOUN-ADP-DET': 0.00018477457501847746,
#  'NUM-ADP-NOUN-PROPN-ADP-VERB-DET-ADJ-NOUN': 0.00018477457501847746,
#  'CCONJ-ADV-ADP-DET-PROPN-ADP': 0.00018477457501847746,
#  'DET-NOUN-ADP-ADJ-PROPN-NOUN-ADP': 0.00018477457501847746,
#  'ADP-DET-NOUN-ADP-NOUN-ADP-PROPN': 0.00018477457501847746,
#  'ADP-DET-NOUN-ADP-NOUN-ADP-PROPN-PROPN-ADP-NUM-ADP': 0.00018477457501847746,
#  'ADV-CCONJ-DET-ADJ-NOUN-ADP-NOUN-NOUN': 0.00018477457501847746,
#  'VERB-ADP-PROPN-ADP-ADJ-NOUN': 0.00018477457501847746,
#  'NOUN-CCONJ': 0.00018477457501847746,
#  'ADV-VERB-ADP-DET': 0.00018477457501847746,
#  'NUM-ADP-DET-NOUN-ADP-DET': 0.00018477457501847746,
#  'VERB-VERB-ADP-PROPN-PROPN-CCONJ-VERB-DET-ADJ-ADP-NUM-NOUN-DET-NOUN-VERB': 0.00018477457501847746,
#  'VERB-VERB-ADP-PROPN-PROPN-CCONJ-VERB-DET-ADJ-ADP-NUM-NOUN-DET-NOUN-VERB-PROPN': 0.00018477457501847746,
#  'VERB-NUM-ADP-DET-NOUN-ADP-NOUN-VERB-NOUN-VERB-ADP-DET': 0.00018477457501847746,
#  'VERB-NUM-PROPN-NOUN-NOUN-ADP-DET-ADJ-NOUN-NOUN': 0.00018477457501847746,
#  'DET-NOUN-DET': 0.00018477457501847746,
#  'VERB-ADP-NUM-CCONJ-PRON-VERB-VERB-ADP-PRON-VERB-VERB-DET-NOUN-ADP-NUM-VERB-ADJ-ADP-DET-NOUN-CCONJ-NOUN-NOUN-PROPN-ADP-PROPN-PART-NOUN': 0.00018477457501847746,
#  'NOUN-PRON-VERB-ADP-DET-PROPN-PROPN-ADP': 0.00018477457501847746,
#  'NOUN-PROPN-NOUN': 0.00018477457501847746,
#  'VERB-DET-NUM-ADJ-NOUN-NOUN-ADP': 0.00018477457501847746,
#  'VERB-ADP-NOUN-ADP-DET': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-ADP-ADJ-NOUN': 0.00018477457501847746,
#  'NOUN-ADP-ADJ-NOUN': 0.00018477457501847746,
#  'PROPN-PROPN-NUM-ADP-PROPN-PROPN-VERB-DET': 0.00018477457501847746,
#  'DET-VERB-VERB-ADP-PROPN-PROPN-ADP-PROPN': 0.00018477457501847746,
#  'PART-ADJ-ADJ-ADP-DET-ADJ-NOUN-NOUN': 0.00018477457501847746,
#  'VERB-DET-NOUN-CCONJ-VERB-VERB-ADP-DET-NOUN-ADP-DET-NOUN': 0.00018477457501847746,
#  'ADP-DET-ADJ-PROPN-CCONJ-ADJ-PROPN-ADP-NOUN-ADP-PROPN-CCONJ-NOUN-ADP': 0.00018477457501847746,
#  'PROPN-VERB-ADV-DET-NOUN-ADP-DET-PROPN-ADP-PROPN-VERB-VERB-ADP-DET': 0.00018477457501847746,
#  'ADP-NUM-ADV-PRON-VERB-ADP-NOUN-NOUN-CCONJ-VERB-NOUN-NOUN-ADP-NOUN-NOUN-PROPN': 0.00018477457501847746,
#  'ADP-NUM-ADV-PRON-VERB-ADP-NOUN-NOUN-CCONJ-VERB-NOUN-NOUN-ADP-NOUN-NOUN-PROPN-PROPN-PROPN-PROPN': 0.00018477457501847746,
#  'VERB-ADJ-ADP-DET-NOUN-VERB-NOUN-ADP': 0.00018477457501847746,
#  'ADP-DET-ADJ-NOUN-NOUN': 0.00018477457501847746,
#  'PRON-VERB-ADP-DET-NOUN-ADP-DET': 0.00018477457501847746,
#  'CCONJ-ADJ-NOUN-ADP-DET-PROPN-NOUN-ADP-DET': 0.00018477457501847746,
#  'CCONJ-ADJ-NOUN-ADP-DET-PROPN-NOUN-ADP-DET-PROPN-NOUN-ADP': 0.00018477457501847746,
#  'NOUN-ADP-DET-PROPN-NOUN-ADP-DET-PROPN-NOUN-ADP': 0.00018477457501847746,
#  'VERB-DET-PROPN-ADP-NOUN-NOUN-VERB-ADP-DET-PROPN-VERB-VERB-PART-VERB-DET-ADJ-NOUN-ADP': 0.00018477457501847746,
#  'VERB-ADP-DET-ADJ': 0.00018477457501847746,
#  'NOUN-CCONJ-DET-ADJ-ADJ-NOUN-ADV-PART-VERB-ADP-DET': 0.00018477457501847746,
#  'VERB-NUM-SYM-NUM-VERB-DET': 0.00018477457501847746,
#  'VERB-ADV-VERB-ADP-DET-NOUN-ADP': 0.00018477457501847746,
#  'PART-NOUN-DET-NUM-DET': 0.00018477457501847746,
#  'NUM-SYM-NUM-VERB-DET-ADJ-CCONJ-ADJ-NOUN-ADP': 0.00018477457501847746,
#  'VERB-VERB-ADP-PROPN-NOUN': 0.00018477457501847746,
#  'VERB-VERB-DET-ADJ-NOUN-ADP': 0.00018477457501847746,
#  'VERB-DET-NOUN-ADP-DET-PROPN-ADP-DET-PROPN-NOUN-ADP': 0.00018477457501847746,
#  'CCONJ-PROPN-ADP-NOUN-ADP-DET': 0.00018477457501847746,
#  'VERB-DET-NOUN-ADP-DET-PROPN-ADP-PROPN-CCONJ-PROPN-NOUN-ADP': 0.00018477457501847746,
#  'PART-NOUN-VERB-PROPN-ADV-VERB-ADP-PROPN-CCONJ': 0.00018477457501847746,
#  'PART-PROPN-NOUN-VERB-ADP-DET-NOUN-VERB-ADP-PROPN-CCONJ': 0.00018477457501847746,
#  'ADP-DET-NOUN-ADP-PROPN-DET-NOUN-VERB': 0.00018477457501847746,
#  'PRON-VERB-ADJ-ADP': 0.00018477457501847746,
#  'CCONJ-PROPN-ADP-PROPN-SYM-PROPN-PROPN': 0.00018477457501847746,
#  'ADP-PROPN-DET-NOUN-CCONJ-NOUN-ADP-NOUN-ADP-NOUN-PROPN-DET-NOUN-ADP-PROPN-PROPN-CCONJ-PROPN-DET-NOUN-ADP-VERB-PROPN-PROPN': 0.00018477457501847746,
#  'ADP-PROPN-DET-NOUN-CCONJ-NOUN-ADP-NOUN-ADP-NOUN-PROPN-DET-NOUN-ADP-PROPN-PROPN-CCONJ-PROPN-DET-NOUN-ADP-VERB-PROPN-PROPN-PROPN-CCONJ-PROPN-ADP-PROPN-SYM-PROPN-PROPN': 0.00018477457501847746,
#  'PROPN-VERB-DET-NOUN-ADP-DET-NOUN-ADP-DET-PROPN-ADP': 0.00018477457501847746,
#  'ADP-DET-PROPN-VERB-PROPN-PART-VERB-DET-ADJ-NOUN-NOUN-VERB-DET': 0.00018477457501847746,
#  'DET-NOUN-NOUN-VERB-ADP-ADJ': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-ADP-DET-PROPN-CCONJ-PROPN-CCONJ-DET-PROPN-ADP-DET-ADJ-PROPN-NOUN-ADP-NOUN-PROPN-ADP-DET-PROPN-ADP': 0.00018477457501847746,
#  'ADP-DET-PROPN-NOUN': 0.00018477457501847746,
#  'ADP-PROPN-VERB-DET-NOUN-ADP-PROPN-PROPN-PROPN-ADP-DET-NOUN-ADP-DET': 0.00018477457501847746,
#  'PROPN-VERB-ADP-DET-NOUN-VERB-NOUN-ADP-DET': 0.00018477457501847746,
#  'NOUN-VERB-PROPN-CCONJ': 0.00018477457501847746,
#  'PROPN-ADP-DET-ADJ-NOUN-CCONJ-NOUN-ADP-DET-ADJ-NOUN-ADP': 0.00018477457501847746,
#  'NOUN-ADP-DET-ADJ': 0.00018477457501847746,
#  'NOUN-VERB-DET-ADJ-NOUN-NOUN-ADP-DET-ADJ-NOUN-ADP-PROPN-ADP-ADJ': 0.00018477457501847746,
#  'PART-NOUN-VERB-DET-NOUN-CCONJ-DET-NOUN-ADP-PROPN-CCONJ': 0.00018477457501847746,
#  'ADJ-NOUN-VERB': 0.00018477457501847746,
#  'VERB-PROPN-VERB-DET-ADJ-NOUN-CCONJ-NOUN-PRON-VERB-ADP-PROPN-ADP-DET-ADJ-NOUN-ADP': 0.00018477457501847746,
#  'NOUN-CCONJ-NOUN-PRON-VERB-ADP-PROPN-ADP-DET-ADJ-NOUN-ADP': 0.00018477457501847746,
#  'ADP-NUM-VERB': 0.00018477457501847746,
#  'VERB-DET-NOUN-ADP-DET-ADJ-NOUN-ADP-DET-NOUN-ADP-PROPN': 0.00018477457501847746,
#  'CCONJ-DET-ADJ-NOUN-ADP-DET-ADJ-NOUN-ADP-PROPN-DET-ADP': 0.00018477457501847746,
#  'DET-ADP': 0.00018477457501847746,
#  'VERB-DET-NUM-ADJ-ADJ-NOUN-VERB': 0.00018477457501847746,
#  'VERB-ADV-NUM-ADV-ADP-DET-PROPN-NOUN-ADP': 0.00018477457501847746,
#  'VERB-VERB-ADP-ADJ-NOUN-ADP': 0.00018477457501847746,
#  'ADP-NUM-ADV-VERB-NOUN-ADP-DET-NOUN-PART-DET-ADJ-NOUN-VERB-VERB-VERB': 0.00018477457501847746,
#  'VERB-PROPN-ADP-PROPN-PROPN-VERB-DET': 0.00018477457501847746,
#  'VERB-NOUN-PROPN-VERB-NOUN-ADP-DET-ADJ-ADJ-NOUN-VERB-ADP': 0.00018477457501847746,
#  'ADP-NOUN-ADP-DET-ADJ-NOUN-PROPN': 0.00018477457501847746,
#  'DET-ADJ-NOUN-ADP-PROPN-DET-VERB-VERB-NOUN-ADP': 0.00018477457501847746,
#  'DET-VERB-ADV-VERB-ADP': 0.00018477457501847746,
#  'ADJ-NOUN-PRON-VERB-ADV-DET-ADJ-NOUN-ADP-DET': 0.00018477457501847746,
#  'CCONJ-PROPN-ADP-ADJ-NOUN-NOUN-ADV-ADV-ADP-DET': 0.00018477457501847746,
#  'ADP-ADJ-NOUN-NOUN-ADV-ADV-ADP-DET': 0.00018477457501847746,
#  'VERB-DET-ADV-VERB-NOUN-NOUN-ADP-DET': 0.00018477457501847746,
#  'PART-ADJ-NOUN-ADP-PROPN-ADP': 0.00018477457501847746,
#  'VERB-VERB-NUM-ADP': 0.00018477457501847746,
#  'PRON-VERB-DET-ADJ-NOUN-ADP-PROPN-PART-NOUN': 0.00018477457501847746,
#  'DET-NOUN-ADP-DET-PROPN-ADP-PROPN-CCONJ-DET-NOUN-ADP-PROPN': 0.00018477457501847746,
#  'NOUN-CCONJ-NOUN-CCONJ-DET-ADJ-NUM-SYM-NUM-NOUN-ADP-PROPN-ADP': 0.00018477457501847746,
#  'NOUN-CCONJ-NOUN-CCONJ-DET-ADJ-NUM-SYM-NUM-NOUN-ADP-PROPN-ADP-PROPN-PART-CCONJ': 0.00018477457501847746,
#  'CCONJ-NOUN-VERB-DET-NOUN-ADP': 0.00018477457501847746,
#  'CCONJ-PROPN-PROPN-NUM-NOUN-NOUN': 0.00018477457501847746,
#  'ADP-NUM-VERB-ADP': 0.00018477457501847746,
#  'VERB-ADP-NUM-ADP-DET-ADJ-PROPN-NOUN-ADP-PROPN-PROPN-CCONJ-DET-PROPN-VERB-ADP-PROPN-PROPN-CCONJ': 0.00018477457501847746,
#  'VERB-ADP-NUM-ADP-DET-ADJ-PROPN-NOUN-ADP-PROPN': 0.00018477457501847746,
#  'ADP-PROPN-ADV-DET-PROPN-ADP-DET-PROPN-DET-NOUN-CCONJ-ADJ-NOUN-ADP': 0.00018477457501847746,
#  'ADP-PROPN-ADV-DET-PROPN-ADP-DET': 0.00018477457501847746,
#  'VERB-VERB-ADP-NOUN-ADP-DET': 0.00018477457501847746,
#  'ADP-PROPN-CCONJ-VERB-ADV-ADV-VERB-ADP': 0.00018477457501847746,
#  'ADV-PRON-VERB-DET-NOUN-VERB-DET-VERB-PROPN-ADP-DET-ADJ-NOUN-ADP-PROPN': 0.00018477457501847746,
#  'VERB-DET-NOUN-VERB-ADV-ADJ-ADP-DET-ADJ-NOUN-ADP-DET-NOUN-VERB-DET-ADJ-NOUN': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-DET-ADJ-NOUN-ADP-PROPN-VERB-DET-ADJ-NOUN-ADP': 0.00018477457501847746,
#  'ADJ-NOUN-PART-VERB-ADJ-NOUN-NOUN': 0.00018477457501847746,
#  'PART-NOUN-ADJ': 0.00018477457501847746,
#  'ADP-PROPN-CCONJ-DET-NOUN': 0.00018477457501847746,
#  'VERB-DET-NOUN-NOUN-NOUN-ADP-DET-PROPN-PART-ADJ-NOUN-ADP-DET-ADJ-NOUN-NOUN-NOUN': 0.00018477457501847746,
#  'CCONJ-ADP-NUM-DET-NOUN': 0.00018477457501847746,
#  'CCONJ-ADV': 0.00018477457501847746,
#  'DET-ADJ-ADJ-NOUN-ADP-PROPN-ADP-DET-PROPN-CCONJ-ADJ-NOUN-ADP': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-ADP-PROPN-PART-ADJ-PROPN-PROPN': 0.00018477457501847746,
#  'PROPN-ADP-DET-NOUN-ADP': 0.00018477457501847746,
#  'ADP-DET-NOUN-ADP-PROPN-NOUN-ADP': 0.00018477457501847746,
#  'CCONJ-DET-NOUN-CCONJ-NOUN-ADP-DET-NOUN': 0.00018477457501847746,
#  'VERB-VERB-ADP-PROPN-PROPN-DET-ADJ-NOUN-ADP-DET-ADJ-NOUN': 0.00018477457501847746,
#  'VERB-DET-ADV-ADJ-ADP-DET-NOUN': 0.00018477457501847746,
#  'DET-ADJ-ADJ-NOUN-VERB-DET-NOUN-ADP': 0.00018477457501847746,
#  'VERB-DET-ADJ-NOUN-CCONJ-ADJ-NOUN-ADP-PROPN': 0.00018477457501847746,
#  'NUM-DET-NUM-CCONJ': 0.00018477457501847746,
#  'ADP-DET-NOUN-VERB-VERB-ADV-PROPN-VERB-VERB-PART-VERB-ADP-DET-ADJ-ADJ-NOUN-ADP-DET-NOUN': 0.00018477457501847746,
#  'PROPN-VERB-ADP-PROPN-NOUN-ADP-PROPN-ADP-DET': 0.00018477457501847746,
#  'CCONJ-ADJ-NOUN-ADP-DET': 0.00018477457501847746,
#  'VERB-ADJ-ADP-NOUN': 0.00018477457501847746,
#  'PROPN-VERB-ADP-PROPN-ADP-DET': 0.00018477457501847746,
#  'ADP-DET-NOUN-NOUN-ADP-DET-NUM-NOUN-NOUN-ADV-VERB': 0.00018477457501847746,
#  'ADP-ADJ-PROPN-PROPN-ADP-DET-NOUN-ADP': 0.00018477457501847746,
#  'NOUN-NOUN-PROPN-ADP-PROPN-NUM-SYM-NUM-VERB-DET-ADJ-ADJ-NOUN-ADP': 0.00018477457501847746,
#  'NOUN-NOUN-PROPN-ADP-PROPN-NUM-SYM-NUM-VERB-DET-ADJ-ADJ-NOUN-ADP-PROPN-PROPN-ADP-PROPN-CCONJ-DET-ADJ-NOUN': 0.00018477457501847746,
#  'PROPN-ADP-PROPN-CCONJ-VERB-DET-NOUN-ADP-DET-NOUN': 0.00018477457501847746,
#  'ADP-NUM-ADP-NUM-CCONJ-VERB-NOUN-ADP': 0.00018477457501847746,
#  'NOUN-PRON-ADV-VERB-ADP': 0.00018477457501847746,
#  'ADP-PROPN-PART-ADJ-NOUN-ADP': 0.00018477457501847746,
#  'PRON-VERB-DET-NOUN': 0.00018477457501847746,
#  'NOUN-ADP-DET-ADJ-NOUN-ADP-DET-PROPN-NOUN-ADP': 0.00018477457501847746,
#  'CCONJ-PROPN-NOUN-ADP-DET-ADJ-NOUN-ADP-DET-PROPN-NOUN-ADP': 0.00018477457501847746,
#  'NUM-PROPN-NUM-VERB-DET-ADJ-NOUN-DET-ADJ-ADJ-PROPN-ADP-PROPN-ADP-PROPN-DET-ADJ-PROPN-PROPN-CCONJ-DET-PROPN-NOUN-ADP': 0.00018477457501847746,
#  'DET-ADJ-NOUN-ADP-DET-NOUN': 0.00018477457501847746,
#  'DET-NOUN-NOUN-ADP-ADJ-NOUN': 0.00018477457501847746,
#  'PROPN-ADP-PROPN-CCONJ-DET-NOUN': 0.00018477457501847746,
#  'NUM-SYM-NUM-NOUN-ADP': 0.00018477457501847746,
#  'PART-DET-ADP': 0.00018477457501847746,
#  'DET-NUM-NOUN-NOUN-ADP': 0.00018477457501847746,
#  'CCONJ-DET-NOUN-PROPN-PROPN-CCONJ-DET-NOUN-ADP': 0.00018477457501847746,
#  'VERB-ADP-DET-ADJ-NOUN-ADP-DET-NOUN-ADP': 0.00018477457501847746,
#  'ADP-NOUN-PROPN-ADP': 0.00018477457501847746,
#  'ADP-NOUN-PROPN-ADP-PROPN-CCONJ-PROPN-ADV-ADP-ADJ': 0.00018477457501847746,
#  'VERB-DET-NOUN-ADP-PROPN-ADP-DET-DET-ADJ-NOUN': 0.00018477457501847746,
#  'VERB-VERB-ADV-ADP-DET-NOUN-ADP': 0.00018477457501847746,
#  'NUM-SYM-NUM-VERB-DET-PROPN-NOUN-DET-NOUN-ADP-DET-PROPN-NOUN-NOUN-NOUN-NUM-SYM-NUM-CCONJ-DET-ADJ-NOUN': 0.00018477457501847746,
#  'NUM-SYM-NUM-VERB-DET-PROPN-NOUN-DET-NOUN-ADP-DET-PROPN-NOUN-NOUN': 0.00018477457501847746,
#  'ADV-VERB-PROPN-NUM-SYM-NUM-VERB-DET-PROPN-NOUN-DET-NOUN-ADP-DET-PROPN-NOUN-NOUN-NOUN-NUM-SYM-NUM-CCONJ-DET-ADJ-NOUN': 0.00018477457501847746,
#  'NUM-SYM-NUM-CCONJ-DET-ADJ-NOUN': 0.00018477457501847746,
#  'ADV-VERB-PROPN-NUM-SYM-NUM-VERB-DET-PROPN-NOUN-DET-NOUN-ADP-DET-PROPN-NOUN-NOUN': 0.00018477457501847746,
#  'PRON-VERB-ADV-VERB-ADP': 0.00018477457501847746,
#  'PRON-VERB-ADV-VERB-ADP-PROPN-CCONJ-ADV-ADP': 0.00018477457501847746,
#  'ADP-NUM-CCONJ-VERB-ADV-DET-NOUN-ADP': 0.00018477457501847746,
#  'NOUN-CCONJ-ADJ-NOUN-PRON-VERB-ADP-DET': 0.00018477457501847746,
#  'ADP-VERB-ADP-DET-ADJ-NOUN-CCONJ-VERB-DET-ADJ-NOUN-ADP-DET': 0.00018477457501847746,
#  'VERB-DET-NOUN-ADP-DET-PROPN-ADJ-ADJ-NOUN': 0.00018477457501847746,
#  'VERB-VERB-ADP-ADJ-NOUN-ADP-DET-NOUN-ADP-PROPN': 0.00018477457501847746,
#  'VERB-DET-PROPN-NOUN-ADP-DET-NOUN-NOUN-ADP': 0.00018477457501847746,
#  'VERB-VERB-VERB-ADP-DET': 0.00018477457501847746,
#  'NUM-VERB-ADP-PROPN-ADP-PROPN-VERB': 0.00018477457501847746,
#  'VERB-DET-NOUN-ADP-PROPN-ADP-DET-ADJ-NOUN-ADP-PROPN-DET-ADJ-ADV-CCONJ-DET-NOUN-ADP-PROPN-ADP-DET': 0.00018477457501847746,
#  'NOUN-DET-NOUN-ADP': 0.00018477457501847746,
#  'VERB-ADJ-NOUN-ADV-DET-NOUN-DET-NOUN': 0.00018477457501847746,
#  'VERB-DET-NOUN-ADP-VERB-NOUN-ADP-DET-NOUN': 0.00018477457501847746,
#  'VERB-DET-NOUN-ADP-VERB-NOUN-ADP-DET-NOUN-PROPN-ADV-VERB-ADP-DET-NOUN': 0.00018477457501847746,
#  'DET-NOUN-ADP-NOUN-PRON-VERB-ADJ-ADP': 0.00018477457501847746,
#  'NOUN-CCONJ-VERB-NOUN': 0.00018477457501847746,
#  'VERB-ADP-NUM-NOUN-ADP-NOUN-NOUN-CCONJ-VERB-NOUN': 0.00018477457501847746,
#  'VERB-ADP-NUM-NOUN-ADP-NOUN-NOUN-CCONJ-VERB-NOUN-PROPN-NOUN': 0.00018477457501847746,
#  'VERB-ADP-NUM-NOUN-ADP-NOUN-NOUN-CCONJ-VERB-NOUN-PROPN-NOUN-PROPN-CCONJ-VERB': 0.00018477457501847746,
#  'VERB-ADP-NUM-NOUN-ADP-NOUN-NOUN-CCONJ-VERB-NOUN-PROPN-NOUN-PROPN-CCONJ-VERB-PROPN-PROPN-PART-PROPN-PROPN-CCONJ-VERB': 0.00018477457501847746,
#  ...}

# %%
valid_relationships = []
valid_ids = []

for index, entity_list in enumerate(sentences_entity_list):
    print("==========")
    entities_relations = find_relation(train_annotated_0_dict, entity_list[0], entity_list)
    print(train_annotated_0_text_list[entity_list[0]])
    print(entity_list[1])
    print("------")
    for entity_relation in entities_relations:
        print(entity_relation)
        score, snowball_pos_pattern = check_pos_pattern_and_update(snowball_pos_pattern_filter, entity_relation[2][1], total_index)
        print("POS Pattern Score: ", score)
        if score != False:
            valid_relationships.append(entity_relation[2][0])
            valid_ids.append(entity_relation[1][:2])
    print("------")
    print("==========")
    print("\n")
# Out:
# ==========
# Zest Airways , Inc. operated as AirAsia Zest ( formerly Asian Spirit and Zest Air ) , was a low - cost airline based at the Ninoy Aquino International Airport in Pasay City , Metro Manila in the Philippines .
# [['Zest Airways , Inc.', 'AirAsia Zest', 'Asian Spirit and Zest Air', 'Ninoy Aquino International Airport', 'Pasay City', 'Metro Manila', 'Philippines'], ['train_annotated_0_0_0', 'train_annotated_0_0_2', 'train_annotated_0_0_1', 'train_annotated_0_1_1', 'train_annotated_0_2_0', 'train_annotated_0_3_0', 'train_annotated_0_4_0'], ['0-1-2-3', '6-7', '10-11-12-13-14', '26-27-28-29', '31-32', '34-35', '38'], ['ORG', 'ORG', 'ORG', 'LOC', 'LOC', 'LOC', 'LOC']]
# ------
# [['Zest Airways , Inc.', 'AirAsia Zest'], ['train_annotated_0_0_0', 'train_annotated_0_0_2', 'ORG-ORG'], ['Zest Airways , Inc. operated as AirAsia Zest', 'VERB-ADP']]
# POS Pattern Score:  0.0021249076127124907
# [['AirAsia Zest', 'Asian Spirit and Zest Air'], ['train_annotated_0_0_2', 'train_annotated_0_0_1', 'ORG-ORG'], ['AirAsia Zest ( formerly Asian Spirit and Zest Air', 'ADV']]
# POS Pattern Score:  0.0005543237250554324
# [['Asian Spirit and Zest Air', 'Ninoy Aquino International Airport'], ['train_annotated_0_0_1', 'train_annotated_0_1_1', 'ORG-LOC'], ['Asian Spirit and Zest Air ) , was a low - cost airline based at the Ninoy Aquino International Airport', 'VERB-DET-ADJ-NOUN-NOUN-VERB-ADP-DET']]
# POS Pattern Score:  False
# [['Ninoy Aquino International Airport', 'Pasay City'], ['train_annotated_0_1_1', 'train_annotated_0_2_0', 'LOC-LOC'], ['Ninoy Aquino International Airport in Pasay City', 'ADP']]
# POS Pattern Score:  0.003048780487804878
# [['Pasay City', 'Metro Manila'], ['train_annotated_0_2_0', 'train_annotated_0_3_0', 'LOC-LOC'], ['Pasay City , Metro Manila', '']]
# POS Pattern Score:  False
# [['Metro Manila', 'Philippines'], ['train_annotated_0_3_0', 'train_annotated_0_4_0', 'LOC-LOC'], ['Metro Manila in the Philippines', 'ADP-DET']]
# POS Pattern Score:  0.0024944567627494456
# ------
# ==========
#
#
# ==========
# It operated scheduled domestic and international tourist services , mainly feeder services linking Manila and Cebu with 24 domestic destinations in support of the trunk route operations of other airlines .
# [['Manila', 'Cebu', '24'], ['train_annotated_0_5_0', 'train_annotated_0_6_0', 'train_annotated_0_7_0'], ['53', '55', '57'], ['LOC', 'LOC', 'NUM']]
# ------
# [['Manila', 'Cebu'], ['train_annotated_0_5_0', 'train_annotated_0_6_0', 'LOC-LOC'], ['Manila and Cebu', 'CCONJ']]
# POS Pattern Score:  0.0022172949002217295
# [['Cebu', '24'], ['train_annotated_0_6_0', 'train_annotated_0_7_0', 'LOC-NUM'], ['Cebu with 24', 'ADP']]
# POS Pattern Score:  0.003048780487804878
# ------
# ==========
#
#
# ==========
# In 2013 , the airline became an affiliate of Philippines AirAsia operating their brand separately .
# [['2013', 'Philippines AirAsia'], ['train_annotated_0_8_0', 'train_annotated_0_9_0'], ['72', '80-81'], ['TIME', 'ORG']]
# ------
# [['2013', 'Philippines AirAsia'], ['train_annotated_0_8_0', 'train_annotated_0_9_0', 'TIME-ORG'], ['2013 , the airline became an affiliate of Philippines AirAsia', 'DET-NOUN-VERB-DET-NOUN-ADP']]
# POS Pattern Score:  False
# ------
# ==========
#
#
# ==========
# Its main base was Ninoy Aquino International Airport , Manila .
# [['Ninoy Aquino International Airport', 'Manila'], ['train_annotated_0_1_0', 'train_annotated_0_5_1'], ['91-92-93-94', '96'], ['LOC', 'LOC']]
# ------
# [['Ninoy Aquino International Airport', 'Manila'], ['train_annotated_0_1_0', 'train_annotated_0_5_1', 'LOC-LOC'], ['Ninoy Aquino International Airport , Manila', '']]
# POS Pattern Score:  False
# ------
# ==========
#
#
# ==========
# The airline was founded as Asian Spirit , the first airline in the Philippines to be run as a cooperative .
# [['Asian Spirit', 'Philippines'], ['train_annotated_0_10_0', 'train_annotated_0_4_1'], ['103-104', '111'], ['ORG', 'LOC']]
# ------
# [['Asian Spirit', 'Philippines'], ['train_annotated_0_10_0', 'train_annotated_0_4_1', 'ORG-LOC'], ['Asian Spirit , the first airline in the Philippines', 'DET-ADJ-NOUN-ADP-DET']]
# POS Pattern Score:  0.0003695491500369549
# ------
# ==========
#
#
# ==========
# On August 16 , 2013 , the Civil Aviation Authority of the Philippines ( CAAP ) , the regulating body of the Government of the Republic of the Philippines for civil aviation , suspended Zest Air flights until further notice because of safety issues .
# [['August 16 , 2013', 'Civil Aviation Authority of the Philippines', 'CAAP', 'Republic of the Philippines', 'Zest Air'], ['train_annotated_0_8_1', 'train_annotated_0_11_0', 'train_annotated_0_11_1', 'train_annotated_0_4_2', 'train_annotated_0_12_0'], ['120-121-122-123', '126-127-128-129-130-131', '133', '144-145-146-147', '153-154'], ['TIME', 'ORG', 'ORG', 'LOC', 'ORG']]
# ------
# [['August 16 , 2013', 'Civil Aviation Authority of the Philippines'], ['train_annotated_0_8_1', 'train_annotated_0_11_0', 'TIME-ORG'], ['August 16 , 2013 , the Civil Aviation Authority of the Philippines', 'DET']]
# POS Pattern Score:  0.001385809312638581
# [['Civil Aviation Authority of the Philippines', 'CAAP'], ['train_annotated_0_11_0', 'train_annotated_0_11_1', 'ORG-ORG'], ['Civil Aviation Authority of the Philippines ( CAAP', '']]
# POS Pattern Score:  False
# [['CAAP', 'Republic of the Philippines'], ['train_annotated_0_11_1', 'train_annotated_0_4_2', 'ORG-LOC'], ['CAAP ) , the regulating body of the Government of the Republic of the Philippines', 'DET-NOUN-NOUN-ADP-DET-PROPN-ADP-DET']]
# POS Pattern Score:  False
# [['Republic of the Philippines', 'Zest Air'], ['train_annotated_0_4_2', 'train_annotated_0_12_0', 'LOC-ORG'], ['Republic of the Philippines for civil aviation , suspended Zest Air', 'ADP-ADJ-NOUN-VERB']]
# POS Pattern Score:  False
# ------
# ==========
#
#
# ==========
# Less than a year after AirAsia and Zest Air 's strategic alliance , the airline has been rebranded as AirAsia Zest .
# [['a year', 'AirAsia', 'Zest Air', 'AirAsia Zest'], ['train_annotated_0_13_0', 'train_annotated_0_14_0', 'train_annotated_0_12_1', 'train_annotated_0_0_3'], ['166-167', '169', '171-172', '183-184'], ['NUM', 'ORG', 'ORG', 'ORG']]
# ------
# [['a year', 'AirAsia'], ['train_annotated_0_13_0', 'train_annotated_0_14_0', 'NUM-ORG'], ['a year after AirAsia', 'ADP']]
# POS Pattern Score:  0.003048780487804878
# [['AirAsia', 'Zest Air'], ['train_annotated_0_14_0', 'train_annotated_0_12_1', 'ORG-ORG'], ['AirAsia and Zest Air', 'CCONJ']]
# POS Pattern Score:  0.0022172949002217295
# [['Zest Air', 'AirAsia Zest'], ['train_annotated_0_12_1', 'train_annotated_0_0_3', 'ORG-ORG'], ["Zest Air 's strategic alliance , the airline has been rebranded as AirAsia Zest", 'PART-ADJ-NOUN-DET-NOUN-VERB-VERB-VERB-ADP']]
# POS Pattern Score:  False
# ------
# ==========
#
#
# ==========
# The airline was merged into AirAsia Philippines in January 2016 .
# [['AirAsia Philippines', 'January 2016'], ['train_annotated_0_15_0', 'train_annotated_0_16_0'], ['191-192', '194-195'], ['ORG', 'TIME']]
# ------
# [['AirAsia Philippines', 'January 2016'], ['train_annotated_0_15_0', 'train_annotated_0_16_0', 'ORG-TIME'], ['AirAsia Philippines in January 2016', 'ADP']]
# POS Pattern Score:  0.003048780487804878
# ------
# ==========

# %% [markdown]
# # Classify Relationships

# %%
nlp_re = spacy.load('en_core_web_sm')
DEVICE = -1
nlp_re.add_pipe("rebel", config={
    'device':DEVICE, # Number of the GPU, -1 if want to use CPU
    'model_name':'Babelscape/rebel-large'} # Model used, will default to 'Babelscape/rebel-large' if not given
    )

# %%
valid_rel = []
for index, relationships in enumerate(valid_relationships):
    doc = nlp_re(relationships)
    rel = []
    for value, rel_dict in doc._.rel.items():
        print(f"{relationships} : {value}: {rel_dict['relation']}")
        rel.append(rel_dict['relation'])
    valid_rel.append(rel)
# Out:
# Zest Airways , Inc. operated as AirAsia Zest : (6, 0): subsidiary
# AirAsia Zest ( formerly Asian Spirit and Zest Air : (0, 4): replaces
# AirAsia Zest ( formerly Asian Spirit and Zest Air : (4, 0): replaced by
# Ninoy Aquino International Airport in Pasay City : (0, 5): place served by transport hub
# Metro Manila in the Philippines : (0, 4): country
# Metro Manila in the Philippines : (4, 0): contains administrative territorial entity
# Manila and Cebu : (0, 2): twinned administrative body
# Manila and Cebu : (2, 0): twinned administrative body
# Cebu with 24 : (0, 2): population
# Asian Spirit , the first airline in the Philippines : (0, 8): country
# AirAsia and Zest Air : (0, 2): subsidiary
# AirAsia and Zest Air : (2, 0): parent organization
# AirAsia Philippines in January 2016 : (0, 3): inception

# %%
valid_filt_ids = []
valid_filt_rel = []
valid_filt_relationships = []
for index, rels in enumerate(valid_rel):
    for rel in enumerate(rels):
        print(valid_ids[index], rel[1])
        valid_filt_ids.append(valid_ids[index])
        valid_filt_rel.append(rel[1])
        valid_filt_relationships.append(valid_relationships[index])
# Out:
# ['train_annotated_0_0_0', 'train_annotated_0_0_2'] subsidiary
# ['train_annotated_0_0_2', 'train_annotated_0_0_1'] replaces
# ['train_annotated_0_0_2', 'train_annotated_0_0_1'] replaced by
# ['train_annotated_0_1_1', 'train_annotated_0_2_0'] place served by transport hub
# ['train_annotated_0_3_0', 'train_annotated_0_4_0'] country
# ['train_annotated_0_3_0', 'train_annotated_0_4_0'] contains administrative territorial entity
# ['train_annotated_0_5_0', 'train_annotated_0_6_0'] twinned administrative body
# ['train_annotated_0_5_0', 'train_annotated_0_6_0'] twinned administrative body
# ['train_annotated_0_6_0', 'train_annotated_0_7_0'] population
# ['train_annotated_0_10_0', 'train_annotated_0_4_1'] country
# ['train_annotated_0_14_0', 'train_annotated_0_12_1'] subsidiary
# ['train_annotated_0_14_0', 'train_annotated_0_12_1'] parent organization
# ['train_annotated_0_15_0', 'train_annotated_0_16_0'] inception

# %% [markdown]
# # Benchmark

# %%
def sort_entity_ids(entity_ids):
    
    for ids in entity_ids:
        ids.sort()
        
    return entity_ids

# %%
def precision(true_positives, false_positives):
    print("Precision: ", true_positives/(true_positives + false_positives))
    return true_positives/(true_positives + false_positives)

# %%
def recall(true_positives, false_negatives):
    print("Recall: ", true_positives/(true_positives + false_negatives))
    return true_positives/(true_positives + false_negatives)

# %%
def benchmark(valid_relationships, valid_ids, valid_rel, ground_truth, rel_type_out):
    true_positives = 0
    false_positives = 0
    false_negatives = 0
    
    valid_relationships = list(map(str, valid_relationships))
    ground_truth = ground_truth[ground_truth["pos_pattern"].notna()]
    ground_truth_relationships = list(map(str, ground_truth["span"].tolist()))
    ground_truth_relationships_type = list(map(str, ground_truth["rel type"].tolist()))
    
    ground_truth_id = ground_truth[["entity 1 mention ID", "entity 2 mention ID"]].values.tolist()
    ground_truth_id = sort_entity_ids(ground_truth_id)
    valid_fixed_ids = []
    for ids in valid_ids: 
        valid_fixed_ids.append(ids[:2])
    valid_ids = sort_entity_ids(valid_fixed_ids)
    pred_rel = ''
    ground_truth_rel = ''
    
    print("\n")
    print("DETECTED RELATIONSHIPS: ")
    [print(relationships) for relationships in valid_relationships]
    print("\n")
    print("GROUND TRUTH RELATIONSHIPS: ")
    [print(relationships) for relationships in ground_truth_relationships]
    print("\n")

    pred_grd_rel_type = []
    for index, ids in enumerate(valid_ids):
        if ids in ground_truth_id:
            if len(valid_rel) != 0:
                id_index = ground_truth_id.index(ids)
                ground_truth_rel = ground_truth_relationships_type[id_index]
                pred_rel = valid_rel[index]
                pred_grd_rel_type.append([pred_rel, ground_truth_rel])
                if ground_truth_rel not in rel_type_out:
                    if ground_truth_rel == pred_rel:
                        print("\nMatched Relationship: %s with relationship: %s" %(valid_relationships[index], pred_rel))
                        true_positives += 1
                    else:
                        print("\nIndex matched for ''%s'' but relationship type not matched with PREDICTED as: %s and ACTUAL as: %s" %(valid_relationships[index], pred_rel, ground_truth_rel))
                        false_positives += 1
                else:
                    print("Ignoring less significant relationalship type ''%s''" %(ground_truth_rel))
            else:
                print("\nMatched Relationship: %s" %(valid_relationships[index]))
                true_positives += 1
        else:
            pred_grd_rel_type.append([valid_rel[index], 'NA'])
            false_positives += 1
    
    for index, ids in enumerate(ground_truth_id):
        if ids not in valid_ids:
            false_negatives += 1
            
    return true_positives, false_positives, false_negatives, pred_grd_rel_type

# %%
def benchmark_dataset(tagged_token_files, ground_truth_files, raw_text_files, snowball_pos_pattern, total_index, re_compute = False, relations = False):
    
    all_precision = []
    all_recall = []
    
    all_valid_relationships = []
    all_valid_ids = []
    all_valid_rel = []
    all_valid_ents = []
    all_valid_ents_type = []
    all_pred_grd_rel_type = []
    
    for index, file in enumerate(tagged_token_files):
        
        try: 
            print("==================Start of File %d==================" % index)
            print("Reading Files: " + raw_text_files[index] + "\n- " + file + "\n- " + ground_truth_files[index])
            print("\n")
            tagged_token = pd.read_csv(file, sep = "\t")
            ground_truth = pd.read_csv(ground_truth_files[index], sep = "\t")
            raw_text = open(raw_text_files[index], "r", encoding="utf8")
            raw_text_list = raw_text.readlines()
            raw_text_list = [sentence for sentence in raw_text_list if sentence != '\n']
            raw_text_list = [sentence.replace(' \n', '') for sentence in raw_text_list]
            
            tagged_token_dict = create_tagged_dict(tagged_token)

            sentences_entity_list = []

            for index, sentence in enumerate(raw_text_list):
                sentence_nlp = nlp(sentence)
                
                entities, indices, key_str, entities_types = sentence_entity(tagged_token_dict, index, sentence_nlp, False)
                # sent_roots, sent_roots_index = extract_root(tagged_token_dict, index, sentence_nlp)
                sentences_entity_list.append([index, [entities, indices, key_str, entities_types]])
                
            # sentences_entity_list = filter_sentences(sentences_entity_list)

            valid_relationships = []
            valid_ids = []
            valid_pos = []
            valid_rel = []
            valid_ents = []
            valid_ents_typ = []
            
            
            for index, entity_list in enumerate(sentences_entity_list):
                entities_relations = find_relation(tagged_token_dict, entity_list[0], entity_list)
                print("===============")
                print(raw_text_list[entity_list[0]])
                # print(entity_list[1])
                print("+++++")
                for entity_relation in entities_relations:
                    # print(entity_relation)
                    score, snowball_pos_pattern = check_pos_pattern_and_update(snowball_pos_pattern, entity_relation[2][1], total_index, re_compute)
                    # print("POS Pattern Score: ", score)
                    if score != False:
                        valid_ents.append([entity_relation[0][0], entity_relation[0][1]])
                        valid_ents_typ.append(entity_relation[1][2])
                        
                        valid_pos.append(entity_relation[2][1])
                        valid_ids.append(entity_relation[1][:2])
                        relationships = entity_relation[2][0]
                        valid_relationships.append(relationships)
                        if relations == True:
                            doc = nlp_re(relationships)
                            rel = []
                            for value, rel_dict in doc._.rel.items():
                                print(f"Detected relationship in '{relationships}' of category '{rel_dict['relation']}'")
                                rel.append(rel_dict['relation'])
                            valid_rel.append(rel)
                            
                print("===============\n")
            valid_filt_ids = []
            valid_filt_rel = []
            valid_filt_ent = []
            valid_filt_ent_typ = []
            valid_filt_relationships = []
            for index, rels in enumerate(valid_rel):
                for rel in enumerate(rels):
                    # print(valid_ids[index], rel[1])
                    valid_filt_ids.append(valid_ids[index])
                    valid_filt_rel.append(rel[1])
                    valid_filt_relationships.append(valid_relationships[index])
                    valid_filt_ent.append(valid_ents[index])
                    valid_filt_ent_typ.append(valid_ents_typ[index])
            

            if "span" in ground_truth:
                true_positives, false_positives, false_negatives, _ = benchmark(valid_filt_relationships, valid_filt_ids, valid_filt_rel, ground_truth[["rel type", "entity 1 mention ID", "entity 2 mention ID", "pos_pattern", "span"]], [])

                print("\n")
                print("BENCHMARK:")
                # print(len(pred_grd_rel_type))

                print("True Positives: %d" % true_positives)
                print("False Positives: %d" % false_positives)
                print("False Negatives: %d" % false_negatives)

                print("\n")
                
                all_valid_relationships.append(valid_filt_relationships)
                all_valid_ids.append(valid_filt_ids)
                all_valid_rel.append(valid_filt_rel)
                all_valid_ents.append(valid_filt_ent)
                all_valid_ents_type.append(valid_filt_ent_typ)
                # all_pred_grd_rel_type.append(pred_grd_rel_type)

                if((true_positives + false_positives) != 0):
                    all_precision.append(precision(true_positives, false_positives))
                else:
                     all_precision.append(0)

                if((true_positives + false_negatives) != 0):
                    all_recall.append(recall(true_positives, false_negatives))
                else:
                    all_recall.append(0)
                    
            else:
                print("\nCan't benchmark ground truth file empty")


            print("==================End of File==================")

            print("\n")
        
        except EmptyDataError:
            print("One of the csv file is empty")
        
    if(len(all_precision) > 0 and len(all_recall) > 0):
        
        print("==================Final Result==================")

        print("\n")

        print("Average Precision %f" %np.mean(all_precision))
        print("Average Recall %f" %np.mean(all_recall))
        
        return all_precision, all_recall, all_valid_relationships, all_valid_ids, all_valid_rel, all_valid_ents, all_valid_ents_type

        print("\n")
        
        print("===============================================")

# %%
true_positives, false_positives, false_negatives, _ = benchmark(valid_filt_relationships, valid_filt_ids, valid_filt_rel, train_annotated_0_truth[["rel type", "entity 1 mention ID", "entity 2 mention ID", "pos_pattern", "span"]], [])
# Out:
# DETECTED RELATIONSHIPS:
# Zest Airways , Inc. operated as AirAsia Zest
# AirAsia Zest ( formerly Asian Spirit and Zest Air
# AirAsia Zest ( formerly Asian Spirit and Zest Air
# Ninoy Aquino International Airport in Pasay City
# Metro Manila in the Philippines
# Metro Manila in the Philippines
# Manila and Cebu
# Manila and Cebu
# Cebu with 24
# Asian Spirit , the first airline in the Philippines
# AirAsia and Zest Air
# AirAsia and Zest Air
# AirAsia Philippines in January 2016
#
#
# GROUND TRUTH RELATIONSHIPS:
# Pasay City , Metro Manila in the Philippines
# Metro Manila in the Philippines
# Asian Spirit , the first airline in the Philippines
#
#
#
# Index matched for ''Metro Manila in the Philippines'' but relationship type not matched with PREDICTED as: country and ACTUAL as: contains administrative territorial entity
#
# Matched Relationship: Metro Manila in the Philippines with relationship: contains administrative territorial entity
#
# Matched Relationship: Asian Spirit , the first airline in the Philippines with relationship: country

# %%
precision(true_positives, false_positives)
# Out:
# Precision:  0.15384615384615385
# 0.15384615384615385

# %%
recall(true_positives, false_negatives)
# Out:
# Recall:  0.6666666666666666
# 0.6666666666666666

# %% [markdown]
# # Benchmarking docred dataset

# %%
tagged_token_files_docred = glob.glob("../Data/relex_processed_data/relex/docred/tagged_tokens/*")
ground_truth_files_docred = glob.glob("../Data/relex_processed_data/relex/docred/ground_truth/*")
raw_text_files_docred = glob.glob("../Data/relex_processed_data/relex/docred/raw_text/*")

# %% [markdown]
# ## 60% Sampling of all files

# %%
tagged_token_files_docred_sample = tagged_token_files_docred[:int(len(tagged_token_files_docred) * .60)]
ground_truth_files_docred_sample = ground_truth_files_docred[:int(len(ground_truth_files_docred) * .60)]
raw_text_files_docred_sample = raw_text_files_docred[:int(len(raw_text_files_docred) * .60)]

# %% [markdown]
# ## 40% Sampling of all files for testing

# %%
tagged_token_files_docred_sample_test = tagged_token_files_docred[int(len(tagged_token_files_docred) * .60):]
ground_truth_files_docred_sample_test = ground_truth_files_docred[int(len(ground_truth_files_docred) * .60):]
raw_text_files_docred_sample_test = raw_text_files_docred[int(len(raw_text_files_docred) * .60):]

# %% [markdown]
# ## 70% sampled SnowBall from ground truth

# %%
docred_file_dir_files = glob.glob("../Data/relex_processed_data/relex/docred/ground_truth/*.csv")

# %%
docred_file_dir_files_sample = docred_file_dir_files[:int(len(docred_file_dir_files) * .70)]
snowball_index_docred = generate_snowball(docred_file_dir_files_sample)
snowball_pos_pattern_docred, docred_total_index  = cal_rank(snowball_index_docred)
snowball_pos_pattern_docred = sort_dict(snowball_pos_pattern_docred)
snowball_pos_pattern_docred_filter = remove_out(snowball_pos_pattern_docred)

# %% [markdown]
# ## Benchmarking on Trained

# %%
all_precision_docred, all_recall_docred, all_valid_relationships, all_valid_ids, all_valid_rel, all_valid_ents, all_valid_ents_type = benchmark_dataset(tagged_token_files_docred_sample, ground_truth_files_docred_sample, raw_text_files_docred_sample, snowball_pos_pattern_docred_filter, docred_total_index, False, True)
# Out:
# ==================Start of File 0==================
# Reading Files: ../Data/relex_processed_data/relex/docred/raw_text\train_annotated_0.txt
# - ../Data/relex_processed_data/relex/docred/tagged_tokens\train_annotated_0.csv
# - ../Data/relex_processed_data/relex/docred/ground_truth\train_annotated_0.csv
#
#
# ===============
# Zest Airways , Inc. operated as AirAsia Zest ( formerly Asian Spirit and Zest Air ) , was a low - cost airline based at the Ninoy Aquino International Airport in Pasay City , Metro Manila in the Philippines .
#
# +++++
# Detected relationship in 'Zest Airways , Inc. operated as AirAsia Zest' of category 'subsidiary'
# Detected relationship in 'AirAsia Zest ( formerly Asian Spirit and Zest Air' of category 'replaces'
# Detected relationship in 'AirAsia Zest ( formerly Asian Spirit and Zest Air' of category 'replaced by'
# Detected relationship in 'Ninoy Aquino International Airport in Pasay City' of category 'place served by transport hub'
# Detected relationship in 'Metro Manila in the Philippines' of category 'country'
# Detected relationship in 'Metro Manila in the Philippines' of category 'contains administrative territorial entity'
# ===============
#
# ===============
# It operated scheduled domestic and international tourist services , mainly feeder services linking Manila and Cebu with 24 domestic destinations in support of the trunk route operations of other airlines .
#
# +++++
# Detected relationship in 'Manila and Cebu' of category 'twinned administrative body'
# Detected relationship in 'Manila and Cebu' of category 'twinned administrative body'
# Detected relationship in 'Cebu with 24' of category 'population'
# ===============
#
# ===============
# In 2013 , the airline became an affiliate of Philippines AirAsia operating their brand separately .
#
# +++++
# ===============
#
# ===============
# Its main base was Ninoy Aquino International Airport , Manila .
#
# +++++
# ===============
#
# ===============
# The airline was founded as Asian Spirit , the first airline in the Philippines to be run as a cooperative .
#
# +++++
# Detected relationship in 'Asian Spirit , the first airline in the Philippines' of category 'country'
# ===============
#
# ===============
# On August 16 , 2013 , the Civil Aviation Authority of the Philippines ( CAAP ) , the regulating body of the Government of the Republic of the Philippines for civil aviation , suspended Zest Air flights until further notice because of safety issues .
#
# +++++
# ===============
#
# ===============
# Less than a year after AirAsia and Zest Air 's strategic alliance , the airline has been rebranded as AirAsia Zest .
#
# +++++
# Detected relationship in 'AirAsia and Zest Air' of category 'subsidiary'
# Detected relationship in 'AirAsia and Zest Air' of category 'parent organization'
# ===============
#
# ===============
# The airline was merged into AirAsia Philippines in January 2016 .
#
# +++++
# Detected relationship in 'AirAsia Philippines in January 2016' of category 'inception'
# ===============
#
#
#
# DETECTED RELATIONSHIPS:
# Zest Airways , Inc. operated as AirAsia Zest
# AirAsia Zest ( formerly Asian Spirit and Zest Air
# AirAsia Zest ( formerly Asian Spirit and Zest Air
# Ninoy Aquino International Airport in Pasay City
# Metro Manila in the Philippines
# Metro Manila in the Philippines
# Manila and Cebu
# Manila and Cebu
# Cebu with 24
# Asian Spirit , the first airline in the Philippines
# AirAsia and Zest Air
# AirAsia and Zest Air
# AirAsia Philippines in January 2016
#
#
# GROUND TRUTH RELATIONSHIPS:
# Pasay City , Metro Manila in the Philippines
# Metro Manila in the Philippines
# Asian Spirit , the first airline in the Philippines
#
#
#
# Index matched for ''Metro Manila in the Philippines'' but relationship type not matched with PREDICTED as: country and ACTUAL as: contains administrative territorial entity
#
# Matched Relationship: Metro Manila in the Philippines with relationship: contains administrative territorial entity
#
# Matched Relationship: Asian Spirit , the first airline in the Philippines with relationship: country
#
#
# BENCHMARK:
# True Positives: 2
# False Positives: 11
# False Negatives: 1
#
#
# Precision:  0.15384615384615385
# Recall:  0.6666666666666666
# ==================End of File==================
#
#
# ==================Start of File 1==================
# Reading Files: ../Data/relex_processed_data/relex/docred/raw_text\train_annotated_1.txt
# - ../Data/relex_processed_data/relex/docred/tagged_tokens\train_annotated_1.csv
# - ../Data/relex_processed_data/relex/docred/ground_truth\train_annotated_1.csv
#
#
# ===============
# The short - beaked common dolphin ( Delphinus delphis ) is a species of common dolphin .
#
# +++++
# ===============
#
# ===============
# It has a larger range than the long - beaked common dolphin ( D. capensis ) , occurring throughout warm - temperate and tropical oceans , including the Indian Ocean although in smaller quantities than other places they are found .
#
# +++++
# ===============
#
# ===============
# There are more short - beaked common dolphins than any other dolphin species in the warm - temperate portions of the Atlantic and Pacific Oceans .
#
# +++++
# Detected relationship in 'Atlantic and Pacific Oceans' of category 'has part'
# ===============
#
# ===============
# It is also found in the Caribbean and Mediterranean Seas .
#
# +++++
# Detected relationship in 'Caribbean and Mediterranean Seas' of category 'has part'
# ===============
#
# ===============
# The short - beaked common dolphin is also abundant in the Black Sea , Gulf of Mexico , and Red Sea .
#
# +++++
# Detected relationship in 'Gulf of Mexico , and Red Sea' of category 'part of'
# ===============
#
# ===============
# They follow the gulf stream up to Norwegian waters .
#
# +++++
# ===============
#
# ===============
# Seldom do any short - beaked dolphin venture near the Arctic .
#
# +++++
# ===============
#
#
# Can't benchmark ground truth file empty
# ==================End of File==================
#
#
# ==================Start of File 2==================
# Reading Files: ../Data/relex_processed_data/relex/docred/raw_text\train_annotated_10.txt
# - ../Data/relex_processed_data/relex/docred/tagged_tokens\train_annotated_10.csv
# - ../Data/relex_processed_data/relex/docred/ground_truth\train_annotated_10.csv
#
#
# ===============
# The Second River , or Watsessing River , in the state of New Jersey in the United States , is the second main tributary of the Passaic River encountered while travelling upstream from its mouth at Newark Bay .
#
# +++++
# Detected relationship in 'Second River , or Watsessing River' of category 'tributary'
# Detected relationship in 'Second River , or Watsessing River' of category 'mouth of the watercourse'
# Detected relationship in 'Watsessing River , in the state of New Jersey' of category 'located in the administrative territorial entity'
# Detected relationship in 'New Jersey in the United States' of category 'country'
# Detected relationship in 'New Jersey in the United States' of category 'contains administrative territorial entity'
# Detected relationship in 'United States , is the second main tributary of the Passaic River' of category 'country'
# ===============
#
# ===============
# From its source in West Orange to the Passaic , it is approximately 5   mi ( 8   km ) long .
#
# +++++
# Detected relationship in 'West Orange to the Passaic' of category 'shares border with'
# Detected relationship in 'West Orange to the Passaic' of category 'shares border with'
# ===============
#
# ===============
# From West Orange , the Second River passes generally easterly through the towns of Orange and East Orange , where it is joined by Wigwam , Parrow , and Nishuane Brooks , then turns slightly to the north ( though still generally easterly ) , and enters the town of Bloomfield .
#
# +++++
# Detected relationship in 'West Orange , the Second River' of category 'located in or next to body of water'
# Detected relationship in 'Orange and East Orange' of category 'shares border with'
# Detected relationship in 'Orange and East Orange' of category 'shares border with'
# Detected relationship in 'East Orange , where it is joined by Wigwam' of category 'shares border with'
# Detected relationship in 'East Orange , where it is joined by Wigwam' of category 'shares border with'
# ===============
#
# ===============
# Here , at Watsessing Park , it is joined by Toney 's Brook .
#
# +++++
# ===============
#
# ===============
# After leaving Bloomfield , it enters the town of Belleville ( which was , early in its history , also named " Second River " ) , and turns slightly to the south ( though still generally easterly ) .
#
# +++++
# Detected relationship in 'Bloomfield , it enters the town of Belleville' of category 'shares border with'
# Detected relationship in 'Bloomfield , it enters the town of Belleville' of category 'shares border with'
# ===============
#
# ===============
# Soon into Belleville , it forms the border between Belleville and Newark .
#
# +++++
# Detected relationship in 'Belleville and Newark' of category 'shares border with'
# Detected relationship in 'Belleville and Newark' of category 'shares border with'
# ===============
#
# ===============
# Finally , it joins the Passaic River , on its way to Newark Bay .
#
# +++++
# Detected relationship in 'Passaic River , on its way to Newark Bay' of category 'mouth of the watercourse'
# Detected relationship in 'Passaic River , on its way to Newark Bay' of category 'tributary'
# ===============
#
# ===============
# In the 19th and early 20th centuries , the Second River supported a sizable industrial complex of mills and factories .
#
# +++++
# Detected relationship in 'the 19th and early 20th centuries' of category 'followed by'
# ===============
#
# ===============
# The Reformed Dutch Church of Second River is named after this river .
#
# +++++
# ===============
#
#
#
# DETECTED RELATIONSHIPS:
# Second River , or Watsessing River
# Second River , or Watsessing River
# Watsessing River , in the state of New Jersey
# New Jersey in the United States
# New Jersey in the United States
# United States , is the second main tributary of the Passaic River
# West Orange to the Passaic
# West Orange to the Passaic
# West Orange , the Second River
# Orange and East Orange
# Orange and East Orange
# East Orange , where it is joined by Wigwam
# East Orange , where it is joined by Wigwam
# Bloomfield , it enters the town of Belleville
# Bloomfield , it enters the town of Belleville
# Belleville and Newark
# Belleville and Newark
# Passaic River , on its way to Newark Bay
# Passaic River , on its way to Newark Bay
# the 19th and early 20th centuries
#
#
# GROUND TRUTH RELATIONSHIPS:
# Second River , or Watsessing River , in the state of New Jersey
# Second River , or Watsessing River , in the state of New Jersey in the United States
# Watsessing River , in the state of New Jersey
# Watsessing River , in the state of New Jersey in the United States
# New Jersey in the United States
# New Jersey in the United States
# United States , is the second main tributary of the Passaic River encountered while travelling upstream from its mouth at Newark Bay
# New Jersey in the United States
#
#
#
# Matched Relationship: Watsessing River , in the state of New Jersey with relationship: located in the administrative territorial entity
#
# Index matched for ''New Jersey in the United States'' but relationship type not matched with PREDICTED as: country and ACTUAL as: located in the administrative territorial entity
#
# Index matched for ''New Jersey in the United States'' but relationship type not matched with PREDICTED as: contains administrative territorial entity and ACTUAL as: located in the administrative territorial entity
#
#
# BENCHMARK:
# True Positives: 1
# False Positives: 19
# False Negatives: 4
#
#
# Precision:  0.05
# Recall:  0.2
# ==================End of File==================
#
#
# ==================Start of File 3==================
# Reading Files: ../Data/relex_processed_data/relex/docred/raw_text\train_annotated_100.txt
# - ../Data/relex_processed_data/relex/docred/tagged_tokens\train_annotated_100.csv
# - ../Data/relex_processed_data/relex/docred/ground_truth\train_annotated_100.csv
#
#
# ===============
# In Occupied Europe during World War II , a co - ordinated assassination offensive against Nazi security forces , codenamed Ratweek , was mounted in January 1944 by the Special Operations Executive ( SOE ) , with the intention of creating confusion and trepidation at the same time as the Allies increased preparations for the Resistance 's contribution to the Normandy Landings .
#
# +++++
# Detected relationship in 'Europe during World War II' of category 'location'
# Detected relationship in 'Ratweek , was mounted in January 1944' of category 'inception'
# Detected relationship in 'January 1944 by the Special Operations Executive' of category 'inception'
# Detected relationship in 'Allies increased preparations for the Resistance' of category 'participant in'
# Detected relationship in 'Allies increased preparations for the Resistance' of category 'participant'
# Detected relationship in 'Resistance 's contribution to the Normandy Landings' of category 'conflict'
# ===============
#
# ===============
# Full details have never been released , but it is known that " Ratweek " achieved successes against Nazi personnel and collaborators in Norway , France , Denmark , and the Netherlands .
#
# +++++
# Detected relationship in 'Ratweek " achieved successes against Nazi' of category 'owner of'
# Detected relationship in 'Denmark , and the Netherlands' of category 'diplomatic relation'
# Detected relationship in 'Denmark , and the Netherlands' of category 'diplomatic relation'
# ===============
#
# ===============
# In 2000 it was revealed that the operation had been supervised by Hardy Amies , best known for his official title as dressmaker for Queen Elizabeth II , and at the time head of the SOE 's Belgian Section .
#
# +++++
# Detected relationship in 'SOE 's Belgian Section' of category 'subsidiary'
# Detected relationship in 'SOE 's Belgian Section' of category 'parent organization'
# ===============
#
#
#
# DETECTED RELATIONSHIPS:
# Europe during World War II
# Ratweek , was mounted in January 1944
# January 1944 by the Special Operations Executive
# Allies increased preparations for the Resistance
# Allies increased preparations for the Resistance
# Resistance 's contribution to the Normandy Landings
# Ratweek " achieved successes against Nazi
# Denmark , and the Netherlands
# Denmark , and the Netherlands
# SOE 's Belgian Section
# SOE 's Belgian Section
#
#
# GROUND TRUTH RELATIONSHIPS:
#
#
#
#
# BENCHMARK:
# True Positives: 0
# False Positives: 11
# False Negatives: 0
#
#
# Precision:  0.0
# ==================End of File==================
#
#
# ==================Start of File 4==================
# Reading Files: ../Data/relex_processed_data/relex/docred/raw_text\train_annotated_1000.txt
# - ../Data/relex_processed_data/relex/docred/tagged_tokens\train_annotated_1000.csv
# - ../Data/relex_processed_data/relex/docred/ground_truth\train_annotated_1000.csv
#
#
# ===============
# The Paulsboro Public Schools is a comprehensive community public school district that serves students in kindergarten through twelfth grade from Paulsboro , in Gloucester County , New Jersey , United States .
#
# +++++
# Detected relationship in 'Paulsboro , in Gloucester County' of category 'located in the administrative territorial entity'
# ===============
#
# ===============
# As of the 2014 - 15 school year , the district and its four schools had an enrollment of 1,142 students and 106.1 classroom teachers ( on an FTE basis ) , for a student – teacher ratio of 10.8:1 .
#
# +++++
# Detected relationship in '1,142 students and 106.1' of category 'number of participants'
# Detected relationship in '1,142 students and 106.1' of category 'has part'
# ===============
#
# ===============
# The district is classified by the New Jersey Department of Education as being in District Factor Group " A " , the lowest of eight groupings .
#
# +++++
# Detected relationship in 'District Factor Group " A " , the lowest of eight' of category 'has part'
# Detected relationship in 'District Factor Group " A " , the lowest of eight' of category 'part of'
# ===============
#
# ===============
# District Factor Groups organize districts statewide to allow comparison by common socioeconomic characteristics of the local districts .
#
# +++++
# ===============
#
# ===============
# From lowest socioeconomic status to highest , the categories are A , B , CD , DE , FG , GH , I and J.
#
# +++++
# ===============
#
# ===============
# Students in ninth through twelfth grades from Greenwich Township attend the district 's high school as part of a sending / receiving relationship with the Greenwich Township School District .
#
# +++++
# ===============
#
# ===============
# As of the 2014 - 15 school year , the high school had an enrollment of 374 students and 36.2 classroom teachers ( on an FTE basis ) , for a student – teacher ratio of 10.3:1 .
#
# +++++
# Detected relationship in '374 students and 36.2' of category 'is a list of'
# ===============
#
#
#
# DETECTED RELATIONSHIPS:
# Paulsboro , in Gloucester County
# 1,142 students and 106.1
# 1,142 students and 106.1
# District Factor Group " A " , the lowest of eight
# District Factor Group " A " , the lowest of eight
# 374 students and 36.2
#
#
# GROUND TRUTH RELATIONSHIPS:
# Paulsboro Public Schools is a comprehensive community public school district that serves students in kindergarten through twelfth grade from Paulsboro , in Gloucester County , New Jersey
# Paulsboro Public Schools is a comprehensive community public school district that serves students in kindergarten through twelfth grade from Paulsboro , in Gloucester County , New Jersey , United States
# Paulsboro , in Gloucester County
# Paulsboro , in Gloucester County , New Jersey , United States
# Gloucester County , New Jersey , United States
#
#
#
# Matched Relationship: Paulsboro , in Gloucester County with relationship: located in the administrative territorial entity
#
#
# BENCHMARK:
# True Positives: 1
# False Positives: 5
# False Negatives: 4
#
#
# Precision:  0.16666666666666666
# Recall:  0.2
# ==================End of File==================
#
#
# ==================Start of File 5==================
# Reading Files: ../Data/relex_processed_data/relex/docred/raw_text\train_annotated_1001.txt
# - ../Data/relex_processed_data/relex/docred/tagged_tokens\train_annotated_1001.csv
# - ../Data/relex_processed_data/relex/docred/ground_truth\train_annotated_1001.csv
#
#
# ===============
# Bru is an island in Rennesøy municipality in Rogaland county , Norway .
#
# +++++
# Detected relationship in 'Bru is an island in Rennesøy' of category 'instance of'
# Detected relationship in 'Bru is an island in Rennesøy' of category 'located in the administrative territorial entity'
# Detected relationship in 'Rennesøy municipality in Rogaland county' of category 'located in the administrative territorial entity'
# Detected relationship in 'Rennesøy municipality in Rogaland county' of category 'contains administrative territorial entity'
# ===============
#
# ===============
# The island lies south of the Boknafjorden , just off the coast of the Stavanger peninsula , along the Byfjorden .
#
# +++++
# Detected relationship in 'Stavanger peninsula , along the Byfjorden' of category 'located in the administrative territorial entity'
# ===============
#
# ===============
# The highest point on the island is the tall mountain , Brufjellet .
#
# +++++
# ===============
#
# ===============
# The island sits in a group of islands with Sokn and Mosterøy to the north and Åmøy to the east .
#
# +++++
# Detected relationship in 'Sokn and Mosterøy' of category 'shares border with'
# Detected relationship in 'Sokn and Mosterøy' of category 'shares border with'
# ===============
#
# ===============
# The island has a road connection to the mainland .
#
# +++++
# ===============
#
# ===============
# There is a bridge on the northeast side of Bru connecting it to the island of Sokn , to the north .
#
# +++++
# ===============
#
# ===============
# Sokn is connected to the mainland by the Byfjord Tunnel , part of the European route E39 highway .
#
# +++++
# Detected relationship in 'Sokn is connected to the mainland by the Byfjord' of category 'located in or next to body of water'
# Detected relationship in 'European route E39 highway' of category 'instance of'
# ===============
#
# ===============
# The tunnel actually passes below the island of Bru on its way to Stavanger .
#
# +++++
# Detected relationship in 'Bru on its way to Stavanger' of category 'located in or next to body of water'
# ===============
#
# ===============
# The island is populated , mostly on the eastern side in what is referred to as the village of Bru .
#
# +++++
# ===============
#
# ===============
# There is a growing population of commuters who live on the island and work in the nearby city of Stavanger .
#
# +++++
# ===============
#
# ===============
# The soil is cultivated on the eastern part of the island , while the western part is mainly moorland .
#
# +++++
# ===============
#
# ===============
# Most farmers on the island keep sheep .
#
# +++++
# ===============
#
#
#
# DETECTED RELATIONSHIPS:
# Bru is an island in Rennesøy
# Bru is an island in Rennesøy
# Rennesøy municipality in Rogaland county
# Rennesøy municipality in Rogaland county
# Stavanger peninsula , along the Byfjorden
# Sokn and Mosterøy
# Sokn and Mosterøy
# Sokn is connected to the mainland by the Byfjord
# European route E39 highway
# Bru on its way to Stavanger
#
#
# GROUND TRUTH RELATIONSHIPS:
# Rennesøy municipality in Rogaland county
# Rennesøy municipality in Rogaland county , Norway
# Rennesøy municipality in Rogaland county
#
#
#
# Matched Relationship: Rennesøy municipality in Rogaland county with relationship: located in the administrative territorial entity
#
# Index matched for ''Rennesøy municipality in Rogaland county'' but relationship type not matched with PREDICTED as: contains administrative territorial entity and ACTUAL as: located in the administrative territorial entity
#
#
# BENCHMARK:
# True Positives: 1
# False Positives: 9
# False Negatives: 1
#
#
# Precision:  0.1
# Recall:  0.5
# ==================End of File==================
#
#
# ==================Start of File 6==================
# Reading Files: ../Data/relex_processed_data/relex/docred/raw_text\train_annotated_1002.txt
# - ../Data/relex_processed_data/relex/docred/tagged_tokens\train_annotated_1002.csv
# - ../Data/relex_processed_data/relex/docred/ground_truth\train_annotated_1002.csv
#
#
# ===============
# Canada – New Zealand relations refers to international relations between New Zealand and Canada .
#
# +++++
# Detected relationship in 'Canada – New Zealand relations refers to international relations between New Zealand' of category 'country'
# Detected relationship in 'New Zealand and Canada' of category 'diplomatic relation'
# Detected relationship in 'New Zealand and Canada' of category 'diplomatic relation'
# ===============
#
# ===============
# New Zealand and Canada have a longstanding relationship that has been fostered by both countries ' shared history and culture , by their membership of the Commonwealth of Nations and links between residents of both countries .
#
# +++++
# Detected relationship in 'New Zealand and Canada' of category 'diplomatic relation'
# Detected relationship in 'New Zealand and Canada' of category 'diplomatic relation'
# ===============
#
# ===============
# The two countries have a common Head of State in Queen Elizabeth II ( legally , the Queen is equally and separately the Head of State of both nations , as Queen of Canada and Queen of New Zealand ) .
#
# +++++
# Detected relationship in 'Elizabeth II ( legally , the Queen is equally and separately the Head of State of both nations , as Queen of Canada' of category 'position held'
# Detected relationship in 'Elizabeth II ( legally , the Queen is equally and separately the Head of State of both nations , as Queen of Canada' of category 'position held'
# Detected relationship in 'Elizabeth II ( legally , the Queen is equally and separately the Head of State of both nations , as Queen of Canada' of category 'officeholder'
# Detected relationship in 'Elizabeth II ( legally , the Queen is equally and separately the Head of State of both nations , as Queen of Canada' of category 'officeholder'
# Detected relationship in 'Canada and Queen of New Zealand' of category 'diplomatic relation'
# Detected relationship in 'Canada and Queen of New Zealand' of category 'diplomatic relation'
# ===============
#
# ===============
# New Zealand and Canada also have links through business or trade relations , the United Nations , the Commonwealth of Nations and mutual treaty agreements .
#
# +++++
# Detected relationship in 'New Zealand and Canada' of category 'diplomatic relation'
# Detected relationship in 'New Zealand and Canada' of category 'diplomatic relation'
# Detected relationship in 'Canada also have links through business or trade relations , the United Nations' of category 'member of'
# Detected relationship in 'United Nations , the Commonwealth of Nations' of category 'diplomatic relation'
# Detected relationship in 'United Nations , the Commonwealth of Nations' of category 'diplomatic relation'
# ===============
#
# ===============
# New Zealand - Canada relations are therefore important to both countries .
#
# +++++
# ===============
#
#
#
# DETECTED RELATIONSHIPS:
# Canada – New Zealand relations refers to international relations between New Zealand
# New Zealand and Canada
# New Zealand and Canada
# New Zealand and Canada
# New Zealand and Canada
# Elizabeth II ( legally , the Queen is equally and separately the Head of State of both nations , as Queen of Canada
# Elizabeth II ( legally , the Queen is equally and separately the Head of State of both nations , as Queen of Canada
# Elizabeth II ( legally , the Queen is equally and separately the Head of State of both nations , as Queen of Canada
# Elizabeth II ( legally , the Queen is equally and separately the Head of State of both nations , as Queen of Canada
# Canada and Queen of New Zealand
# Canada and Queen of New Zealand
# New Zealand and Canada
# New Zealand and Canada
# Canada also have links through business or trade relations , the United Nations
# United Nations , the Commonwealth of Nations
# United Nations , the Commonwealth of Nations
#
#
# GROUND TRUTH RELATIONSHIPS:
# Canada also have links through business or trade relations , the United Nations
# Elizabeth II ( legally , the Queen is equally and separately the Head of State of both nations , as Queen of Canada
# New Zealand and Canada also have links through business or trade relations , the United Nations
# Elizabeth II ( legally , the Queen is equally and separately the Head of State of both nations , as Queen of Canada and Queen of New Zealand
# Elizabeth II ( legally , the Queen is equally and separately the Head of State of both nations , as Queen of Canada
#
#
#
# Index matched for ''Elizabeth II ( legally , the Queen is equally and separately the Head of State of both nations , as Queen of Canada'' but relationship type not matched with PREDICTED as: position held and ACTUAL as: head of state
#
# Index matched for ''Elizabeth II ( legally , the Queen is equally and separately the Head of State of both nations , as Queen of Canada'' but relationship type not matched with PREDICTED as: position held and ACTUAL as: head of state
#
# Index matched for ''Elizabeth II ( legally , the Queen is equally and separately the Head of State of both nations , as Queen of Canada'' but relationship type not matched with PREDICTED as: officeholder and ACTUAL as: head of state
#
# Index matched for ''Elizabeth II ( legally , the Queen is equally and separately the Head of State of both nations , as Queen of Canada'' but relationship type not matched with PREDICTED as: officeholder and ACTUAL as: head of state
#
# Matched Relationship: Canada also have links through business or trade relations , the United Nations with relationship: member of
#
#
# BENCHMARK:
# True Positives: 1
# False Positives: 15
# False Negatives: 2
#
#
# Precision:  0.0625
# Recall:  0.3333333333333333
# ==================End of File==================
#
#
# ==================Start of File 7==================
# Reading Files: ../Data/relex_processed_data/relex/docred/raw_text\train_annotated_1003.txt
# - ../Data/relex_processed_data/relex/docred/tagged_tokens\train_annotated_1003.csv
# - ../Data/relex_processed_data/relex/docred/ground_truth\train_annotated_1003.csv
#
#
# ===============
# Antwerp ( , , ) is a city in Belgium , and is the capital of Antwerp province in Flanders .
#
# +++++
# Detected relationship in 'Antwerp ( , , ) is a city in Belgium' of category 'country'
# Detected relationship in 'Belgium , and is the capital of Antwerp' of category 'capital'
# Detected relationship in 'Belgium , and is the capital of Antwerp' of category 'country'
# Detected relationship in 'Antwerp province in Flanders' of category 'part of'
# Detected relationship in 'Antwerp province in Flanders' of category 'capital'
# ===============
#
# ===============
# With a population of 520,504 , it is the most populous city proper in Belgium .
#
# +++++
# ===============
#
# ===============
# Its metropolitan area houses around 1,200,000 people , coming in second behind Brussels .
#
# +++++
# ===============
#
# ===============
# Antwerp is on the River Scheldt , linked to the North Sea by the Westerschelde estuary .
#
# +++++
# Detected relationship in 'Antwerp is on the River Scheldt' of category 'located in or next to body of water'
# Detected relationship in 'River Scheldt , linked to the North Sea' of category 'mouth of the watercourse'
# Detected relationship in 'River Scheldt , linked to the North Sea' of category 'tributary'
# Detected relationship in 'North Sea by the Westerschelde estuary' of category 'tributary'
# Detected relationship in 'North Sea by the Westerschelde estuary' of category 'mouth of the watercourse'
# ===============
#
# ===============
# It is about north of Brussels , and about from the Dutch border .
#
# +++++
# ===============
#
# ===============
# The Port of Antwerp is one of the biggest in the world , ranking second in Europe and within the top 20 globally .
#
# +++++
# ===============
#
# ===============
# Antwerp was also the place of the world 's oldest stock exchange building , originally built in 1531 and re - built in 1872 .
#
# +++++
# ===============
#
# ===============
# Antwerp has long been an important city in the Low Countries , both economically and culturally , especially before the Spanish Fury ( 1576 ) and in the Dutch Revolt .
#
# +++++
# ===============
#
# ===============
# The inhabitants of Antwerp are nicknamed Sinjoren ( ) , after the Spanish honorific señor or French seigneur , " lord " , referring to the Spanish noblemen who ruled the city in the 17th century .
#
# +++++
# Detected relationship in 'Antwerp are nicknamed Sinjoren' of category 'located in the administrative territorial entity'
# Detected relationship in 'Sinjoren ( ) , after the Spanish' of category 'language used'
# ===============
#
# ===============
# Today Antwerp is a major trade and cultural centre .
#
# +++++
# ===============
#
# ===============
# The city hosted the 1920 Summer Olympics .
#
# +++++
# ===============
#
#
#
# DETECTED RELATIONSHIPS:
# Antwerp ( , , ) is a city in Belgium
# Belgium , and is the capital of Antwerp
# Belgium , and is the capital of Antwerp
# Antwerp province in Flanders
# Antwerp province in Flanders
# Antwerp is on the River Scheldt
# River Scheldt , linked to the North Sea
# River Scheldt , linked to the North Sea
# North Sea by the Westerschelde estuary
# North Sea by the Westerschelde estuary
# Antwerp are nicknamed Sinjoren
# Sinjoren ( ) , after the Spanish
#
#
# GROUND TRUTH RELATIONSHIPS:
# Antwerp is on the River Scheldt
# Belgium , and is the capital of Antwerp province in Flanders
# Belgium , and is the capital of Antwerp province in Flanders
# Belgium , and is the capital of Antwerp province in Flanders
# River Scheldt , linked to the North Sea
#
#
#
# Matched Relationship: Antwerp is on the River Scheldt with relationship: located in or next to body of water
#
# Matched Relationship: River Scheldt , linked to the North Sea with relationship: mouth of the watercourse
#
# Index matched for ''River Scheldt , linked to the North Sea'' but relationship type not matched with PREDICTED as: tributary and ACTUAL as: mouth of the watercourse
#
#
# BENCHMARK:
# True Positives: 2
# False Positives: 10
# False Negatives: 3
#
#
# Precision:  0.16666666666666666
# Recall:  0.4
# ==================End of File==================
#
#
# ==================Start of File 8==================
# Reading Files: ../Data/relex_processed_data/relex/docred/raw_text\train_annotated_1004.txt
# - ../Data/relex_processed_data/relex/docred/tagged_tokens\train_annotated_1004.csv
# - ../Data/relex_processed_data/relex/docred/ground_truth\train_annotated_1004.csv
#
#
# ===============
# Pymatuning State Park is a Pennsylvania state park covering in Conneaut , North Shenango , Pine , Sadsbury , South Shenango , West Fallowfield and West Shenango Townships , Crawford County , Pennsylvania , in the United States .
#
# +++++
# Detected relationship in 'Pymatuning State Park is a Pennsylvania' of category 'located in the administrative territorial entity'
# Detected relationship in 'Pennsylvania state park covering in Conneaut' of category 'contains administrative territorial entity'
# Detected relationship in 'Pennsylvania state park covering in Conneaut' of category 'located in the administrative territorial entity'
# Detected relationship in 'West Fallowfield and West Shenango Townships' of category 'instance of'
# Detected relationship in 'West Fallowfield and West Shenango Townships' of category 'instance of'
# Detected relationship in 'Pennsylvania , in the United States' of category 'country'
# Detected relationship in 'Pennsylvania , in the United States' of category 'contains administrative territorial entity'
# ===============
#
# ===============
# Pymatuning State Park is the largest state park in Pennsylvania and contains the of Pymatuning Lake , three - quarters of which is in Pennsylvania and one - quarter of which is in Ohio .
#
# +++++
# Detected relationship in 'Pymatuning State Park is the largest state park in Pennsylvania' of category 'located in the administrative territorial entity'
# Detected relationship in 'Pennsylvania and one - quarter' of category 'part of'
# Detected relationship in 'Pennsylvania and one - quarter' of category 'has part'
# ===============
#
# ===============
# A three - mile ( 5   km ) causeway extends between Pennsylvania and Ohio near the center of the lake .
#
# +++++
# Detected relationship in 'Pennsylvania and Ohio' of category 'shares border with'
# Detected relationship in 'Pennsylvania and Ohio' of category 'shares border with'
# ===============
#
# ===============
# The lake provides fishing and boating year round .
#
# +++++
# ===============
#
# ===============
# There are two natural areas , Clark Island ( ) and Blackjack ( ) in the park .
#
# +++++
# Detected relationship in 'two natural areas , Clark Island' of category 'instance of'
# Detected relationship in 'Clark Island ( ) and Blackjack' of category 'location'
# ===============
#
# ===============
# The park is also home to the University of Pittsburgh 's Pymatuning Laboratory of Ecology .
#
# +++++
# Detected relationship in 'University of Pittsburgh 's Pymatuning Laboratory of Ecology' of category 'part of'
# ===============
#
# ===============
# Like all Pennsylvania state parks , admission to the Pymatuning State Park is free .
#
# +++++
# ===============
#
# ===============
# The northern access for Pymatuning State Park can be reached from U.S. Route 6 and the southern access is reached from U.S. Route 322 .
#
# +++++
# Detected relationship in 'Pymatuning State Park can be reached from U.S. Route 6' of category 'located on street'
# ===============
#
# ===============
# Pymatuning State Park was chosen by the Pennsylvania Department of Conservation and Natural Resources ( DCNR ) and its Bureau of Parks as one of " 25 Must - See Pennsylvania State Parks " .
#
# +++++
# Detected relationship in 'Pymatuning State Park was chosen by the Pennsylvania Department of Conservation and Natural Resources' of category 'operator'
# Detected relationship in 'DCNR ) and its Bureau of Parks' of category 'subsidiary'
# Detected relationship in 'DCNR ) and its Bureau of Parks' of category 'parent organization'
# Detected relationship in 'Bureau of Parks as one of " 25 Must - See Pennsylvania State Parks' of category 'operator'
# ===============
#
#
#
# DETECTED RELATIONSHIPS:
# Pymatuning State Park is a Pennsylvania
# Pennsylvania state park covering in Conneaut
# Pennsylvania state park covering in Conneaut
# West Fallowfield and West Shenango Townships
# West Fallowfield and West Shenango Townships
# Pennsylvania , in the United States
# Pennsylvania , in the United States
# Pymatuning State Park is the largest state park in Pennsylvania
# Pennsylvania and one - quarter
# Pennsylvania and one - quarter
# Pennsylvania and Ohio
# Pennsylvania and Ohio
# two natural areas , Clark Island
# Clark Island ( ) and Blackjack
# University of Pittsburgh 's Pymatuning Laboratory of Ecology
# Pymatuning State Park can be reached from U.S. Route 6
# Pymatuning State Park was chosen by the Pennsylvania Department of Conservation and Natural Resources
# DCNR ) and its Bureau of Parks
# DCNR ) and its Bureau of Parks
# Bureau of Parks as one of " 25 Must - See Pennsylvania State Parks
#
#
# GROUND TRUTH RELATIONSHIPS:
# Conneaut , North Shenango , Pine , Sadsbury , South Shenango , West Fallowfield and West Shenango Townships , Crawford County
# Conneaut , North Shenango , Pine , Sadsbury , South Shenango , West Fallowfield and West Shenango Townships , Crawford County , Pennsylvania , in the United States
# North Shenango , Pine , Sadsbury , South Shenango , West Fallowfield and West Shenango Townships , Crawford County
# North Shenango , Pine , Sadsbury , South Shenango , West Fallowfield and West Shenango Townships , Crawford County , Pennsylvania , in the United States
# Pine , Sadsbury , South Shenango , West Fallowfield and West Shenango Townships , Crawford County
# Pine , Sadsbury , South Shenango , West Fallowfield and West Shenango Townships , Crawford County , Pennsylvania , in the United States
# Sadsbury , South Shenango , West Fallowfield and West Shenango Townships , Crawford County
# Sadsbury , South Shenango , West Fallowfield and West Shenango Townships , Crawford County , Pennsylvania , in the United States
# South Shenango , West Fallowfield and West Shenango Townships , Crawford County
# South Shenango , West Fallowfield and West Shenango Townships , Crawford County , Pennsylvania , in the United States
# West Fallowfield and West Shenango Townships , Crawford County
# West Fallowfield and West Shenango Townships , Crawford County , Pennsylvania , in the United States
# West Shenango Townships , Crawford County , Pennsylvania , in the United States
# Crawford County , Pennsylvania , in the United States
# Pymatuning State Park is a Pennsylvania state park covering in Conneaut , North Shenango , Pine , Sadsbury , South Shenango , West Fallowfield and West Shenango Townships , Crawford County , Pennsylvania , in the United States
#
#
#
#
# BENCHMARK:
# True Positives: 0
# False Positives: 20
# False Negatives: 15
#
#
# Precision:  0.0
# Recall:  0.0
# ==================End of File==================
#
#
# ==================Start of File 9==================
# Reading Files: ../Data/relex_processed_data/relex/docred/raw_text\train_annotated_1005.txt
# - ../Data/relex_processed_data/relex/docred/tagged_tokens\train_annotated_1005.csv
# - ../Data/relex_processed_data/relex/docred/ground_truth\train_annotated_1005.csv
#
#
# ===============
# The Canadian Screen Award for Best First Feature , formerly the Claude Jutra Award , is a special Canadian film award , presented by the Academy of Canadian Cinema and Television to the year 's best feature film by a first - time film director .
#
# +++++
# Detected relationship in 'Canadian Screen Award for Best First Feature , formerly the Claude Jutra Award' of category 'instance of'
# Detected relationship in 'Claude Jutra Award , is a special Canadian' of category 'country'
# ===============
#
# ===============
# The award was previously named in memory of Claude Jutra , a Canadian film director who died in 1986 .
#
# +++++
# Detected relationship in 'Claude Jutra , a Canadian' of category 'country of citizenship'
# ===============
#
# ===============
# Formerly part of the Genie Awards ceremonies , the Claude Jutra Award was transitioned to be part of the Canadian Screen Awards .
#
# +++++
# Detected relationship in 'Genie Awards ceremonies , the Claude Jutra Award' of category 'instance of'
# ===============
#
# ===============
# Following the February 2016 publication of Yves Lever 's biography of Jutra , containing allegations that Jutra had sexually abused underage children during his lifetime , the Academy announced that it was renaming the award to its current name .
#
# +++++
# Detected relationship in 'February 2016 publication of Yves Lever' of category 'publication date'
# Detected relationship in 'Yves Lever 's biography of Jutra' of category 'author'
# Detected relationship in 'Jutra , containing allegations that Jutra' of category 'instance of'
# ===============
#
# ===============
# Québec Cinéma also removed Jutra 's name from its Prix Jutra ceremonies on the same day .
#
# +++++
# Detected relationship in 'Jutra 's name from its Prix Jutra' of category 'named after'
# ===============
#
# ===============
# The award is a juried prize whose winner is announced in advance , although the prize is formally presented to the winner at the ceremony .
#
# +++++
# ===============
#
# ===============
# To date three films , The Confessional ( Le Confessionnal ) , and Away from Her , have won both the Best First Feature and Best Picture awards in the same year ; all three films ' directors also won the award for Best Director for the same films .
#
# +++++
# Detected relationship in 'three films , The Confessional' of category 'instance of'
# Detected relationship in 'Le Confessionnal ) , and Away from Her' of category 'followed by'
# Detected relationship in 'Le Confessionnal ) , and Away from Her' of category 'follows'
# Detected relationship in 'Best First Feature and Best Picture' of category 'instance of'
# Detected relationship in 'Best First Feature and Best Picture' of category 'has part'
# ===============
#
#
#
# DETECTED RELATIONSHIPS:
# Canadian Screen Award for Best First Feature , formerly the Claude Jutra Award
# Claude Jutra Award , is a special Canadian
# Claude Jutra , a Canadian
# Genie Awards ceremonies , the Claude Jutra Award
# February 2016 publication of Yves Lever
# Yves Lever 's biography of Jutra
# Jutra , containing allegations that Jutra
# Jutra 's name from its Prix Jutra
# three films , The Confessional
# Le Confessionnal ) , and Away from Her
# Le Confessionnal ) , and Away from Her
# Best First Feature and Best Picture
# Best First Feature and Best Picture
#
#
# GROUND TRUTH RELATIONSHIPS:
# Claude Jutra , a Canadian film director who died in 1986
#
#
#
#
# BENCHMARK:
# True Positives: 0
# False Positives: 13
# False Negatives: 1
#
#
# Precision:  0.0
# Recall:  0.0
# ==================End of File==================
#
#
# ==================Start of File 10==================
# Reading Files: ../Data/relex_processed_data/relex/docred/raw_text\train_annotated_1006.txt
# - ../Data/relex_processed_data/relex/docred/tagged_tokens\train_annotated_1006.csv
# - ../Data/relex_processed_data/relex/docred/ground_truth\train_annotated_1006.csv
#
#
# ===============
# Tikhon Nikolayevich Khrennikov (;   – 14 August 2007 ) , HSL , PAU , was a Russian and Soviet composer , pianist , and leader of the Union of Soviet Composers , who was also known for his political activities .
#
# +++++
# Detected relationship in 'Russian and Soviet' of category 'diplomatic relation'
# Detected relationship in 'Russian and Soviet' of category 'diplomatic relation'
# Detected relationship in 'Soviet composer , pianist , and leader of the Union of Soviet Composers' of category 'country'
# ===============
#
# ===============
# He wrote three symphonies , four piano concertos , two violin concertos , two cello concertos , operas , operettas , ballets , chamber music , incidental music and film music .
#
# +++++
# Detected relationship in 'three symphonies , four' of category 'number of participants'
# Detected relationship in 'four piano concertos , two' of category 'uses'
# Detected relationship in 'two violin concertos , two' of category 'is a list of'
# ===============
#
# ===============
# During the 1930s , Khrennikov was already being hailed as a leading official Soviet composer .
#
# +++++
# ===============
#
# ===============
# In 1948 , Andrei Zhdanov , the leader of the anti - formalism campaign , nominated Khrennikov as Secretary of the Union of Soviet Composers .
#
# +++++
# Detected relationship in 'Andrei Zhdanov , the leader of the anti - formalism campaign' of category 'member of political party'
# Detected relationship in 'anti - formalism campaign , nominated Khrennikov' of category 'movement'
# Detected relationship in 'Khrennikov as Secretary of the Union of Soviet Composers' of category 'office held by head of the organization'
# ===============
#
# ===============
# He held this influential post until the collapse of the Soviet Union in 1991 .
#
# +++++
# ===============
#
#
#
# DETECTED RELATIONSHIPS:
# Russian and Soviet
# Russian and Soviet
# Soviet composer , pianist , and leader of the Union of Soviet Composers
# three symphonies , four
# four piano concertos , two
# two violin concertos , two
# Andrei Zhdanov , the leader of the anti - formalism campaign
# anti - formalism campaign , nominated Khrennikov
# Khrennikov as Secretary of the Union of Soviet Composers
#
#
# GROUND TRUTH RELATIONSHIPS:
# Tikhon Nikolayevich Khrennikov (; – 14 August 2007 ) , HSL , PAU , was a Russian
#
#
#
#
# BENCHMARK:
# True Positives: 0
# False Positives: 9
# False Negatives: 1
#
#
# Precision:  0.0
# Recall:  0.0
# ==================End of File==================
#
#
# ==================Start of File 11==================
# Reading Files: ../Data/relex_processed_data/relex/docred/raw_text\train_annotated_1007.txt
# - ../Data/relex_processed_data/relex/docred/tagged_tokens\train_annotated_1007.csv
# - ../Data/relex_processed_data/relex/docred/ground_truth\train_annotated_1007.csv
#
#
# ===============
# Franklin County Regional Airport , formerly known as Chambersburg Municipal Airport , is a general aviation airport located three miles ( 5   km ) north of the Borough of Chambersburg , in Franklin County , Pennsylvania , USA .
#
# +++++
# Detected relationship in 'Franklin County Regional Airport , formerly known as Chambersburg Municipal Airport' of category 'place served by transport hub'
# Detected relationship in '5   km ) north of the Borough of Chambersburg' of category 'instance of'
# Detected relationship in 'Chambersburg , in Franklin County' of category 'located in the administrative territorial entity'
# Detected relationship in 'Chambersburg , in Franklin County' of category 'contains administrative territorial entity'
# ===============
#
# ===============
# The airport is situated approximately 45 miles southwest of Harrisburg .
#
# +++++
# Detected relationship in '45 miles southwest of Harrisburg' of category 'elevation above sea level'
# ===============
#
# ===============
# In 2004 , the Susquehanna Area Regional Airport Authority ( SARAA ) bought Franklin County Regional Airport and formed a Study Advisory Group ( SAG ) to develop a list of recommended improvements at the airport .
#
# +++++
# Detected relationship in '2004 , the Susquehanna Area Regional Airport Authority' of category 'inception'
# Detected relationship in 'SARAA ) bought Franklin County Regional Airport' of category 'owned by'
# Detected relationship in 'Franklin County Regional Airport and formed a Study Advisory Group' of category 'instance of'
# ===============
#
# ===============
# Those improvements included : rehabilitation of the runway , taxiway , ramp area and other landside faculties , additional parking , signage , hangars , an automated weather observation station ( AWOS ) and a fueling service .
#
# +++++
# ===============
#
# ===============
# The improvements will be made on a priority basis and as grant monies become available .
#
# +++++
# ===============
#
#
#
# DETECTED RELATIONSHIPS:
# Franklin County Regional Airport , formerly known as Chambersburg Municipal Airport
# 5   km ) north of the Borough of Chambersburg
# Chambersburg , in Franklin County
# Chambersburg , in Franklin County
# 45 miles southwest of Harrisburg
# 2004 , the Susquehanna Area Regional Airport Authority
# SARAA ) bought Franklin County Regional Airport
# Franklin County Regional Airport and formed a Study Advisory Group
#
#
# GROUND TRUTH RELATIONSHIPS:
# Chambersburg , in Franklin County
# Chambersburg , in Franklin County , Pennsylvania , USA
# Franklin County , Pennsylvania , USA
#
#
#
# ...
#
# +++++
# Detected relationship in 'Zürich – Winterthur line towards Zürich Oerlikon station' of category 'connecting line'
# ===============
#
# ===============
# Trains on the S6 provide a half - hourly connection to Zürich Hauptbahnhof station , taking 12 minutes for the journey via the southern connector and Oerlikon station .
#
# +++++
# Detected relationship in 'S6 provide a half - hourly connection to Zürich Hauptbahnhof' of category 'connecting line'
# Detected relationship in 'Zürich Hauptbahnhof station , taking 12 minutes' of category 'length'
# ===============
#
# ===============
# In the opposite direction , S6 trains continue to Baden station , taking 28 minutes for the journey .
#
# +++++
# Detected relationship in 'S6 trains continue to Baden' of category 'connecting line'
# Detected relationship in 'Baden station , taking 28 minutes' of category 'length'
# ===============
#
# ===============
# The station also sees significant through freight traffic , most of which takes the Furttal line in order to avoid passing through central Zürich , using the northern connector onto or off the Zürich – Winterthur line .
#
# +++++
# ===============
#
#
#
# DETECTED RELATIONSHIPS:
# Zürich Seebach ( ) is a railway station in the Seebach
# Seebach quarter of the Swiss
# Swiss city of Zürich
# S6 of the Zürich
# Furttal line continues as a dual track railway towards Zürich Affoltern
# Furttal line continues as a dual track railway towards Zürich Affoltern
# Zürich – Winterthur line towards Zürich Oerlikon station
# S6 provide a half - hourly connection to Zürich Hauptbahnhof
# Zürich Hauptbahnhof station , taking 12 minutes
# S6 trains continue to Baden
# Baden station , taking 28 minutes
#
#
# GROUND TRUTH RELATIONSHIPS:
# Zürich Seebach ( ) is a railway station in the Seebach quarter of the Swiss
# Zürich Seebach ( ) is a railway station in the Seebach quarter of the Swiss city of Zürich
# Seebach quarter of the Swiss
# Seebach quarter of the Swiss city of Zürich
# Swiss city of Zürich
# Swiss city of Zürich
# Swiss city of Zürich
#
#
#
# Matched Relationship: Seebach quarter of the Swiss with relationship: country
#
# Index matched for ''Swiss city of Zürich'' but relationship type not matched with PREDICTED as: country and ACTUAL as: contains administrative territorial entity
#
#
# BENCHMARK:
# True Positives: 1
# False Positives: 10
# False Negatives: 3
#
#
# Precision:  0.09090909090909091
# Recall:  0.25
# ==================End of File==================
#
#
# ==================Start of File 432==================
# Reading Files: ../Data/relex_processed_data/relex/docred/raw_text\train_annotated_1387.txt
# - ../Data/relex_processed_data/relex/docred/tagged_tokens\train_annotated_1387.csv
# - ../Data/relex_processed_data/relex/docred/ground_truth\train_annotated_1387.csv
#
#
# ===============
# Theodore Vernon Enslin ( March 25 , 1925 – November 21 , 2011 ) was an American poet associated with Cid Corman 's Origin and press .
#
# +++++
# Detected relationship in 'American poet associated with Cid Corman' of category 'country of citizenship'
# Detected relationship in 'Cid Corman 's Origin' of category 'performer'
# ===============
#
# ===============
# He is widely regarded as one of the most musical of American avant - garde poets .
#
# +++++
# ===============
#
# ===============
# Enslin was born in Chester , Pennsylvania .
#
# +++++
# Detected relationship in 'Enslin was born in Chester' of category 'place of birth'
# ===============
#
# ===============
# His father was a biblical scholar and his mother a Latin scholar .
#
# +++++
# ===============
#
# ===============
# He studied musical composition at Cambridge , Massachusetts .
#
# +++++
# ===============
#
# ===============
# His teacher , Nadia Boulanger , was the first person to recognize his ability as a writer and encouraged him to pursue his interest in poetry .
#
# +++++
# ===============
#
# ===============
# He has said " I like to be considered as a composer who happens to use words instead of notes . "
#
# +++++
# ===============
#
# ===============
# His first book , The Work Proposed , was published by Origin in 1958 .
#
# +++++
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25100/3698774800.py in <module>
# ----> 1 all_precision_docred, all_recall_docred, all_valid_relationships, all_valid_ids, all_valid_rel, all_valid_ents, all_valid_ents_type = benchmark_dataset(tagged_token_files_docred_sample, ground_truth_files_docred_sample, raw_text_files_docred_sample, snowball_pos_pattern_docred_filter, docred_total_index, False, True)
#
# ~\AppData\Local\Temp/ipykernel_25100/1075745540.py in benchmark_dataset(tagged_token_files, ground_truth_files, raw_text_files, snowball_pos_pattern, total_index, re_compute, relations)
#      64                         valid_relationships.append(relationships)
#      65                         if relations == True:
# ---> 66                             doc = nlp_re(relationships)
#      67                             rel = []
#      68                             for value, rel_dict in doc._.rel.items():
#
# ~\AppData\Roaming\Python\Python38\site-packages\spacy\language.py in __call__(self, text, disable, component_cfg)
#    1009                 error_handler = proc.get_error_handler()
#    1010             try:
# -> 1011                 doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1012             except KeyError as e:
#    1013                 # This typically happens if a component is not initialized
#
# ~\Repos\Work\Indepedent Study\Code\spacy_component.py in __call__(self, doc)
#     229         """
#     230
# --> 231         sentence_triplets = self._generate_triplets(doc.sents)
#     232         self.set_annotations(doc, sentence_triplets)
#     233
#
# ~\Repos\Work\Indepedent Study\Code\spacy_component.py in _generate_triplets(self, sents)
#     146         """
#     147
# --> 148         output_ids = self.triplet_extractor(
#     149                 [sent.text for sent in sents],
#     150                 return_tensors = True,
#
# ~\AppData\Roaming\Python\Python38\site-packages\transformers\pipelines\text2text_generation.py in __call__(self, *args, **kwargs)
#     135         """
#     136
# --> 137         result = super().__call__(*args, **kwargs)
#     138         if (
#     139             isinstance(args[0], list)
#
# ~\AppData\Roaming\Python\Python38\site-packages\transformers\pipelines\base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1030                     inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1031                 )
# -> 1032                 outputs = [output for output in final_iterator]
#    1033                 return outputs
#    1034             else:
#
# ~\AppData\Roaming\Python\Python38\site-packages\transformers\pipelines\base.py in <listcomp>(.0)
#    1030                     inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1031                 )
# -> 1032                 outputs = [output for output in final_iterator]
#    1033                 return outputs
#    1034             else:
#
# ~\AppData\Roaming\Python\Python38\site-packages\transformers\pipelines\pt_utils.py in __next__(self)
#     109
#     110         # We're out of items within a batch
# --> 111         item = next(self.iterator)
#     112         processed = self.infer(item, **self.params)
#     113         # We now have a batch of "inferred things".
#
# ~\AppData\Roaming\Python\Python38\site-packages\transformers\pipelines\pt_utils.py in __next__(self)
#     110         # We're out of items within a batch
#     111         item = next(self.iterator)
# --> 112         processed = self.infer(item, **self.params)
#     113         # We now have a batch of "inferred things".
#     114         if self.loader_batch_size is not None:
#
# ~\AppData\Roaming\Python\Python38\site-packages\transformers\pipelines\base.py in forward(self, model_inputs, **forward_params)
#     957                 with inference_context():
#     958                     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# --> 959                     model_outputs = self._forward(model_inputs, **forward_params)
#     960                     model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#     961             else:
#
# ~\AppData\Roaming\Python\Python38\site-packages\transformers\pipelines\text2text_generation.py in _forward(self, model_inputs, **generate_kwargs)
#     157         generate_kwargs["max_length"] = generate_kwargs.get("max_length", self.model.config.max_length)
#     158         self.check_inputs(input_length, generate_kwargs["min_length"], generate_kwargs["max_length"])
# --> 159         output_ids = self.model.generate(**model_inputs, **generate_kwargs)
#     160         out_b = output_ids.shape[0]
#     161         if self.framework == "pt":
#
# c:\users\debde\appdata\local\programs\python\python38\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# ~\AppData\Roaming\Python\Python38\site-packages\transformers\generation_utils.py in generate(self, inputs, max_length, min_length, do_sample, early_stopping, num_beams, temperature, top_k, top_p, typical_p, repetition_penalty, bad_words_ids, force_words_ids, bos_token_id, pad_token_id, eos_token_id, length_penalty, no_repeat_ngram_size, encoder_no_repeat_ngram_size, num_return_sequences, max_time, max_new_tokens, decoder_start_token_id, use_cache, num_beam_groups, diversity_penalty, prefix_allowed_tokens_fn, logits_processor, renormalize_logits, stopping_criteria, constraints, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, forced_bos_token_id, forced_eos_token_id, remove_invalid_values, synced_gpus, exponential_decay_length_penalty, **model_kwargs)
#    1352             )
#    1353             # 12. run beam search
# -> 1354             return self.beam_search(
#    1355                 input_ids,
#    1356                 beam_scorer,
#
# ~\AppData\Roaming\Python\Python38\site-packages\transformers\generation_utils.py in beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, **model_kwargs)
#    2203             model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2204
# -> 2205             outputs = self(
#    2206                 **model_inputs,
#    2207                 return_dict=True,
#
# c:\users\debde\appdata\local\programs\python\python38\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\AppData\Roaming\Python\Python38\site-packages\transformers\models\bart\modeling_bart.py in forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1351                 )
#    1352
# -> 1353         outputs = self.model(
#    1354             input_ids,
#    1355             attention_mask=attention_mask,
#
# c:\users\debde\appdata\local\programs\python\python38\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\AppData\Roaming\Python\Python38\site-packages\transformers\models\bart\modeling_bart.py in forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1238
#    1239         # decoder outputs consists of (dec_features, past_key_value, dec_hidden, dec_attn)
# -> 1240         decoder_outputs = self.decoder(
#    1241             input_ids=decoder_input_ids,
#    1242             attention_mask=decoder_attention_mask,
#
# c:\users\debde\appdata\local\programs\python\python38\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\AppData\Roaming\Python\Python38\site-packages\transformers\models\bart\modeling_bart.py in forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1096             else:
#    1097
# -> 1098                 layer_outputs = decoder_layer(
#    1099                     hidden_states,
#    1100                     attention_mask=attention_mask,
#
# c:\users\debde\appdata\local\programs\python\python38\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\AppData\Roaming\Python\Python38\site-packages\transformers\models\bart\modeling_bart.py in forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, layer_head_mask, cross_attn_layer_head_mask, past_key_value, output_attentions, use_cache)
#     452         # Fully Connected
#     453         residual = hidden_states
# --> 454         hidden_states = self.activation_fn(self.fc1(hidden_states))
#     455         hidden_states = nn.functional.dropout(hidden_states, p=self.activation_dropout, training=self.training)
#     456         hidden_states = self.fc2(hidden_states)
#
# c:\users\debde\appdata\local\programs\python\python38\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\users\debde\appdata\local\programs\python\python38\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
all_precision_docred

# %%
all_recall_docred
